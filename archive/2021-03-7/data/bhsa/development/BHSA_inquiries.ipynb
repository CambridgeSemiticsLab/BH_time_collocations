# %% [markdown]
# # BHSA Inquiries
#
# In this NB we probe the BHSA data and look for shortcomings in the time adverbials which are tagged.

# %%
import collections
import pandas as pd
from helpers import convert2pandas
from tf_tools.load import load_tf
from tf_tools.tokenizers import tokenize_surface
TF, API, A = load_tf(hoist=globals())

A.displaySetup(condenseType='clause', extraFeatures='st top_assoc lex', withNodes=True)

pd.set_option('display.max_rows', None) # prevent pd truncating the table
# Out:
# This is Text-Fabric 7.9.0
# Api reference : https://annotation.github.io/text-fabric/Api/Fabric/
#
# 120 features found and 4 ignored
#   0.00s loading features ...
#    |     0.54s T otype                from /Users/cody/github/CambridgeSemiticsLab/time_collocations/data/bhsa/tf
#    |     9.31s T oslots               from /Users/cody/github/CambridgeSemiticsLab/time_collocations/data/bhsa/tf
#    |     0.00s No structure info in otext, the structure part of the T-API cannot be used
#    |      |     0.78s C __levels__           from otype, oslots, otext
#    |      |       16s C __order__            from otype, oslots, __levels__
#    |      |     0.72s C __rank__             from otype, __order__
#    |      |       15s C __levUp__            from otype, oslots, __rank__
#    |      |       10s C __levDown__          from otype, __levUp__, __rank__
#    |      |     3.61s C __boundary__         from otype, oslots, __rank__
#    |      |     0.07s C __sections__         from otype, oslots, otext, __levUp__, __levels__, book, chapter, verse
#    |     0.20s T vt                   from /Users/cody/github/CambridgeSemiticsLab/time_collocations/data/bhsa/tf
#     58s All features loaded/computed - for details use loadLog()
# <style>
# @font-face {
#   font-family: "Ezra SIL";
#   src:
#     local("SILEOT.ttf"),
#     url("https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true");
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0a6611;
#     display: flex;
#     flex-flow: column nowrap;
#     padding: 0.1em;
#     margin: 0.1em;
#     direction: ltr;
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1em 0em;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-style: italic;
#   font-size: small;
#   font-weight: normal;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .verse {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .vl {
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-end;
#     align-items: flex-end;
#     direction: ltr;
#     width: 100%;
# }
# .outeritem {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .sentence,.clause,.phrase {
#     margin-top: -1.2em;
#     margin-left: 1em;
#     background: #ffffff none repeat scroll 0 0;
#     padding: 0 0.3em;
#     border-style: solid;
#     border-radius: 0.2em;
#     font-size: small;
#     display: block;
#     width: fit-content;
#     max-width: fit-content;
#     direction: ltr;
# }
# .atoms {
#     display: flex;
#     flex-flow: row wrap;
#     margin: 0.3em;
#     padding: 0.3em;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .satom,.catom,.patom {
#     margin: 0.3em;
#     padding: 0.3em;
#     border-radius: 0.3em;
#     border-style: solid;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .sentence {
#     border-color: #aa3333;
#     border-width: 1px;
# }
# .clause {
#     border-color: #aaaa33;
#     border-width: 1px;
# }
# .phrase {
#     border-color: #33aaaa;
#     border-width: 1px;
# }
# .satom {
#     border-color: #aa3333;
#     border-width: 4px;
# }
# .catom {
#     border-color: #aaaa33;
#     border-width: 3px;
# }
# .patom {
#     border-color: #33aaaa;
#     border-width: 3px;
# }
# .word {
#     padding: 0.1em;
#     margin: 0.1em;
#     border-radius: 0.1em;
#     border: 1px solid #cccccc;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .lextp {
#     padding: 0.1em;
#     margin: 0.1em;
#     border-radius: 0.1em;
#     border: 2px solid #888888;
#     width: fit-content;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .occs {
#     font-size: x-small;
# }
# .satom.l,.catom.l,.patom.l {
#     border-left-style: dotted
# }
# .satom.r,.catom.r,.patom.r {
#     border-right-style: dotted
# }
# .satom.lno,.catom.lno,.patom.lno {
#     border-left-style: none
# }
# .satom.rno,.catom.rno,.patom.rno {
#     border-right-style: none
# }
# .tr,.tr a:visited,.tr a:link {
#     font-family: sans-serif;
#     font-size: large;
#     color: #000044;
#     direction: ltr;
#     text-decoration: none;
# }
# .trb,.trb a:visited,.trb a:link {
#     font-family: sans-serif;
#     font-size: normal;
#     direction: ltr;
#     text-decoration: none;
# }
# .prb,.prb a:visited,.prb a:link {
#     font-family: sans-serif;
#     font-size: large;
#     direction: ltr;
#     text-decoration: none;
# }
# .h,.h a:visited,.h a:link {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     color: #000044;
#     direction: rtl;
#     text-decoration: none;
# }
# .hb,.hb a:visited,.hb a:link {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     line-height: 2;
#     direction: rtl;
#     text-decoration: none;
# }
# .vn {
#   font-size: small !important;
#   padding-right: 1em;
# }
# .rela,.function,.typ {
#     font-family: monospace;
#     font-size: small;
#     color: #0000bb;
# }
# .pdp,.pdp a:visited,.pdp a:link {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
#     text-decoration: none;
# }
# .voc_lex {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
# }
# .vs {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .vt {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .gloss {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #444444;
# }
# .vrs {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: #444444;
# }
# .nd {
#     font-family: monospace;
#     font-size: x-small;
#     color: #999999;
# }
# .hl {
#     background-color: #ffee66;
# }
#
# tr.tf, td.tf, th.tf {
#   text-align: left;
# }
#
# span.hldot {
# 	background-color: var(--hl-strong);
# 	border: 0.2rem solid var(--hl-rim);
# 	border-radius: 0.4rem;
# 	/*
# 	display: inline-block;
# 	width: 0.8rem;
# 	height: 0.8rem;
# 	*/
# }
# span.hl {
# 	background-color: var(--hl-strong);
# 	border-width: 0;
# 	border-radius: 0.1rem;
# 	border-style: solid;
# }
#
# span.hlup {
# 	border-color: var(--hl-dark);
# 	border-width: 0.1rem;
# 	border-style: solid;
# 	border-radius: 0.2rem;
#   padding: 0.2rem;
# }
#
# :root {
# 	--hl-strong:        hsla( 60, 100%,  70%, 0.9  );
# 	--hl-rim:           hsla( 55, 100%,  60%, 0.9  );
# 	--hl-dark:          hsla( 55, 100%,  40%, 0.9  );
# }
# </style>

# %% [markdown]
# ## Modi

# %% [markdown]
# ### Surfaces

# %%
modi_counts = collections.Counter()

for ph in F.function.s('Modi'):
    surface = tokenize_surface(ph, A.api)
    modi_counts[surface] += 1
    
modi_counts = convert2pandas(modi_counts)

# %%
modi_counts.shape
# Out:
# (518, 1)

# %%
modi_counts.head(100)
# Out:
#                  Total
# כה                 564
# כן                 302
# לכן                200
# מאד                186
# גם                 129
# סביב                96
# יחדו                91
# אף                  79
# אך                  77
# עוד                 70
# עתה                 59
# שׁם                 53
# מות                 49
# אולי                44
# יחד                 43
# רק                  36
# ככה                 34
# הרבה                29
# חנם                 28
# סביב.סביב           25
# זה                  24
# אולם                19
# ריקם                15
# ידע                 12
# שׁמוע               11
# מעט                 10
# דבר.יום.ב.יומו      10
# תמיד                 9
# אחור                 9
# אמנם                 9
# הנה                  8
# כבר                  7
# היטב                 7
# אספרנא               7
# חיה                  7
# שׁמה                 7
# עשׂה                 7
# בטח                  6
# בדד                  6
# הרבה.מאד             6
# יהודית               6
# נקה                  6
# שׁוב                 6
# השׁב                 6
# ברך                  6
# שׁלם                 5
# המת                  5
# הגד                  5
# הצל                  5
# ברם                  5
# הלוך                 5
# דרך.שׁלשׁת.ימים      5
# שׁבע                 5
# להן                  5
# שׁקר                 5
# אפס                  5
# רבת                  5
# שׂגיא                5
# שׁמע                 5
# פקד                  5
# כנמא                 5
# ארמית                5
# פנים.אל.פנים         5
# אבד                  4
# פשׂה                 4
# ראשׁנה               4
# היו                  4
# יצא                  4
# קדימה                4
# בכו                  4
# הבל                  4
# כליל                 4
# רבה                  4
# הלך                  4
# אמר                  4
# יומם                 4
# מאד.מאד              4
# חיו                  4
# בא                   4
# בוא                  4
# כען                  4
# יכול                 3
# גאל                  3
# אחרנית               3
# אכל                  3
# ה.חוצה               3
# אף.אמנם              3
# נתון                 3
# החרשׁ                3
# רב                   3
# אסף                  3
# עשׂו                 3
# נתן                  3
# הוכח                 3
# שׁלח                 3
# נגבה                 3
# טרף                  3
# פתע                  3
# צפונה                3
# אז                   3

# %%
# find modi phrases with time-attracted word

# A.show(A.search('''

# p:phrase function=Modi
#     w:word top_assoc=Time
    
# p := w
# p =: w

# ''')[100:], condenseType='clause', end=200)

# %% [markdown]
# ## TO DO:
#
# * check "PT</" in Adju phrases: e.g. `693977`; but there is also one in a Cmpl phrase (!): `779825`
#
#
# ## Consider:
#
# * HRBH (RBH\[)
# * KBR/

# %%
# find modi phrases with lexeme

A.show(A.search('''

p:phrase function=Modi
    w:word lex~>Z
    
p =: w
p := w

'''), condenseType='clause', end=200)
# Out:
#   0.75s 5 results
# <p><b>result</b> <i>1</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Judices&amp;chapter=5&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Judges 5:8">Judges 5:8</a>
# <div class="atoms  " >
# <a href="#" class="nd">451581</a>
#
#
#
# <div class="catom  " >
#
#     <div class="clause " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Judices&amp;chapter=5&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Judges 5:8" sec="Judges 5:8">clause</a> <a href="#" class="nd">451581</a>  <span class="typ">NmCl</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  hl" >
#
#     <div class="phrase hl" >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Judices&amp;chapter=5&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Judges 5:8" sec="Judges 5:8">phrase</a> <a href="#" class="nd">724446</a>  <span class="function">Modi</span> <span class="typ">AdvP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  hl" >
# <a href="#" class="nd">130059</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1AZ" title="show this lexeme in SHEBANQ">אָ֖ז </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Judices&amp;chapter=5&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Judges 5:8" sec="Judges 5:8">advb</a></span> <span class="gloss">then</span> <span class="lex xft"><span class="f">lex=</span>>Z</span> <span class="top_assoc xft"><span class="f">top_assoc=</span>Time</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Judices&amp;chapter=5&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Judges 5:8" sec="Judges 5:8">phrase</a> <a href="#" class="nd">724447</a>  <span class="function">Subj</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <a href="#" class="nd">130060</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1LXMin" title="show this lexeme in SHEBANQ">לָחֶ֣ם </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Judices&amp;chapter=5&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Judges 5:8" sec="Judges 5:8">subs</a></span> <span class="gloss">&lt;uncertain></span> <span class="lex xft"><span class="f">lex=</span>LXM=/</span> <span class="st xft"><span class="f">st=</span>a</span> <span class="top_assoc xft"><span class="f">top_assoc=</span>Subj</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Judices&amp;chapter=5&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Judges 5:8" sec="Judges 5:8">phrase</a> <a href="#" class="nd">724448</a>  <span class="function">PreC</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <a href="#" class="nd">130061</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CORn" title="show this lexeme in SHEBANQ">שְׁעָרִ֑ים </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Judices&amp;chapter=5&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Judges 5:8" sec="Judges 5:8">subs</a></span> <span class="gloss">gate</span> <span class="lex xft"><span class="f">lex=</span>C&lt;R/</span> <span class="st xft"><span class="f">st=</span>a</span> <span class="top_assoc xft"><span class="f">top_assoc=</span>Loca</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>2</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=2&amp;verse=5&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Daniel 2:5">Daniel 2:5</a>
# <div class="atoms  " >
# <a href="#" class="nd">506088</a>
#
#
#
# <div class="catom  " >
#
#     <div class="clause " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=2&amp;verse=5&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Daniel 2:5" sec="Daniel 2:5">clause</a> <a href="#" class="nd">506088</a>  <span class="typ">NmCl</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=2&amp;verse=5&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Daniel 2:5" sec="Daniel 2:5">phrase</a> <a href="#" class="nd">876511</a>  <span class="function">Subj</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <a href="#" class="nd">370623</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=2MLHn" title="show this lexeme in SHEBANQ">מִלְּתָ֖א </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=2&amp;verse=5&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Daniel 2:5" sec="Daniel 2:5">subs</a></span> <span class="gloss">word</span> <span class="lex xft"><span class="f">lex=</span>MLH/</span> <span class="st xft"><span class="f">st=</span>e</span> <span class="top_assoc xft"><span class="f">top_assoc=</span>Subj</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=2&amp;verse=5&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Daniel 2:5" sec="Daniel 2:5">phrase</a> <a href="#" class="nd">876512</a>  <span class="function">PreC</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <a href="#" class="nd">370624</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=2MN" title="show this lexeme in SHEBANQ">מִנִּ֣י </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=2&amp;verse=5&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Daniel 2:5" sec="Daniel 2:5">prep</a></span> <span class="gloss">from</span> <span class="lex xft"><span class="f">lex=</span>MN</span> <span class="top_assoc xft"><span class="f">top_assoc=</span>Cmpl</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  hl" >
#
#     <div class="phrase hl" >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=2&amp;verse=5&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Daniel 2:5" sec="Daniel 2:5">phrase</a> <a href="#" class="nd">876513</a>  <span class="function">Modi</span> <span class="typ">AdvP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  hl" >
# <a href="#" class="nd">370625</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=2AZDA" title="show this lexeme in SHEBANQ">אַזְדָּ֑א </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=2&amp;verse=5&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Daniel 2:5" sec="Daniel 2:5">advb</a></span> <span class="gloss">publicly known</span> <span class="lex xft"><span class="f">lex=</span>>ZD></span> <span class="top_assoc xft"><span class="f">top_assoc=</span>Modi</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>3</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=2&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Daniel 2:8">Daniel 2:8</a>
# <div class="atoms  " >
# <a href="#" class="nd">506104</a>
#
#
#
# <div class="catom  " >
#
#     <div class="clause " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=2&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Daniel 2:8" sec="Daniel 2:8">clause</a> <a href="#" class="nd">506104</a>  <span class="rela">Objc</span> <span class="typ">NmCl</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=2&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Daniel 2:8" sec="Daniel 2:8">phrase</a> <a href="#" class="nd">876558</a>  <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <a href="#" class="nd">370687</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=2DJ" title="show this lexeme in SHEBANQ">דִּ֥י </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=2&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Daniel 2:8" sec="Daniel 2:8">conj</a></span> <span class="gloss">&lt;relative></span> <span class="lex xft"><span class="f">lex=</span>DJ</span> <span class="top_assoc xft"><span class="f">top_assoc=</span>Rela</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  hl" >
#
#     <div class="phrase hl" >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=2&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Daniel 2:8" sec="Daniel 2:8">phrase</a> <a href="#" class="nd">876559</a>  <span class="function">Modi</span> <span class="typ">AdvP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  hl" >
# <a href="#" class="nd">370688</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=2AZDA" title="show this lexeme in SHEBANQ">אַזְדָּ֖א </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=2&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Daniel 2:8" sec="Daniel 2:8">advb</a></span> <span class="gloss">publicly known</span> <span class="lex xft"><span class="f">lex=</span>>ZD></span> <span class="top_assoc xft"><span class="f">top_assoc=</span>Modi</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=2&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Daniel 2:8" sec="Daniel 2:8">phrase</a> <a href="#" class="nd">876560</a>  <span class="function">PreC</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <a href="#" class="nd">370689</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=2MN" title="show this lexeme in SHEBANQ">מִנִּ֥י </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=2&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Daniel 2:8" sec="Daniel 2:8">prep</a></span> <span class="gloss">from</span> <span class="lex xft"><span class="f">lex=</span>MN</span> <span class="top_assoc xft"><span class="f">top_assoc=</span>Cmpl</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=2&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Daniel 2:8" sec="Daniel 2:8">phrase</a> <a href="#" class="nd">876561</a>  <span class="function">Subj</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <a href="#" class="nd">370690</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=2MLHn" title="show this lexeme in SHEBANQ">מִלְּתָֽא׃ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=2&amp;verse=8&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Daniel 2:8" sec="Daniel 2:8">subs</a></span> <span class="gloss">word</span> <span class="lex xft"><span class="f">lex=</span>MLH/</span> <span class="st xft"><span class="f">st=</span>e</span> <span class="top_assoc xft"><span class="f">top_assoc=</span>Subj</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>4</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_I&amp;chapter=11&amp;verse=16&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="1_Chronicles 11:16">1_Chronicles 11:16</a>
# <div class="atoms  " >
# <a href="#" class="nd">510746</a>
#
#
#
# <div class="catom  " >
#
#     <div class="clause " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_I&amp;chapter=11&amp;verse=16&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Chronicles 11:16" sec="1_Chronicles 11:16">clause</a> <a href="#" class="nd">510746</a>  <span class="typ">NmCl</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_I&amp;chapter=11&amp;verse=16&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Chronicles 11:16" sec="1_Chronicles 11:16">phrase</a> <a href="#" class="nd">890004</a>  <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <a href="#" class="nd">397308</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="show this lexeme in SHEBANQ">וְ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_I&amp;chapter=11&amp;verse=16&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Chronicles 11:16" sec="1_Chronicles 11:16">conj</a></span> <span class="gloss">and</span> <span class="lex xft"><span class="f">lex=</span>W</span> <span class="top_assoc xft"><span class="f">top_assoc=</span>Conj</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_I&amp;chapter=11&amp;verse=16&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Chronicles 11:16" sec="1_Chronicles 11:16">phrase</a> <a href="#" class="nd">890005</a>  <span class="function">Subj</span> <span class="typ">PrNP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <a href="#" class="nd">397309</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1DWDiin" title="show this lexeme in SHEBANQ">דָוִ֖יד </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_I&amp;chapter=11&amp;verse=16&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Chronicles 11:16" sec="1_Chronicles 11:16">nmpr</a></span> <span class="gloss">David</span> <span class="lex xft"><span class="f">lex=</span>DWD==/</span> <span class="st xft"><span class="f">st=</span>a</span> <span class="top_assoc xft"><span class="f">top_assoc=</span>Subj</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  hl" >
#
#     <div class="phrase hl" >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_I&amp;chapter=11&amp;verse=16&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Chronicles 11:16" sec="1_Chronicles 11:16">phrase</a> <a href="#" class="nd">890006</a>  <span class="function">Modi</span> <span class="typ">AdvP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  hl" >
# <a href="#" class="nd">397310</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1AZ" title="show this lexeme in SHEBANQ">אָ֣ז </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_I&amp;chapter=11&amp;verse=16&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Chronicles 11:16" sec="1_Chronicles 11:16">advb</a></span> <span class="gloss">then</span> <span class="lex xft"><span class="f">lex=</span>>Z</span> <span class="top_assoc xft"><span class="f">top_assoc=</span>Time</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_I&amp;chapter=11&amp;verse=16&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Chronicles 11:16" sec="1_Chronicles 11:16">phrase</a> <a href="#" class="nd">890007</a>  <span class="function">PreC</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <a href="#" class="nd">397311</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="show this lexeme in SHEBANQ">בַּ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_I&amp;chapter=11&amp;verse=16&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Chronicles 11:16" sec="1_Chronicles 11:16">prep</a></span> <span class="gloss">in</span> <span class="lex xft"><span class="f">lex=</span>B</span> <span class="top_assoc xft"><span class="f">top_assoc=</span>Cmpl</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">397312</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="show this lexeme in SHEBANQ"></a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_I&amp;chapter=11&amp;verse=16&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Chronicles 11:16" sec="1_Chronicles 11:16">art</a></span> <span class="gloss">the</span> <span class="lex xft"><span class="f">lex=</span>H</span> <span class="top_assoc xft"><span class="f">top_assoc=</span>Rela</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">397313</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1MYWDHn" title="show this lexeme in SHEBANQ">מְּצוּדָ֑ה </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_I&amp;chapter=11&amp;verse=16&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Chronicles 11:16" sec="1_Chronicles 11:16">subs</a></span> <span class="gloss">fortification</span> <span class="lex xft"><span class="f">lex=</span>MYWDH/</span> <span class="st xft"><span class="f">st=</span>a</span> <span class="top_assoc xft"><span class="f">top_assoc=</span>PreC</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>5</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_I&amp;chapter=11&amp;verse=16&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="1_Chronicles 11:16">1_Chronicles 11:16</a>
# <div class="atoms  " >
# <a href="#" class="nd">510747</a>
#
#
#
# <div class="catom  " >
#
#     <div class="clause " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_I&amp;chapter=11&amp;verse=16&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Chronicles 11:16" sec="1_Chronicles 11:16">clause</a> <a href="#" class="nd">510747</a>  <span class="typ">NmCl</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_I&amp;chapter=11&amp;verse=16&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Chronicles 11:16" sec="1_Chronicles 11:16">phrase</a> <a href="#" class="nd">890008</a>  <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <a href="#" class="nd">397314</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="show this lexeme in SHEBANQ">וּ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_I&amp;chapter=11&amp;verse=16&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Chronicles 11:16" sec="1_Chronicles 11:16">conj</a></span> <span class="gloss">and</span> <span class="lex xft"><span class="f">lex=</span>W</span> <span class="top_assoc xft"><span class="f">top_assoc=</span>Conj</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_I&amp;chapter=11&amp;verse=16&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Chronicles 11:16" sec="1_Chronicles 11:16">phrase</a> <a href="#" class="nd">890009</a>  <span class="function">Subj</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <a href="#" class="nd">397315</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1NYJBn" title="show this lexeme in SHEBANQ">נְצִ֣יב </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_I&amp;chapter=11&amp;verse=16&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Chronicles 11:16" sec="1_Chronicles 11:16">subs</a></span> <span class="gloss">pillar</span> <span class="lex xft"><span class="f">lex=</span>NYJB/</span> <span class="st xft"><span class="f">st=</span>c</span> <span class="top_assoc xft"><span class="f">top_assoc=</span>Objc</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">397316</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1PLCTJn" title="show this lexeme in SHEBANQ">פְּלִשְׁתִּ֔ים </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_I&amp;chapter=11&amp;verse=16&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Chronicles 11:16" sec="1_Chronicles 11:16">subs</a></span> <span class="gloss">Philistine</span> <span class="lex xft"><span class="f">lex=</span>PLCTJ/</span> <span class="st xft"><span class="f">st=</span>a</span> <span class="top_assoc xft"><span class="f">top_assoc=</span>Subj</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  hl" >
#
#     <div class="phrase hl" >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_I&amp;chapter=11&amp;verse=16&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Chronicles 11:16" sec="1_Chronicles 11:16">phrase</a> <a href="#" class="nd">890010</a>  <span class="function">Modi</span> <span class="typ">AdvP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  hl" >
# <a href="#" class="nd">397317</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1AZ" title="show this lexeme in SHEBANQ">אָ֖ז </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_I&amp;chapter=11&amp;verse=16&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Chronicles 11:16" sec="1_Chronicles 11:16">advb</a></span> <span class="gloss">then</span> <span class="lex xft"><span class="f">lex=</span>>Z</span> <span class="top_assoc xft"><span class="f">top_assoc=</span>Time</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_I&amp;chapter=11&amp;verse=16&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Chronicles 11:16" sec="1_Chronicles 11:16">phrase</a> <a href="#" class="nd">890011</a>  <span class="function">PreC</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <a href="#" class="nd">397318</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="show this lexeme in SHEBANQ">בְּ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_I&amp;chapter=11&amp;verse=16&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Chronicles 11:16" sec="1_Chronicles 11:16">prep</a></span> <span class="gloss">in</span> <span class="lex xft"><span class="f">lex=</span>B</span> <span class="top_assoc xft"><span class="f">top_assoc=</span>Cmpl</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">397319</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1BJT_LXMn" title="show this lexeme in SHEBANQ">בֵ֥ית לָֽחֶם׃ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_I&amp;chapter=11&amp;verse=16&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Chronicles 11:16" sec="1_Chronicles 11:16">nmpr</a></span> <span class="gloss">Bethlehem</span> <span class="lex xft"><span class="f">lex=</span>BJT_LXM/</span> <span class="st xft"><span class="f">st=</span>a</span> <span class="top_assoc xft"><span class="f">top_assoc=</span>Loca</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>

# %% [markdown]
# <hr>

# %%
A.show(A.search('''

clause
/with/
    word pdp=verb
/-/
    p:phrase function=Modi
        w:word g_cons=KL

'''), end=200)
# Out:
#   1.39s 2 results
# <p><b>result</b> <i>1</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=21&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Genesis 21:12">Genesis 21:12</a>
# <div class="atoms  " >
# <a href="#" class="nd">429397</a>
#
#
#
# <div class="catom  l " >
#
#     <div class="clause " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=21&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 21:12" sec="Genesis 21:12">clause</a> <a href="#" class="nd">429397</a>  <span class="typ">xIm0|Defc</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  hl" >
#
#     <div class="phrase hl" >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=21&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 21:12" sec="Genesis 21:12">phrase</a> <a href="#" class="nd">657230</a>  <span class="function">Modi</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  hl" >
# <a href="#" class="nd">9799</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1KLn" title="show this lexeme in SHEBANQ">כֹּל֩ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=21&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 21:12" sec="Genesis 21:12">subs</a></span> <span class="gloss">whole</span> <span class="g_cons xft"><span class="f">g_cons=</span>KL</span> <span class="lex xft"><span class="f">lex=</span>KL/</span> <span class="st xft"><span class="f">st=</span>c</span> <span class="top_assoc xft"><span class="f">top_assoc=</span>Subj</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="catom  r " >
#
#     <div class="clause " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=21&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 21:12" sec="Genesis 21:12">clause</a> <a href="#" class="nd">429397</a>  <span class="typ">xIm0|ZIm0</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=21&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 21:12" sec="Genesis 21:12">phrase</a> <a href="#" class="nd">657235</a>  <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <a href="#" class="nd">9804</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CMOv" title="show this lexeme in SHEBANQ">שְׁמַ֣ע </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=21&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 21:12" sec="Genesis 21:12">verb</a></span> <span class="gloss">hear</span> <span class="vs">qal</span> <span class="vt">impv</span> <span class="g_cons xft"><span class="f">g_cons=</span>CM&lt;</span> <span class="lex xft"><span class="f">lex=</span>CM&lt;[</span> <span class="top_assoc xft"><span class="f">top_assoc=</span>Pred</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=21&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 21:12" sec="Genesis 21:12">phrase</a> <a href="#" class="nd">657236</a>  <span class="function">Cmpl</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <a href="#" class="nd">9805</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="show this lexeme in SHEBANQ">בְּ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=21&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 21:12" sec="Genesis 21:12">prep</a></span> <span class="gloss">in</span> <span class="g_cons xft"><span class="f">g_cons=</span>B</span> <span class="lex xft"><span class="f">lex=</span>B</span> <span class="top_assoc xft"><span class="f">top_assoc=</span>Cmpl</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">9806</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1QWLn" title="show this lexeme in SHEBANQ">קֹלָ֑הּ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=21&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 21:12" sec="Genesis 21:12">subs</a></span> <span class="gloss">sound</span> <span class="g_cons xft"><span class="f">g_cons=</span>QLH</span> <span class="lex xft"><span class="f">lex=</span>QWL/</span> <span class="st xft"><span class="f">st=</span>a</span> <span class="top_assoc xft"><span class="f">top_assoc=</span>Objc</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <p><b>result</b> <i>2</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Jeremia&amp;chapter=44&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Jeremiah 44:12">Jeremiah 44:12</a>
# <div class="atoms  " >
# <a href="#" class="nd">478755</a>
#
#
#
# <div class="catom  " >
#
#     <div class="clause " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Jeremia&amp;chapter=44&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Jeremiah 44:12" sec="Jeremiah 44:12">clause</a> <a href="#" class="nd">478755</a>  <span class="typ">WQt0</span>
#     </div>
#     <div class="atoms">
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Jeremia&amp;chapter=44&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Jeremiah 44:12" sec="Jeremiah 44:12">phrase</a> <a href="#" class="nd">803353</a>  <span class="function">Conj</span> <span class="typ">CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <a href="#" class="nd">258988</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="show this lexeme in SHEBANQ">וְ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Jeremia&amp;chapter=44&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Jeremiah 44:12" sec="Jeremiah 44:12">conj</a></span> <span class="gloss">and</span> <span class="g_cons xft"><span class="f">g_cons=</span>W</span> <span class="lex xft"><span class="f">lex=</span>W</span> <span class="top_assoc xft"><span class="f">top_assoc=</span>Conj</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Jeremia&amp;chapter=44&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Jeremiah 44:12" sec="Jeremiah 44:12">phrase</a> <a href="#" class="nd">803354</a>  <span class="function">Pred</span> <span class="typ">VP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <a href="#" class="nd">258989</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1TMMv" title="show this lexeme in SHEBANQ">תַ֨מּוּ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Jeremia&amp;chapter=44&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Jeremiah 44:12" sec="Jeremiah 44:12">verb</a></span> <span class="gloss">be complete</span> <span class="vs">qal</span> <span class="vt">perf</span> <span class="g_cons xft"><span class="f">g_cons=</span>TMW</span> <span class="lex xft"><span class="f">lex=</span>TMM[</span> <span class="top_assoc xft"><span class="f">top_assoc=</span>Pred</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  hl" >
#
#     <div class="phrase hl" >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Jeremia&amp;chapter=44&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Jeremiah 44:12" sec="Jeremiah 44:12">phrase</a> <a href="#" class="nd">803355</a>  <span class="function">Modi</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  hl" >
# <a href="#" class="nd">258990</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1KLn" title="show this lexeme in SHEBANQ">כֹ֜ל </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Jeremia&amp;chapter=44&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Jeremiah 44:12" sec="Jeremiah 44:12">subs</a></span> <span class="gloss">whole</span> <span class="g_cons xft"><span class="f">g_cons=</span>KL</span> <span class="lex xft"><span class="f">lex=</span>KL/</span> <span class="st xft"><span class="f">st=</span>a</span> <span class="top_assoc xft"><span class="f">top_assoc=</span>Subj</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>

# %%
# A.show(A.search('''

# phrase function=Conj
# /without/
#     word lex=W
# /-/

# '''), end=200,)
