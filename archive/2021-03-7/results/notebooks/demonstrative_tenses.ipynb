# %% [markdown]
# *best viewed in [nbviewer](https://nbviewer.jupyter.org/github/CambridgeSemiticsLab/BH_time_collocations/blob/master/results/notebooks/demonstrative_tenses.ipynb)*

# %% [markdown]
# # Tense Collocations with Demonstratives
# ## Investigating the Effects of Distance
# ### Cody Kingham
# <a href="../../docs/sponsors.md"><img height=200px width=200px align='left' src="../../docs/images/CambridgeU_BW.png"></a>

# %%
! echo "last updated:"; date
# Out:
# last updated:
# Wed  4 Mar 2020 10:45:49 GMT

# %% [markdown]
# ## Introduction
#
# Demonstrative adjectives such as הוא "that (m)", היא "that (f)", זה "this", זאת "these", occur frequently within time adverbials headed by a nominal element. These demonstratives also correspond with a contiuum of "near" versus "far" within a conceptual space. An event which is marked with הוא "that", for instance, is an event in the distant past or future relative to speech time, while an event marked with זה "this" is one which is near to the present of speech time. In this notebook, we will investigate how these opposite poles affect verb collocation tendencies.
#
# The investigation must also involve an examination of the prepositional lexemes that potentially direct these adverbials. For instance, the phrase עד היום הזה "unto this day" represents an event as extended over a time ending at the present. This kind of phrase should be classified differently from the similar phrase היום הזה "this day", which contains no extent and conveys only a single position near the present. The same issues could be said for phrases such as ביום הוא "in that day", a point in time in the future, versus עד היום ההוא "unto that day", an extended time ending in the future.
#
# Because demonstratives will be used with nominalized elements that have no inherent temporal anchor, we can assume that the lexeme of the time-word will matter less for the analysis. The position of the time-word in the conceptual space is fully reliant on the demonstrative element.
#
# ### Relation to prototypical adverb collocations
#
# In the notebook on [yiqtol associations with adverbs](https://nbviewer.jupyter.org/github/CambridgeSemiticsLab/BH_time_collocations/blob/master/results/notebooks/yqtl_association_with_advb.ipynb) we found that prototypical adverbs such as עולם "forever", נצח "duration", מחר "tomorrow", מתי "when", עוד "still", have a strong preference for collocating with the yiqtol. One possibility to explain this pattern is that these adverbials generally indicate open ended times in the future. The interrogative מתי is indeed different from the other cases, but it does share a common attribute of being unbounded (perhaps most explicitly so!). מחר is likewise different. Though it shares the property of being future oriented, does it also share the characteristic of unboundedness?
#
# Since this notebook focuses on nominal time adverbials, we will not see many of these prototypical adverbs. This also provides an opportunity to compare the collocation profiles of these phrases against the yiqtol preference for unbounded futuristic time adverbials. Do we see a similar phenomenon in the demonstratives?
#
# <hr>

# %% [markdown]
# # Python
#
# Now we import the modules and data needed for the analysis.

# %%
# standard & data science packages
import collections
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams['font.serif'] = ['SBL Biblit']
import seaborn as sns
from bidi.algorithm import get_display # bi-directional text support for plotting
from paths import main_table, figs

# custom packages (see /tools)
from tf_tools.load import load_tf
from stats.significance import contingency_table, apply_fishers, apply_deltaP

# launch Text-Fabric with custom data
TF, API, A = load_tf(silent='deep')
A.displaySetup(condenseType='phrase')
F, E, T, L = A.api.F, A.api.E, A.api.T, A.api.L # corpus analysis methods

# load and set up project dataset
times_full = pd.read_csv(main_table, sep='\t')
times_full.set_index(['node'], inplace=True)
times = pd.DataFrame(times_full[~times_full.classi.str.contains('component')]) # select singles
# Out:
# <style>
# @font-face {
#   font-family: "Ezra SIL";
#   src:
#     local("SILEOT.ttf"),
#     url("https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true");
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0a6611;
#     display: flex;
#     flex-flow: column nowrap;
#     padding: 0.1em;
#     margin: 0.1em;
#     direction: ltr;
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1em 0em;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-style: italic;
#   font-size: small;
#   font-weight: normal;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .verse {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .vl {
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-end;
#     align-items: flex-end;
#     direction: ltr;
#     width: 100%;
# }
# .outeritem {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .sentence,.clause,.phrase {
#     margin-top: -1.2em;
#     margin-left: 1em;
#     background: #ffffff none repeat scroll 0 0;
#     padding: 0 0.3em;
#     border-style: solid;
#     border-radius: 0.2em;
#     font-size: small;
#     display: block;
#     width: fit-content;
#     max-width: fit-content;
#     direction: ltr;
# }
# .atoms {
#     display: flex;
#     flex-flow: row wrap;
#     margin: 0.3em;
#     padding: 0.3em;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .satom,.catom,.patom {
#     margin: 0.3em;
#     padding: 0.3em;
#     border-radius: 0.3em;
#     border-style: solid;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .sentence {
#     border-color: #aa3333;
#     border-width: 1px;
# }
# .clause {
#     border-color: #aaaa33;
#     border-width: 1px;
# }
# .phrase {
#     border-color: #33aaaa;
#     border-width: 1px;
# }
# .satom {
#     border-color: #aa3333;
#     border-width: 4px;
# }
# .catom {
#     border-color: #aaaa33;
#     border-width: 3px;
# }
# .patom {
#     border-color: #33aaaa;
#     border-width: 3px;
# }
# .word {
#     padding: 0.1em;
#     margin: 0.1em;
#     border-radius: 0.1em;
#     border: 1px solid #cccccc;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .lextp {
#     padding: 0.1em;
#     margin: 0.1em;
#     border-radius: 0.1em;
#     border: 2px solid #888888;
#     width: fit-content;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .occs {
#     font-size: x-small;
# }
# .satom.l,.catom.l,.patom.l {
#     border-left-style: dotted
# }
# .satom.r,.catom.r,.patom.r {
#     border-right-style: dotted
# }
# .satom.lno,.catom.lno,.patom.lno {
#     border-left-style: none
# }
# .satom.rno,.catom.rno,.patom.rno {
#     border-right-style: none
# }
# .tr,.tr a:visited,.tr a:link {
#     font-family: sans-serif;
#     font-size: large;
#     color: #000044;
#     direction: ltr;
#     text-decoration: none;
# }
# .trb,.trb a:visited,.trb a:link {
#     font-family: sans-serif;
#     font-size: normal;
#     direction: ltr;
#     text-decoration: none;
# }
# .prb,.prb a:visited,.prb a:link {
#     font-family: sans-serif;
#     font-size: large;
#     direction: ltr;
#     text-decoration: none;
# }
# .h,.h a:visited,.h a:link {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     color: #000044;
#     direction: rtl;
#     text-decoration: none;
# }
# .hb,.hb a:visited,.hb a:link {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     line-height: 2;
#     direction: rtl;
#     text-decoration: none;
# }
# .vn {
#   font-size: small !important;
#   padding-right: 1em;
# }
# .rela,.function,.typ {
#     font-family: monospace;
#     font-size: small;
#     color: #0000bb;
# }
# .pdp,.pdp a:visited,.pdp a:link {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
#     text-decoration: none;
# }
# .voc_lex {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
# }
# .vs {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .vt {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .gloss {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #444444;
# }
# .vrs {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: #444444;
# }
# .nd {
#     font-family: monospace;
#     font-size: x-small;
#     color: #999999;
# }
# .hl {
#     background-color: #ffee66;
# }
#
# tr.tf, td.tf, th.tf {
#   text-align: left;
# }
#
# span.hldot {
# 	background-color: var(--hl-strong);
# 	border: 0.2rem solid var(--hl-rim);
# 	border-radius: 0.4rem;
# 	/*
# 	display: inline-block;
# 	width: 0.8rem;
# 	height: 0.8rem;
# 	*/
# }
# span.hl {
# 	background-color: var(--hl-strong);
# 	border-width: 0;
# 	border-radius: 0.1rem;
# 	border-style: solid;
# }
#
# span.hlup {
# 	border-color: var(--hl-dark);
# 	border-width: 0.1rem;
# 	border-style: solid;
# 	border-radius: 0.2rem;
#   padding: 0.2rem;
# }
#
# :root {
# 	--hl-strong:        hsla( 60, 100%,  70%, 0.9  );
# 	--hl-rim:           hsla( 55, 100%,  60%, 0.9  );
# 	--hl-dark:          hsla( 55, 100%,  40%, 0.9  );
# }
# </style>

# %% [markdown]
# ## Data Exploration
#
# Below we look at how often the demonstratives in question appear:

# %%
times.demon_dist.count()
# Out:
# 475

# %% [markdown]
# This ^ is the number of non-null values contained in the dataset. Below we calculate the proportional representation out of all time adverbials.

# %%
times.demon_dist.count() / times.shape[0]
# Out:
# 0.12509876218066895

# %% [markdown]
# These represent $13\%$ of the whole dataset. That is a non-trivial proportion. This already shows that the demonstrative construction plays a key role in Biblical Hebrew time adverbial phrases.

# %% [markdown]
# Here is how the values break down:

# %%
times.demon_dist.value_counts()
# Out:
# far     324
# near    151
# Name: demon_dist, dtype: int64

# %% [markdown]
# ## Collocation Dataset
#
# Now we will build a collocation dataset between the demonstrative categories, preposition lexemes, and verb tenses. First we create a composite column by adding the leading preposition string to the demonstrative.

# %%
times['prep_demon'] = times.leading_prep.fillna('ø') + '|' + times.demon_dist

# %% [markdown]
# We can have a look at the new column's discrete values below.

# %%
times['prep_demon'].value_counts()
# Out:
# ב|far       311
# עד|near      68
# ø|near       31
# ב|near       29
# אחר|near     12
# כ|near        8
# עד|far        6
# ø|far         3
# מן|far        2
# ל|near        2
# אחר|far       1
# ל|far         1
# מן|near       1
# Name: prep_demon, dtype: int64

# %% [markdown]
# Now we can construct a collocation pivot table with the verb tenses. We set aside the infinitives and imperatives. We also drop those cases with < 5 occurrences.

# %%
tense_collocations = pd.pivot_table(
    times, index='prep_demon', columns='tense', 
    aggfunc='size',
    fill_value=0,
).drop(['infc','impv'], 1)

tense_collocations = tense_collocations[tense_collocations.sum(1) >= 5]

tense_collocations
# Out:
# tense       ptcp  qtl  wqtl  wyqtl  yqtl
# prep_demon
# ø|near         1   14     2      1     8
# אחר|near       0    3     0      8     0
# ב|far          9   74    33    107    75
# ב|near         3    8     3      6     8
# עד|far         0    6     0      0     0
# עד|near        2   18     0     37     4

# %% [markdown]
# Let's look at the ratios.

# %%
tense_ratios = tense_collocations.divide(tense_collocations.sum(1), axis=0)

tense_ratios
# Out:
# tense           ptcp       qtl      wqtl     wyqtl      yqtl
# prep_demon
# ø|near      0.038462  0.538462  0.076923  0.038462  0.307692
# אחר|near    0.000000  0.272727  0.000000  0.727273  0.000000
# ב|far       0.030201  0.248322  0.110738  0.359060  0.251678
# ב|near      0.107143  0.285714  0.107143  0.214286  0.285714
# עד|far      0.000000  1.000000  0.000000  0.000000  0.000000
# עד|near     0.032787  0.295082  0.000000  0.606557  0.065574

# %% [markdown]
# And the associations.

# %%
tense_assocs, odds = apply_fishers(tense_collocations, 0, 1)

tense_assocs
# Out:
#               ptcp       qtl      wqtl     wyqtl      yqtl
# ø|near   -0.000000  2.217446  0.000000 -4.041268  0.485302
# אחר|near  0.000000  0.000000 -0.215031  1.653891 -0.877280
# ב|far    -0.389571 -1.960313  1.806835 -0.286822  1.635244
# ב|near    1.178049  0.000000  0.138346 -0.981997  0.320134
# עד|far    0.000000  3.299935  0.000000 -1.049680 -0.460718
# עד|near   0.000000  0.056009 -2.507844  4.273573 -3.106689

# %%
fig = plt.figure(figsize=(8, 6))
# reorder elements for analysis
plot_data = tense_assocs.loc[
    ['ב|near', 'ב|far', 'עד|near', 'עד|far', 'ø|near', 'אחר|near'],
    ['yqtl', 'wqtl', 'ptcp', 'qtl', 'wyqtl']
]
ax = sns.heatmap(plot_data, center=0, robust=True)
ax.set_yticklabels([get_display(t) for t in plot_data.index], size=16, rotation=0, fontfamily='serif')
ax.set_ylabel('prep|demonstrative', size=14)
ax.set_xlabel('verb tense', size=14)
plt.show()

# %% [markdown]
# We can see two important patterns in the graph. Those patterns can be summarized in the following table:
#
# |adverbial|association|
# |---------|-----------|
# |  yqtl   |  ב\|far |
# |  wqtl   |  ב\|far |
# |  qtl    | עד\|far |
# |  qtl    | ø\|near |
# |  wyqtl  | עד\|near|
# | wyqtl   | אחר\|near|
# |  ptcp   | ב\|near |

# %%
fig = plt.figure(figsize=(4, 6))
# reorder elements for analysis
plot_data = tense_assocs.loc[
    ['ב|near', 'ב|far', 'עד|near', 'עד|far', 'ø|near', 'אחר|near'],
    ['qtl', 'yqtl']
]
ax = sns.heatmap(plot_data, center=0, robust=True)
ax.set_yticklabels([get_display(t) for t in plot_data.index], size=16, rotation=0, fontfamily='serif')
ax.set_ylabel('prep|demonstrative', size=14)
ax.set_xlabel('verb tense', size=14)
plt.show()

# %%
fig = plt.figure(figsize=(4, 6))
# reorder elements for analysis
plot_data = tense_assocs.loc[
    ['ב|near', 'ב|far', 'עד|near', 'עד|far', 'ø|near', 'אחר|near'],
    ['qtl', 'wyqtl']
]
ax = sns.heatmap(plot_data, center=0, robust=True)
ax.set_yticklabels([get_display(t) for t in plot_data.index], size=16, rotation=0, fontfamily='serif')
ax.set_ylabel('prep|demonstrative', size=14)
ax.set_xlabel('verb tense', size=14)
plt.show()

# %% [markdown]
# Based on these graphs above we can see a possible two-part opposition:
#
# |  |near|far|
# |--|----|---|
# |**point (ב/ø)**| qtl | yqtl |
# |**extent (עד)**| wyqtl | qtl |

# %% [markdown]
# We should be careful, though. While the עד|near adverbial is associated with wyqtl, it is not at all absent from qtl, with $18$ attested uses. Yet, given the overall frequency of qtl and the overall frequency of the עד|near adverbial, the use with wyqtl is significant.

# %% [markdown]
# ## ΔP Unidirectional Significance Test

# %%
demon_cue = apply_deltaP(tense_collocations, 0, 1)

demon_cue
# Out:
# tense           ptcp       qtl      wqtl     wyqtl      yqtl
# prep_demon
# ø|near      0.003808  0.268660 -0.012186 -0.352628  0.092346
# אחר|near   -0.035800 -0.013669 -0.090692  0.366891 -0.226730
# ב|far      -0.015253 -0.122890  0.072859 -0.034879  0.100163
# ב|near      0.077292 -0.000355  0.020078 -0.166311  0.069296
# עד|far     -0.035377  0.724057 -0.089623 -0.375000 -0.224057
# עד|near    -0.002443  0.010529 -0.102981  0.275934 -0.181039

# %%
demon_cue.describe()
# Out:
# tense      ptcp       qtl      wqtl     wyqtl      yqtl
# count  6.000000  6.000000  6.000000  6.000000  6.000000
# mean  -0.001296  0.144389 -0.033757 -0.047665 -0.061670
# std    0.041834  0.312009  0.071952  0.313357  0.164272
# min   -0.035800 -0.122890 -0.102981 -0.375000 -0.226730
# 25%   -0.030346 -0.010341 -0.090425 -0.306049 -0.213302
# 50%   -0.008848  0.005087 -0.050904 -0.100595 -0.055871
# 75%    0.002245  0.204127  0.012012  0.198231  0.086583
# max    0.077292  0.724057  0.072859  0.366891  0.100163

# %%
fig = plt.figure(figsize=(8, 6))
# reorder elements for analysis
plot_data = demon_cue.loc[
    ['ב|near', 'ב|far', 'עד|near', 'עד|far', 'ø|near', 'אחר|near'],
    ['yqtl', 'wqtl', 'ptcp', 'qtl', 'wyqtl']
]
ax = sns.heatmap(plot_data, center=0, robust=True)
ax.set_yticklabels([get_display(t) for t in plot_data.index], size=14, rotation=0)
ax.set_ylabel('prep|demonstrative', size=14)
ax.set_xlabel('verb tense', size=14)
ax.set_title('ΔP test: Demonstrative as cue verb as response', size=14)
plt.show()

# %% [markdown]
# The plot shows similar results to the Fisher's test.

# %%
verb_cue = apply_deltaP(tense_collocations.T, 0, 1)

verb_cue
# Out:
# prep_demon    ø|near  אחר|near     ב|far    ב|near    עד|far   עד|near
# tense
# ptcp        0.006426 -0.026506 -0.096386  0.139759 -0.014458 -0.008835
# qtl         0.074733 -0.001668 -0.128016 -0.000106  0.048780  0.006276
# wqtl       -0.008593 -0.028061  0.192401  0.015172 -0.015306 -0.155612
# wyqtl      -0.085962  0.039244 -0.031841 -0.043445 -0.022140  0.144144
# yqtl        0.030479 -0.032836  0.123802  0.024509 -0.017910 -0.128044

# %%
verb_cue.describe()
# Out:
# prep_demon    ø|near  אחר|near     ב|far    ב|near    עד|far   עד|near
# count       5.000000  5.000000  5.000000  5.000000  5.000000  5.000000
# mean        0.003417 -0.009965  0.011992  0.027178 -0.004207 -0.028414
# std         0.059077  0.030061  0.139927  0.068113  0.029771  0.119863
# min        -0.085962 -0.032836 -0.128016 -0.043445 -0.022140 -0.155612
# 25%        -0.008593 -0.028061 -0.096386 -0.000106 -0.017910 -0.128044
# 50%         0.006426 -0.026506 -0.031841  0.015172 -0.015306 -0.008835
# 75%         0.030479 -0.001668  0.123802  0.024509 -0.014458  0.006276
# max         0.074733  0.039244  0.192401  0.139759  0.048780  0.144144

# %%
fig = plt.figure(figsize=(8, 6))
# reorder elements for analysis
plot_data = verb_cue
ax = sns.heatmap(plot_data, center=0)
ax.set_xticklabels([get_display(t) for t in plot_data.columns], size=14)
ax.set_ylabel('verb tense', size=14)
ax.set_xlabel('prep|demonstrative', size=14)
ax.set_title('ΔP test: Verb as cue demonstrative as response', size=14)
plt.show()

# %% [markdown]
# Note that our highest value in the demonstrative as cue test was $0.72$ but here it is only $0.19$. Again we see that the verb is not as strong a predictor for choice of time adverbial as time adverbial is of the choice of verb.

# %% [markdown]
# ### Export Inspections

# %%
times[(times.leading_prep == 'עד') & (times.time == 'עתה')]
# Out:
#                  ref         book  ph_type           text   token  \
# node
# 1447848    Deut 12:9  Deuteronomy  prep_ph   עַד־עָ֑תָּה   עד.עתה
# 1449075  2 Kgs 13:23      2_Kings  prep_ph  עַד־עָֽתָּה׃   עד.עתה
#
#                                                                       clause  \
# node
# 1447848  כִּ֥י לֹא־בָּאתֶ֖ם עַד־עָ֑תָּה אֶל־הַמְּנוּחָה֙ וְאֶל־הַֽנַּחֲלָ֔ה
# 1449075                    וְלֹֽא־הִשְׁלִיכָ֥ם מֵֽעַל־פָּנָ֖יו עַד־עָֽתָּה׃
#
#                            classi time time_etcbc time_pos  ...  \
# node                                                        ...
# 1447848  single.prep.bare.øanchor  עתה        <TH     advb  ...
# 1449075  single.prep.bare.øanchor  עתה        <TH     advb  ...
#
#          demonstrative  demon_str  demon_dist ordinal ord_str cl_kind  verb  \
# node
# 1447848          False        NaN         NaN   False     NaN      VC  True
# 1449075          False        NaN         NaN   False     NaN      VC  True
#
#          tense  verb_lex  prep_demon
# node
# 1447848    qtl       בוא         NaN
# 1449075    qtl      שׁלך         NaN
#
# [2 rows x 36 columns]

# %%
pd.set_option('display.max_colwidth', 100)
pd.set_option('display.max_row', 100)

# %%
times[(times.prep_demon == 'עד|far') & (times.tense == 'qtl')][['ref', 'text', 'clause']].head(50)
# Out:
#                 ref                        text  \
# node
# 1448274   Judg 18:1       עַד־הַיֹּ֥ום הַה֛וּא
# 1448807   1 Kgs 3:2  עַ֖ד הַיָּמִ֥ים הָהֵֽם׃ פ
# 1449121  2 Kgs 18:4  עַד־הַיָּמִ֤ים הָהֵ֨מָּה֙
# 1450773    Dan 12:1        עַ֖ד הָעֵ֣ת הַהִ֑יא
# 1450860     Neh 6:1   גַּ֚ם עַד־הָעֵ֣ת הַהִ֔יא
# 1450874    Neh 8:17      עַ֖ד הַיֹּ֣ום הַה֑וּא
#
#                                                                                                    clause
# node
# 1448274     כִּי֩ לֹֽא־נָ֨פְלָה לֹּ֜ו עַד־הַיֹּ֥ום הַה֛וּא בְּתֹוךְ־שִׁבְטֵ֥י יִשְׂרָאֵ֖ל בְּנַחֲלָֽה׃ ס
# 1448807                             כִּ֠י לֹא־נִבְנָ֥ה בַ֨יִת֙ לְשֵׁ֣ם יְהוָ֔ה עַ֖ד הַיָּמִ֥ים הָהֵֽם׃ פ
# 1449121                                        כִּ֣י עַד־הַיָּמִ֤ים הָהֵ֨מָּה֙ הָי֤וּ בְנֵֽי־יִשְׂרָאֵל֙
# %%
qtl_ad_far = times[(times.prep_demon == 'עד|far') & (times.tense == 'qtl')][['ref', 'text', 'clause']]

qtl_ad_far.shape
# Out:
# (6, 3)

# %%
qtl_ad_far
# Out:
#                 ref                        text  \
# node
# 1448274   Judg 18:1       עַד־הַיֹּ֥ום הַה֛וּא
# 1448807   1 Kgs 3:2  עַ֖ד הַיָּמִ֥ים הָהֵֽם׃ פ
# 1449121  2 Kgs 18:4  עַד־הַיָּמִ֤ים הָהֵ֨מָּה֙
# 1450773    Dan 12:1        עַ֖ד הָעֵ֣ת הַהִ֑יא
# 1450860     Neh 6:1   גַּ֚ם עַד־הָעֵ֣ת הַהִ֔יא
# 1450874    Neh 8:17      עַ֖ד הַיֹּ֣ום הַה֑וּא
#
#                                                                                                    clause
# node
# 1448274     כִּי֩ לֹֽא־נָ֨פְלָה לֹּ֜ו עַד־הַיֹּ֥ום הַה֛וּא בְּתֹוךְ־שִׁבְטֵ֥י יִשְׂרָאֵ֖ל בְּנַחֲלָֽה׃ ס
# 1448807                             כִּ֠י לֹא־נִבְנָ֥ה בַ֨יִת֙ לְשֵׁ֣ם יְהוָ֔ה עַ֖ד הַיָּמִ֥ים הָהֵֽם׃ פ
# 1449121                                        כִּ֣י עַד־הַיָּמִ֤ים הָהֵ֨מָּה֙ הָי֤וּ בְנֵֽי־יִשְׂרָאֵל֙
# 1450773                                                      אֲשֶׁ֤ר לֹֽא־נִהְיְתָה֙ עַ֖ד הָעֵ֣ת הַהִ֑יא
# 1450860                             גַּ֚ם עַד־הָעֵ֣ת הַהִ֔יא דְּלָתֹ֖ות לֹא־הֶעֱמַ֥דְתִּי בַשְּׁעָרִֽים׃
# 1450874  כִּ֣י לֹֽא־עָשׂ֡וּ מִימֵי֩ יֵשׁ֨וּעַ בִּן־נ֥וּן כֵּן֙ בְּנֵ֣י יִשְׂרָאֵ֔ל עַ֖ד הַיֹּ֣ום הַה֑וּא

# %%
yqtl_ad_near = times[(times.prep_demon == 'עד|near') & (times.tense == 'yqtl')][['ref', 'tense', 'text', 'clause']]

yqtl_ad_near.shape
# Out:
# (4, 4)

# %%
yqtl_ad_near
# Out:
#                ref tense                           text  \
# node
# 1447029  Gen 32:33  yqtl         עַ֖ד הַיֹּ֣ום הַזֶּ֑ה
# 1447496  Lev 23:14  yqtl  עַד־עֶ֨צֶם֙ הַיֹּ֣ום הַזֶּ֔ה
# 1448206  Judg 10:4  yqtl         עַ֚ד הַיֹּ֣ום הַזֶּ֔ה
# 1448358  1 Sam 5:5  yqtl      עַ֖ד הַיֹּ֥ום הַזֶּֽה׃ ס
#
#                                                                                                       clause
# node
# 1447029             עַל־כֵּ֡ן לֹֽא־יֹאכְל֨וּ בְנֵֽי־יִשְׂרָאֵ֜ל אֶת־גִּ֣יד הַנָּשֶׁ֗ה עַ֖ד הַיֹּ֣ום הַזֶּ֑ה
# 1447496                           וְלֶחֶם֩ וְקָלִ֨י וְכַרְמֶ֜ל לֹ֣א תֹֽאכְל֗וּ עַד־עֶ֨צֶם֙ הַיֹּ֣ום הַזֶּ֔ה
# 1448206                                            לָהֶ֞ם יִקְרְא֣וּ׀ חַוֹּ֣ת יָאִ֗יר עַ֚ד הַיֹּ֣ום הַזֶּ֔ה
# 1448358  עַל־כֵּ֡ן לֹֽא־יִדְרְכוּ֩ כֹהֲנֵ֨י דָגֹ֜ון וְכָֽל־עַל־מִפְתַּ֥ן דָּגֹ֖ון בְּאַשְׁדֹּ֑וד עַ֖ד הַי...

# %%
times[times.tense.isnull()].shape
# Out:
# (541, 36)

# %%
null_ad_near = times[(times.prep_demon == 'עד|near') & (times.tense.isnull())][['ref', 'tense', 'text', 'clause']]

null_ad_near.shape
# Out:
# (6, 4)

# %%
null_ad_near
# Out:
#                ref tense                       text  \
# node
# 1446968  Gen 26:33   NaN  עַ֖ד הַיֹּ֥ום הַזֶּֽה׃ ס
# 1447768  Deut 3:14   NaN    עַ֖ד הַיֹּ֥ום הַזֶּֽה׃
# 1448146  Judg 1:26   NaN  עַ֖ד הַיֹּ֥ום הַזֶּֽה׃ פ
# 1448170  Judg 6:24   NaN     עַ֚ד הַיֹּ֣ום הַזֶּ֔ה
# 1448374  1 Sam 8:8   NaN      עַד־הַיֹּ֣ום הַזֶּ֔ה
# 1450804   Ezra 9:7   NaN     עַ֖ד הַיֹּ֣ום הַזֶּ֑ה
#
#                                                                                clause
# node
# 1446968              עַל־כֵּ֤ן שֵׁם־הָעִיר֙ בְּאֵ֣ר שֶׁ֔בַע עַ֖ד הַיֹּ֥ום הַזֶּֽה׃ ס
# 1447768                        אֶת־הַבָּשָׁן֙ חַוֹּ֣ת יָאִ֔יר עַ֖ד הַיֹּ֥ום הַזֶּֽה׃
# 1448146                                      ה֣וּא שְׁמָ֔הּ עַ֖ד הַיֹּ֥ום הַזֶּֽה׃ פ
# 1448170            עַ֚ד הַיֹּ֣ום הַזֶּ֔ה עֹודֶ֕נּוּ בְּעָפְרָ֖ת אֲבִ֥י הָעֶזְרִֽי׃ פ
# 1448374                                                       וְעַד־הַיֹּ֣ום הַזֶּ֔ה
# 1450804  מִימֵ֣י אֲבֹתֵ֗ינוּ אֲנַ֨חְנוּ֙ בְּאַשְׁמָ֣ה גְדֹלָ֔ה עַ֖ד הַיֹּ֣ום הַזֶּ֑ה

# %% [markdown]
# ## Timephrase preceded by noun

# %%
query = A.search('''

sentence
    phrase typ=NP function#Time|Subj
    <: timephrase
        =: phrase
            =: word lex=<D|L

''')
# Out:
#   1.16s 64 results

# %%
#A.show(query, condenseType='sentence', withNodes=True)

# %% [markdown]
# # TO FIX:
#
# See the cases below. Two cases of demonstratives are included in this set. They are clauses marked as `Ellp` which have verbal mother clauses.
#
# Solving these cases will involve thinking a bit more deeply about how to adapt ETCBC clause definitions to this project.

# %%
verbal = []

for ca, tp in A.search('''
clause_atom typ=Ellp
    timephrase
'''):
    mother = E.mother.f(ca)[0]
    mother_clause = L.u(mother,'clause')[0]
    if F.kind.v(mother_clause) == 'VC':
        verbal.append((ca,tp))
# Out:
#   0.11s 104 results

# %%
len(verbal)
# Out:
# 82

# %%
#A.show(verbal,condenseType='sentence', withNodes=True)
