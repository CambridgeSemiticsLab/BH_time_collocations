# %%
from tf.app import use
A = use('bhsa', hoist=globals())
A.displaySetup(condenseType='clause', withNodes=True, extraFeatures='pdp st')

import sys
import collections
sys.path.append('../scripts/tools/')
from load_parse import ParseLoader

slot2pos = ParseLoader('../../results/parsing/slot2pos.json').load()
pos2slot = collections.defaultdict(set)
for slot, pos in slot2pos.items():
    pos2slot[pos].add(slot)
# Out:
# <b title="local commit">TF-app:</b> <span title="#113c0687cfce3077734dac1844d244d20f4ace6f offline under ~/text-fabric-data">~/text-fabric-data/annotation/app-bhsa/code</span>
# <b title="local release">data:</b> <span title="rv1.6 offline under ~/text-fabric-data">~/text-fabric-data/etcbc/bhsa/tf/c</span>
# <b title="local release">data:</b> <span title="r1.2 offline under ~/text-fabric-data">~/text-fabric-data/etcbc/phono/tf/c</span>
# <b title="local release">data:</b> <span title="r1.2 offline under ~/text-fabric-data">~/text-fabric-data/etcbc/parallels/tf/c</span>
# <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 8.4.14</a>, <a target="_blank" href="https://github.com/annotation/app-bhsa" title="bhsa TF-app">app-bhsa v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br><b>Data:</b> <a target="_blank" href="https://etcbc.github.io/bhsa/0_home" title="provenance of BHSA = Biblia Hebraica Stuttgartensia Amstelodamensis">BHSA</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/hebrew.html" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://etcbc.github.io/bhsa/features/0_home" title="BHSA feature documentation">Feature docs</a><br><b>Features:</b><br><details><summary><b>Parallel Passages</b></summary><b><i><a target="_blank" href="https://nbviewer.jupyter.org/github/etcbc/parallels/blob/master/programs/parallels.ipynb" title="~/text-fabric-data/etcbc/parallels/tf/c/crossref.tf">crossref</a></i></b><br></details><details><summary><b>BHSA = Biblia Hebraica Stuttgartensia Amstelodamensis</b></summary><a target="_blank" href="https://etcbc.github.io/bhsa/features/book" title="~/text-fabric-data/etcbc/bhsa/tf/c/book.tf">book</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/book@ll" title="~/text-fabric-data/etcbc/bhsa/tf/c/book@am.tf">book@ll</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/chapter" title="~/text-fabric-data/etcbc/bhsa/tf/c/chapter.tf">chapter</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/code" title="~/text-fabric-data/etcbc/bhsa/tf/c/code.tf">code</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/det" title="~/text-fabric-data/etcbc/bhsa/tf/c/det.tf">det</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/domain" title="~/text-fabric-data/etcbc/bhsa/tf/c/domain.tf">domain</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/freq_lex" title="~/text-fabric-data/etcbc/bhsa/tf/c/freq_lex.tf">freq_lex</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/function" title="~/text-fabric-data/etcbc/bhsa/tf/c/function.tf">function</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/g_cons" title="~/text-fabric-data/etcbc/bhsa/tf/c/g_cons.tf">g_cons</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/g_cons_utf8" title="~/text-fabric-data/etcbc/bhsa/tf/c/g_cons_utf8.tf">g_cons_utf8</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/g_lex" title="~/text-fabric-data/etcbc/bhsa/tf/c/g_lex.tf">g_lex</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/g_lex_utf8" title="~/text-fabric-data/etcbc/bhsa/tf/c/g_lex_utf8.tf">g_lex_utf8</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/g_word" title="~/text-fabric-data/etcbc/bhsa/tf/c/g_word.tf">g_word</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/g_word_utf8" title="~/text-fabric-data/etcbc/bhsa/tf/c/g_word_utf8.tf">g_word_utf8</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/gloss" title="~/text-fabric-data/etcbc/bhsa/tf/c/gloss.tf">gloss</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/gn" title="~/text-fabric-data/etcbc/bhsa/tf/c/gn.tf">gn</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/label" title="~/text-fabric-data/etcbc/bhsa/tf/c/label.tf">label</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/language" title="~/text-fabric-data/etcbc/bhsa/tf/c/language.tf">language</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/lex" title="~/text-fabric-data/etcbc/bhsa/tf/c/lex.tf">lex</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/lex_utf8" title="~/text-fabric-data/etcbc/bhsa/tf/c/lex_utf ...
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-
# <div><b>Text-Fabric API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF</a> directly usable</div><hr>

# %%
for phrase_atom in L.d(428158, 'phrase_atom'):
    print(phrase_atom, E.mother.f(phrase_atom))
# Out:
# 906675 ()
# 906676 (906675,)
# 906677 ()
# 906678 ()
# 906679 (906678,)
# 906680 ()
# 906681 ()
# 906682 ()

# %%
A.pretty(651894, extraFeatures='function pdp', hiddenTypes=['subphrase'])
# Out:
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=30&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 1:30">Genesis 1:30</a></div><div class="rtl children"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:651894</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Subj</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905125</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">643</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1NPCn" title="Show this on SHEBANQ"><span class="txtu hbo">נֶ֣פֶשׁ </span></a></div><div class='features'><span class="pdp xft" ><span class="f">pdp=</span>subs</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">644</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1XJn" title="Show this on SHEBANQ"><span class="txtu hbo">חַיָּ֔ה </span></a></div><div class='features'><span class="pdp xft" ><span class="f">pdp=</span>adjv</span></div></div></div></div></div></div></div>

# %%
len(F.otype.s('clause'))
# Out:
# 88121

# %% [markdown]
# # Lookup Passages

# %%
passage = ('Psalms', 90, 4)
verse = T.nodeFromSection(passage)
for cl in L.d(verse, 'clause'):
    A.pretty(cl, extraFeatures='function', hiddenTypes={'subphrase', 'clause_atom'})
# Out:
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&amp;chapter=90&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Psalms 90:4">Psalms 90:4</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:494771</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:846351</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Conj</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:1110031</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">326259</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1KJ" title="Show this on SHEBANQ"><span class="txtu hbo">כִּ֤י </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>KJ</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:846352</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Subj</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:1110032</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">326260</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1ALPin" title="Show this on SHEBANQ"><span class="txtu hbo">אֶ֪לֶף </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>>LP=/</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">326261</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CNHn" title="Show this on SHEBANQ"><span class="txtu hbo">שָׁנִ֡ים </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>CNH/</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:846353</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Adju</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:1110033</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">326262</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="Show this on SHEBANQ"><span class="txtu hbo">בְּֽ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>B</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">326263</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1OJNn" title="Show this on SHEBANQ"><span class="txtu hbo">עֵינֶ֗יךָ </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>&lt;JN/</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:846354</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>PreC</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:1110034</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">326264</span> <a class=" txtu hbo" target="_blank" href=" ...
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&amp;chapter=90&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Psalms 90:4">Psalms 90:4</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:494772</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:846355</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Conj</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:1110035</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">326267</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1KJ" title="Show this on SHEBANQ"><span class="txtu hbo">כִּ֣י </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>KJ</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:846356</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Pred</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:1110036</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">326268</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1OBRv" title="Show this on SHEBANQ"><span class="txtu hbo">יַעֲבֹ֑ר </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>&lt;BR[</span></div></div></div></div></div></div></div></div></div>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&amp;chapter=90&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Psalms 90:4">Psalms 90:4</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:494773</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:846357</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Conj</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:1110037</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">326269</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="Show this on SHEBANQ"><span class="txtu hbo">וְ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>W</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:846358</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>PreC</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:1110038</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">326270</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1ACMWRHn" title="Show this on SHEBANQ"><span class="txtu hbo">אַשְׁמוּרָ֥ה </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>>CMWRH/</span></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:1110039</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">326271</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="Show this on SHEBANQ"><span class="txtu hbo">בַ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>B</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">326272</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="Show this on SHEBANQ"></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>H</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">326273</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1LJLHn" title="Show this on SHEBANQ"><span class="txtu hbo">לָּֽיְלָה׃ </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>LJLH/</span></div></div></div></div></div></div></div></div></div>

# %% [markdown]
# # Run Queries

# %%
query = '''

phrase function=PreO

'''

query = A.search(query, sets=pos2slot)
# Out:
#   0.33s 5402 results

# %%
A.show(query, end=200, condenseType='sentence', hiddenTypes={'subphrase', 'clause_atom'}, extraFeatures='rela st pdp lex typ function')
# Out:
# <p><b>result</b> <i>1</i></p>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=28&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 1:28">Genesis 1:28</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1172369</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">sentence_atom:1236096</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:427660</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>WIm0</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:651863</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Conj</span><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905091</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">568</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="Show this on SHEBANQ"><span class="txtu hbo">וְ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>W</span><span class="pdp xft" ><span class="f">pdp=</span>conj</span></div></div></div></div></div></div><div class="contnr c1  rtl  hl" ><div class="lbl c1  hl" ><span class="nd">phrase:651864</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>PreO</span><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905092</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">569</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1KBCv" title="Show this on SHEBANQ"><span class="txtu hbo">כִבְשֻׁ֑הָ </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>KBC[</span><span class="pdp xft" ><span class="f">pdp=</span>verb</span></div></div></div></div></div></div></div></div></div></div></div></div></div>
# <p><b>result</b> <i>2</i></p>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=2&amp;verse=15&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 2:15">Genesis 2:15</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1172412</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">sentence_atom:1236141</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:427730</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>Way0</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:652069</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Conj</span><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905301</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">952</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="Show this on SHEBANQ"><span class="txtu hbo">וַ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>W</span><span class="pdp xft" ><span class="f">pdp=</span>conj</span></div></div></div></div></div></div><div class="contnr c1  rtl  hl" ><div class="lbl c1  hl" ><span class="nd">phrase:652070</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>PreO</span><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905302</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">953</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1NWXv" title="Show this on SHEBANQ"><span class="txtu hbo">יַּנִּחֵ֣הוּ </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>NWX[</span><span class="pdp xft" ><span class="f">pdp=</span>verb</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:652071</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Cmpl</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905303</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">954</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="Show this on SHEBANQ"><span class="txtu hbo">בְ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>B</span><span class="pdp xft" ><span class="f">pdp=</span>prep</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">955</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1GNn" title="Show this on SHEBANQ"><span class="txtu hbo">גַן־</span></a></div><div class='features'><span class=" ...
# <p><b>result</b> <i>3</i></p>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=2&amp;verse=15&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 2:15">Genesis 2:15</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1172412</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">sentence_atom:1236141</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:427730</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>Way0</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:652069</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Conj</span><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905301</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">952</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="Show this on SHEBANQ"><span class="txtu hbo">וַ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>W</span><span class="pdp xft" ><span class="f">pdp=</span>conj</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:652070</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>PreO</span><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905302</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">953</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1NWXv" title="Show this on SHEBANQ"><span class="txtu hbo">יַּנִּחֵ֣הוּ </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>NWX[</span><span class="pdp xft" ><span class="f">pdp=</span>verb</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:652071</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Cmpl</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905303</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">954</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="Show this on SHEBANQ"><span class="txtu hbo">בְ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>B</span><span class="pdp xft" ><span class="f">pdp=</span>prep</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">955</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1GNn" title="Show this on SHEBANQ"><span class="txtu hbo">גַן־</span></a></div><div class='features'><span class="lex  ...
# <p><b>result</b> <i>4</i></p>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=2&amp;verse=15&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 2:15">Genesis 2:15</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1172412</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">sentence_atom:1236141</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:427730</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>Way0</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:652069</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Conj</span><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905301</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">952</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="Show this on SHEBANQ"><span class="txtu hbo">וַ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>W</span><span class="pdp xft" ><span class="f">pdp=</span>conj</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:652070</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>PreO</span><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905302</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">953</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1NWXv" title="Show this on SHEBANQ"><span class="txtu hbo">יַּנִּחֵ֣הוּ </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>NWX[</span><span class="pdp xft" ><span class="f">pdp=</span>verb</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:652071</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Cmpl</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905303</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">954</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="Show this on SHEBANQ"><span class="txtu hbo">בְ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>B</span><span class="pdp xft" ><span class="f">pdp=</span>prep</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">955</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1GNn" title="Show this on SHEBANQ"><span class="txtu hbo">גַן־</span></a></div><div class='features'><span class="lex  ...
# <p><b>result</b> <i>5</i></p>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=2&amp;verse=22&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 2:22">Genesis 2:22</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1172430</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">sentence_atom:1236159</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:427759</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>Way0</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:652158</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Conj</span><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905393</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1111</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="Show this on SHEBANQ"><span class="txtu hbo">וַ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>W</span><span class="pdp xft" ><span class="f">pdp=</span>conj</span></div></div></div></div></div></div><div class="contnr c1  rtl  hl" ><div class="lbl c1  hl" ><span class="nd">phrase:652159</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>PreO</span><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905394</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1112</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1BWAv" title="Show this on SHEBANQ"><span class="txtu hbo">יְבִאֶ֖הָ </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>BW>[</span><span class="pdp xft" ><span class="f">pdp=</span>verb</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:652160</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Cmpl</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905395</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1113</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1AL" title="Show this on SHEBANQ"><span class="txtu hbo">אֶל־</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>>L</span><span class="pdp xft" ><span class="f">pdp=</span>prep</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1114</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="Show this on SHEBANQ"><span class="txtu hbo">הָֽ</span></a></div><div class='features'><span class ...
# <p><b>result</b> <i>6</i></p>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=3&amp;verse=11&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 3:11">Genesis 3:11</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1172474</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">sentence_atom:1236204</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl l " ><div class="lbl c2  " ><span class="nd">clause:427818</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>xQt0</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:652332</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Ques</span><span class="typ xft" ><span class="f">typ=</span>InrP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905572</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>InrP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1378</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1Hi" title="Show this on SHEBANQ"><span class="txtu hbo">הֲ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>H=</span><span class="pdp xft" ><span class="f">pdp=</span>inrg</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:652333</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Cmpl</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905573</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1379</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1MN" title="Show this on SHEBANQ"><span class="txtu hbo">מִן־</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>MN</span><span class="pdp xft" ><span class="f">pdp=</span>prep</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1380</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="Show this on SHEBANQ"><span class="txtu hbo">הָ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>H</span><span class="pdp xft" ><span class="f">pdp=</span>art</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1381</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1OYn" title="Show this on SHEBANQ"><span class="txtu hbo">עֵ֗ץ </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>&lt;Y/</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>a</span></div></div></div></div></div></div></div></div><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:427819</span></div><div class='features'><span class="rela xft" ><span class="f">rela=</span>Attr</span><span class="typ xft" ><span class="f">typ=</span>xQt0</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lb ...
# <p><b>result</b> <i>7</i></p>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=3&amp;verse=13&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 3:13">Genesis 3:13</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1172480</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">sentence_atom:1236210</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:427829</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>XQtl</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:652361</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Subj</span><span class="typ xft" ><span class="f">typ=</span>NP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905601</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>NP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1420</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="Show this on SHEBANQ"><span class="txtu hbo">הַ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>H</span><span class="pdp xft" ><span class="f">pdp=</span>art</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1421</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1NXCn" title="Show this on SHEBANQ"><span class="txtu hbo">נָּחָ֥שׁ </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>NXC/</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>a</span></div></div></div></div></div></div><div class="contnr c1  rtl  hl" ><div class="lbl c1  hl" ><span class="nd">phrase:652362</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>PreO</span><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905602</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1422</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1NCAiv" title="Show this on SHEBANQ"><span class="txtu hbo">הִשִּׁיאַ֖נִי </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>NC>=[</span><span class="pdp xft" ><span class="f">pdp=</span>verb</span></div></div></div></div></div></div></div></div></div></div></div></div></div>
# <p><b>result</b> <i>8</i></p>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=3&amp;verse=15&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 3:15">Genesis 3:15</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1172488</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">sentence_atom:1236218</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:427837</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>XYqt</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:652385</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Subj</span><span class="typ xft" ><span class="f">typ=</span>PPrP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905625</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>PPrP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1470</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1HWA" title="Show this on SHEBANQ"><span class="txtu hbo">ה֚וּא </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>HW></span><span class="pdp xft" ><span class="f">pdp=</span>prps</span></div></div></div></div></div></div><div class="contnr c1  rtl  hl" ><div class="lbl c1  hl" ><span class="nd">phrase:652386</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>PreO</span><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905626</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1471</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CWPv" title="Show this on SHEBANQ"><span class="txtu hbo">יְשׁוּפְךָ֣ </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>CWP[</span><span class="pdp xft" ><span class="f">pdp=</span>verb</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:652387</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Objc</span><span class="typ xft" ><span class="f">typ=</span>NP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905627</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>NP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1472</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1RACn" title="Show this on SHEBANQ"><span class="txtu hbo">רֹ֔אשׁ </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>R>C/</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>a</span></div></div></div></div></div></div></div></div></div></div></div></div></div>
# <p><b>result</b> <i>9</i></p>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=3&amp;verse=15&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 3:15">Genesis 3:15</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1172489</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">sentence_atom:1236219</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:427838</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>WXYq</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:652388</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Conj</span><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905628</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1473</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="Show this on SHEBANQ"><span class="txtu hbo">וְ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>W</span><span class="pdp xft" ><span class="f">pdp=</span>conj</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:652389</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Subj</span><span class="typ xft" ><span class="f">typ=</span>PPrP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905629</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>PPrP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1474</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1ATH" title="Show this on SHEBANQ"><span class="txtu hbo">אַתָּ֖ה </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>>TH</span><span class="pdp xft" ><span class="f">pdp=</span>prps</span></div></div></div></div></div></div><div class="contnr c1  rtl  hl" ><div class="lbl c1  hl" ><span class="nd">phrase:652390</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>PreO</span><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905630</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1475</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CWPiv" title="Show this on SHEBANQ"><span class="txtu hbo">תְּשׁוּפֶ֥נּוּ </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>CWP=[</span><span class="pdp xft" ><span class="f">pdp=</span>verb</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:652391</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Objc</span><span class="typ xft" ><span class="f">typ=</span>NP</span></div><div cl ...
# <p><b>result</b> <i>10</i></p>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=3&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 3:17">Genesis 3:17</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1172497</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">sentence_atom:1236227</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:427846</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>Way0</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:652413</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Conj</span><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905653</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1507</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="Show this on SHEBANQ"><span class="txtu hbo">וַ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>W</span><span class="pdp xft" ><span class="f">pdp=</span>conj</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:652414</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Pred</span><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905654</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1508</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1AKLv" title="Show this on SHEBANQ"><span class="txtu hbo">תֹּ֨אכַל֙ </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>>KL[</span><span class="pdp xft" ><span class="f">pdp=</span>verb</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:652415</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Cmpl</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905655</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1509</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1MN" title="Show this on SHEBANQ"><span class="txtu hbo">מִן־</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>MN</span><span class="pdp xft" ><span class="f">pdp=</span>prep</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1510</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="Show this on SHEBANQ"><span class="txtu hbo">הָ</span></a></div><div class='features'><span class="lex ...
# <p><b>result</b> <i>11</i></p>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=3&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 3:17">Genesis 3:17</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1172500</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">sentence_atom:1236230</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:427851</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>xYq0</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:652425</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Adju</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905665</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1524</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="Show this on SHEBANQ"><span class="txtu hbo">בְּ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>B</span><span class="pdp xft" ><span class="f">pdp=</span>prep</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1525</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1OYBWNn" title="Show this on SHEBANQ"><span class="txtu hbo">עִצָּבֹון֙ </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>&lt;YBWN/</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>a</span></div></div></div></div></div></div><div class="contnr c1  rtl  hl" ><div class="lbl c1  hl" ><span class="nd">phrase:652426</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>PreO</span><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905666</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1526</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1AKLv" title="Show this on SHEBANQ"><span class="txtu hbo">תֹּֽאכֲלֶ֔נָּה </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>>KL[</span><span class="pdp xft" ><span class="f">pdp=</span>verb</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:652427</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Time</span><span class="typ xft" ><span class="f">typ=</span>NP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905667</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>NP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1527</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1KLn" title="Show this on SHE ...
# <p><b>result</b> <i>12</i></p>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=3&amp;verse=21&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 3:21">Genesis 3:21</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1172510</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">sentence_atom:1236240</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:427862</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>Way0</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:652463</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Conj</span><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905703</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1586</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="Show this on SHEBANQ"><span class="txtu hbo">וַ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>W</span><span class="pdp xft" ><span class="f">pdp=</span>conj</span></div></div></div></div></div></div><div class="contnr c1  rtl  hl" ><div class="lbl c1  hl" ><span class="nd">phrase:652464</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>PreO</span><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905704</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">1587</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1LBCv" title="Show this on SHEBANQ"><span class="txtu hbo">יַּלְבִּשֵֽׁם׃ פ </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>LBC[</span><span class="pdp xft" ><span class="f">pdp=</span>verb</span></div></div></div></div></div></div></div></div></div></div></div></div></div>
# <p><b>result</b> <i>13</i></p>
# ...
# <p><b>result</b> <i>97</i></p>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=25&amp;verse=6&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 25:6">Genesis 25:6</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1174128</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">sentence_atom:1237871</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl l " ><div class="lbl c2  " ><span class="nd">clause:429977</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>Way0</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:658928</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Conj</span><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:912477</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">12507</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="Show this on SHEBANQ"><span class="txtu hbo">וַֽ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>W</span><span class="pdp xft" ><span class="f">pdp=</span>conj</span></div></div></div></div></div></div><div class="contnr c1  rtl  hl" ><div class="lbl c1  hl" ><span class="nd">phrase:658929</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>PreO</span><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:912478</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">12508</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CLXv" title="Show this on SHEBANQ"><span class="txtu hbo">יְשַׁלְּחֵ֞ם </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>CLX[</span><span class="pdp xft" ><span class="f">pdp=</span>verb</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:658930</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Cmpl</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:912479</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">12509</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1MN" title="Show this on SHEBANQ"><span class="txtu hbo">מֵ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>MN</span><span class="pdp xft" ><span class="f">pdp=</span>prep</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">12510</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1OL" title="Show this on SHEBANQ"><span class="txtu hbo">עַ֨ל </span></a></div><div class='features'>< ...
# <p><b>result</b> <i>98</i></p>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=25&amp;verse=30&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 25:30">Genesis 25:30</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1174187</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">sentence_atom:1237930</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:430055</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>ZIm0</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  hl" ><div class="lbl c1  hl" ><span class="nd">phrase:659157</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>PreO</span><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:912728</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">12897</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1LOVv" title="Show this on SHEBANQ"><span class="txtu hbo">הַלְעִיטֵ֤נִי </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>L&lt;V[</span><span class="pdp xft" ><span class="f">pdp=</span>verb</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:659158</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Intj</span><span class="typ xft" ><span class="f">typ=</span>InjP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:912729</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>InjP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">12898</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1NA" title="Show this on SHEBANQ"><span class="txtu hbo">נָא֙ </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>N></span><span class="pdp xft" ><span class="f">pdp=</span>intj</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:659159</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Cmpl</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:912730</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">12899</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1MN" title="Show this on SHEBANQ"><span class="txtu hbo">מִן־</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>MN</span><span class="pdp xft" ><span class="f">pdp=</span>prep</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">12900</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="Show this on SHEBANQ"><span class="txtu hbo">הָ</span></a></div><div class= ...
# <p><b>result</b> <i>99</i></p>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=26&amp;verse=3&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 26:3">Genesis 26:3</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1174213</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">sentence_atom:1237956</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:430084</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>WYq0</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:659247</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Conj</span><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:912820</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">13028</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="Show this on SHEBANQ"><span class="txtu hbo">וַ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>W</span><span class="pdp xft" ><span class="f">pdp=</span>conj</span></div></div></div></div></div></div><div class="contnr c1  rtl  hl" ><div class="lbl c1  hl" ><span class="nd">phrase:659248</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>PreO</span><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:912821</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">13029</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1BRKv" title="Show this on SHEBANQ"><span class="txtu hbo">אֲבָרְכֶ֑ךָּ </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>BRK[</span><span class="pdp xft" ><span class="f">pdp=</span>verb</span></div></div></div></div></div></div></div></div></div></div></div></div></div>
# <p><b>result</b> <i>100</i></p>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=26&amp;verse=7&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 26:7">Genesis 26:7</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1174227</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">sentence_atom:1237970</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:430100</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>xYqX</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:659294</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Conj</span><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:912868</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">13112</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1PN" title="Show this on SHEBANQ"><span class="txtu hbo">פֶּן־</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>PN</span><span class="pdp xft" ><span class="f">pdp=</span>conj</span></div></div></div></div></div></div><div class="contnr c1  rtl  hl" ><div class="lbl c1  hl" ><span class="nd">phrase:659295</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>PreO</span><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:912869</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">13113</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1HRGv" title="Show this on SHEBANQ"><span class="txtu hbo">יַֽהַרְגֻ֜נִי </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>HRG[</span><span class="pdp xft" ><span class="f">pdp=</span>verb</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:659296</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Subj</span><span class="typ xft" ><span class="f">typ=</span>NP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:912870</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>NP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">13114</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1AJCn" title="Show this on SHEBANQ"><span class="txtu hbo">אַנְשֵׁ֤י </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>>JC/</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>c</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">13115</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="Show this on SHEBAN ...
# <b>100 more results skipped</b> because we show a maximum of 100 results at a time

# %%
def format_edge(src, tgt, rela, note=''):
    """Format JSON-like entry for edge relations used by project."""
    return (
        f'"{src}": {{\n'
        f'    "edge": [[{tgt}], "{rela}"],\n'
        f'    "note": "{note}"\n'
        '}'
    )

def form_edges(results, src_i, tgt_i, rela, note=''):
    """Format copy-pastable JSON entries for edge relas."""
    edges = []
    for r in results:
        src, tgt = r[src_i], r[tgt_i]
        edges.append(format_edge(src, tgt, rela, note=note))
    return ',\n'.join(edges)

# %%
print(form_edges(query, 4, 1, 'SPEC', note='Normalize to other cases; draw Spec to other ב-headed phrase atom instead of word'))
# Out:
# "950423": {
#     "edge": [[950422], "SPEC"],
#     "note": "Normalize to other cases; draw Spec to other ב-headed phrase atom instead of word"
# },
# "950441": {
#     "edge": [[950440], "SPEC"],
#     "note": "Normalize to other cases; draw Spec to other ב-headed phrase atom instead of word"
# },
# "966230": {
#     "edge": [[966229], "SPEC"],
#     "note": "Normalize to other cases; draw Spec to other ב-headed phrase atom instead of word"
# },
# "1018760": {
#     "edge": [[1018759], "SPEC"],
#     "note": "Normalize to other cases; draw Spec to other ב-headed phrase atom instead of word"
# },
# "1018761": {
#     "edge": [[1018760], "SPEC"],
#     "note": "Normalize to other cases; draw Spec to other ב-headed phrase atom instead of word"
# },
# "1034479": {
#     "edge": [[1034478], "SPEC"],
#     "note": "Normalize to other cases; draw Spec to other ב-headed phrase atom instead of word"
# },
# "1034568": {
#     "edge": [[1034567], "SPEC"],
#     "note": "Normalize to other cases; draw Spec to other ב-headed phrase atom instead of word"
# },
# "1034832": {
#     "edge": [[1034831], "SPEC"],
#     "note": "Normalize to other cases; draw Spec to other ב-headed phrase atom instead of word"
# },
# "1112864": {
#     "edge": [[1112863], "SPEC"],
#     "note": "Normalize to other cases; draw Spec to other ב-headed phrase atom instead of word"
# },
# "1138929": {
#     "edge": [[1138928], "SPEC"],
#     "note": "Normalize to other cases; draw Spec to other ב-headed phrase atom instead of word"
# }

# %%
T.sectionFromNode(1024006)
# Out:
# ('1_Kings', 22, 52)

# %% [markdown]
# ## Investigate Accent Separators

# %%
import json

# %%
with open('../../results/disambigs/accentseps.json', 'r') as infile:
    accentseps = json.load(infile)

# %%
len(accentseps)
# Out:
# 682

# %%
# for w in accentseps[:100]:
#     ph = L.u(w, 'phrase_atom')
#     A.prettyTuple(ph, seq=0, condenseType='phrase', highlights={w})
