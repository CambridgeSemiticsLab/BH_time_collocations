# %%
from tf.app import use
A = use('bhsa', hoist=globals())
A.displaySetup(condenseType='clause', withNodes=True, extraFeatures='pdp st')

import sys
import collections
sys.path.append('../scripts/tools/')
from load_parse import ParseLoader

slot2pos = ParseLoader('../../results/parsing/slot2pos.json').load()
pos2slot = collections.defaultdict(set)
for slot, pos in slot2pos.items():
    pos2slot[pos].add(slot)
# Out:
# <b title="local commit">TF-app:</b> <span title="#113c0687cfce3077734dac1844d244d20f4ace6f offline under ~/text-fabric-data">~/text-fabric-data/annotation/app-bhsa/code</span>
# <b title="local release">data:</b> <span title="rv1.6 offline under ~/text-fabric-data">~/text-fabric-data/etcbc/bhsa/tf/c</span>
# <b title="local release">data:</b> <span title="r1.2 offline under ~/text-fabric-data">~/text-fabric-data/etcbc/phono/tf/c</span>
# <b title="local release">data:</b> <span title="r1.2 offline under ~/text-fabric-data">~/text-fabric-data/etcbc/parallels/tf/c</span>
# <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 8.4.14</a>, <a target="_blank" href="https://github.com/annotation/app-bhsa" title="bhsa TF-app">app-bhsa v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br><b>Data:</b> <a target="_blank" href="https://etcbc.github.io/bhsa/0_home" title="provenance of BHSA = Biblia Hebraica Stuttgartensia Amstelodamensis">BHSA</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/hebrew.html" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://etcbc.github.io/bhsa/features/0_home" title="BHSA feature documentation">Feature docs</a><br><b>Features:</b><br><details><summary><b>Parallel Passages</b></summary><b><i><a target="_blank" href="https://nbviewer.jupyter.org/github/etcbc/parallels/blob/master/programs/parallels.ipynb" title="~/text-fabric-data/etcbc/parallels/tf/c/crossref.tf">crossref</a></i></b><br></details><details><summary><b>BHSA = Biblia Hebraica Stuttgartensia Amstelodamensis</b></summary><a target="_blank" href="https://etcbc.github.io/bhsa/features/book" title="~/text-fabric-data/etcbc/bhsa/tf/c/book.tf">book</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/book@ll" title="~/text-fabric-data/etcbc/bhsa/tf/c/book@am.tf">book@ll</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/chapter" title="~/text-fabric-data/etcbc/bhsa/tf/c/chapter.tf">chapter</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/code" title="~/text-fabric-data/etcbc/bhsa/tf/c/code.tf">code</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/det" title="~/text-fabric-data/etcbc/bhsa/tf/c/det.tf">det</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/domain" title="~/text-fabric-data/etcbc/bhsa/tf/c/domain.tf">domain</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/freq_lex" title="~/text-fabric-data/etcbc/bhsa/tf/c/freq_lex.tf">freq_lex</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/function" title="~/text-fabric-data/etcbc/bhsa/tf/c/function.tf">function</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/g_cons" title="~/text-fabric-data/etcbc/bhsa/tf/c/g_cons.tf">g_cons</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/g_cons_utf8" title="~/text-fabric-data/etcbc/bhsa/tf/c/g_cons_utf8.tf">g_cons_utf8</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/g_lex" title="~/text-fabric-data/etcbc/bhsa/tf/c/g_lex.tf">g_lex</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/g_lex_utf8" title="~/text-fabric-data/etcbc/bhsa/tf/c/g_lex_utf8.tf">g_lex_utf8</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/g_word" title="~/text-fabric-data/etcbc/bhsa/tf/c/g_word.tf">g_word</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/g_word_utf8" title="~/text-fabric-data/etcbc/bhsa/tf/c/g_word_utf8.tf">g_word_utf8</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/gloss" title="~/text-fabric-data/etcbc/bhsa/tf/c/gloss.tf">gloss</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/gn" title="~/text-fabric-data/etcbc/bhsa/tf/c/gn.tf">gn</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/label" title="~/text-fabric-data/etcbc/bhsa/tf/c/label.tf">label</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/language" title="~/text-fabric-data/etcbc/bhsa/tf/c/language.tf">language</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/lex" title="~/text-fabric-data/etcbc/bhsa/tf/c/lex.tf">lex</a><br><a target="_blank" href="https://etcbc.github.io/bhsa/features/lex_utf8" title="~/text-fabric-data/etcbc/bhsa/tf/c/lex_utf ...
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-
# <div><b>Text-Fabric API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF</a> directly usable</div><hr>

# %%
for phrase_atom in L.d(428158, 'phrase_atom'):
    print(phrase_atom, E.mother.f(phrase_atom))
# Out:
# 906675 ()
# 906676 (906675,)
# 906677 ()
# 906678 ()
# 906679 (906678,)
# 906680 ()
# 906681 ()
# 906682 ()

# %%
A.pretty(651894, extraFeatures='function pdp', hiddenTypes=['subphrase'])
# Out:
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=30&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 1:30">Genesis 1:30</a></div><div class="rtl children"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:651894</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Subj</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:905125</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">643</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1NPCn" title="Show this on SHEBANQ"><span class="txtu hbo">נֶ֣פֶשׁ </span></a></div><div class='features'><span class="pdp xft" ><span class="f">pdp=</span>subs</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">644</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1XJn" title="Show this on SHEBANQ"><span class="txtu hbo">חַיָּ֔ה </span></a></div><div class='features'><span class="pdp xft" ><span class="f">pdp=</span>adjv</span></div></div></div></div></div></div></div>

# %%
len(F.otype.s('clause'))
# Out:
# 88121

# %% [markdown]
# # Lookup Passages

# %%
passage = ('Psalms', 90, 4)
verse = T.nodeFromSection(passage)
for cl in L.d(verse, 'clause'):
    A.pretty(cl, extraFeatures='function', hiddenTypes={'subphrase', 'clause_atom'})
# Out:
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&amp;chapter=90&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Psalms 90:4">Psalms 90:4</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:494771</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:846351</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Conj</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:1110031</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">326259</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1KJ" title="Show this on SHEBANQ"><span class="txtu hbo">כִּ֤י </span></a></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:846352</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Subj</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:1110032</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">326260</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1ALPin" title="Show this on SHEBANQ"><span class="txtu hbo">אֶ֪לֶף </span></a></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">326261</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CNHn" title="Show this on SHEBANQ"><span class="txtu hbo">שָׁנִ֡ים </span></a></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:846353</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Adju</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:1110033</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">326262</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="Show this on SHEBANQ"><span class="txtu hbo">בְּֽ</span></a></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">326263</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1OJNn" title="Show this on SHEBANQ"><span class="txtu hbo">עֵינֶ֗יךָ </span></a></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:846354</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>PreC</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:1110034</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">326264</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1K" title="Show this on SHEBANQ"><span class="txtu hbo">כְּ</span></a></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">326265</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1JWMn" title="Show this on SHEBANQ"><span class="txtu hbo">יֹ֣ום </span></a></div></div><div class="cont ...
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&amp;chapter=90&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Psalms 90:4">Psalms 90:4</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:494772</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:846355</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Conj</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:1110035</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">326267</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1KJ" title="Show this on SHEBANQ"><span class="txtu hbo">כִּ֣י </span></a></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:846356</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Pred</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:1110036</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">326268</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1OBRv" title="Show this on SHEBANQ"><span class="txtu hbo">יַעֲבֹ֑ר </span></a></div></div></div></div></div></div></div></div></div>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&amp;chapter=90&amp;verse=4&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Psalms 90:4">Psalms 90:4</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:494773</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:846357</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Conj</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:1110037</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">326269</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="Show this on SHEBANQ"><span class="txtu hbo">וְ</span></a></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:846358</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>PreC</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:1110038</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">326270</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1ACMWRHn" title="Show this on SHEBANQ"><span class="txtu hbo">אַשְׁמוּרָ֥ה </span></a></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:1110039</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">326271</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="Show this on SHEBANQ"><span class="txtu hbo">בַ</span></a></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">326272</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="Show this on SHEBANQ"></a></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">326273</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1LJLHn" title="Show this on SHEBANQ"><span class="txtu hbo">לָּֽיְלָה׃ </span></a></div></div></div></div></div></div></div></div></div>

# %% [markdown]
# # Run Queries

# %%
query = '''

phrase function=Time
    word lex=B
    <: word lex=KL/
    <: word lex=H
        
'''

query = A.search(query, sets=pos2slot)
# Out:
#   1.54s 0 results

# %%
A.show(query, end=200, condenseType='sentence', hiddenTypes={'subphrase', 'clause_atom'}, extraFeatures='rela st pdp lex typ function')
# Out:
# <p><b>result</b> <i>1</i></p>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=7&amp;verse=11&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 7:11">Genesis 7:11</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1172737</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">sentence_atom:1236467</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:428158</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>xQtX</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  hl" ><div class="lbl c1  hl" ><span class="nd">phrase:653401</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Time</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:906675</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  hl" ><div class="lbl c0 trm hl" ><span class="nd">3228</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="Show this on SHEBANQ"><span class="txtu hbo">בִּ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>B</span><span class="pdp xft" ><span class="f">pdp=</span>prep</span></div></div><div class="contnr c0 trm rtl  hl" ><div class="lbl c0 trm hl" ><span class="nd">3229</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CNHn" title="Show this on SHEBANQ"><span class="txtu hbo">שְׁנַ֨ת </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>CNH/</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>c</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">3230</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CCn" title="Show this on SHEBANQ"><span class="txtu hbo">שֵׁשׁ־</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>CC/</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>c</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">3231</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1MAHn" title="Show this on SHEBANQ"><span class="txtu hbo">מֵאֹ֤ות </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>M>H/</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>a</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">3232</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CNHn" title="Show this on SHEBANQ"><span class="txtu hbo">שָׁנָה֙ </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>CNH/</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>a</span></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:906676</span></div><div class='features'><span class="rela xft" ><span class="f">rela=</span>Spec</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class=" ...
# <p><b>result</b> <i>2</i></p>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=7&amp;verse=11&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 7:11">Genesis 7:11</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1172737</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">sentence_atom:1236467</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:428158</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>xQtX</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  hl" ><div class="lbl c1  hl" ><span class="nd">phrase:653401</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Time</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:906675</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  hl" ><div class="lbl c0 trm hl" ><span class="nd">3228</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="Show this on SHEBANQ"><span class="txtu hbo">בִּ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>B</span><span class="pdp xft" ><span class="f">pdp=</span>prep</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">3229</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CNHn" title="Show this on SHEBANQ"><span class="txtu hbo">שְׁנַ֨ת </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>CNH/</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>c</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">3230</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CCn" title="Show this on SHEBANQ"><span class="txtu hbo">שֵׁשׁ־</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>CC/</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>c</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">3231</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1MAHn" title="Show this on SHEBANQ"><span class="txtu hbo">מֵאֹ֤ות </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>M>H/</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>a</span></div></div><div class="contnr c0 trm rtl  hl" ><div class="lbl c0 trm hl" ><span class="nd">3232</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CNHn" title="Show this on SHEBANQ"><span class="txtu hbo">שָׁנָה֙ </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>CNH/</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>a</span></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:906676</span></div><div class='features'><span class="rela xft" ><span class="f">rela=</span>Spec</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class=" ...
# <p><b>result</b> <i>3</i></p>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=8&amp;verse=13&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 8:13">Genesis 8:13</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1172791</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">sentence_atom:1236521</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:428232</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>xQtX</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  hl" ><div class="lbl c1  hl" ><span class="nd">phrase:653659</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Time</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:906959</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  hl" ><div class="lbl c0 trm hl" ><span class="nd">3799</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="Show this on SHEBANQ"><span class="txtu hbo">בְּ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>B</span><span class="pdp xft" ><span class="f">pdp=</span>prep</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">3800</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1AXDn" title="Show this on SHEBANQ"><span class="txtu hbo">אַחַ֨ת </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>>XD/</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>a</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">3801</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="Show this on SHEBANQ"><span class="txtu hbo">וְ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>W</span><span class="pdp xft" ><span class="f">pdp=</span>conj</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">3802</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CCn" title="Show this on SHEBANQ"><span class="txtu hbo">שֵׁשׁ־</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>CC/</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>c</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">3803</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1MAHn" title="Show this on SHEBANQ"><span class="txtu hbo">מֵאֹ֜ות </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>M>H/</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>a</span></div></div><div class="contnr c0 trm rtl  hl" ><div class="lbl c0 trm hl" ><span class="nd">3804</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CNHn" title="Show this on SHEBANQ"><span class="txtu hbo">שָׁנָ֗ה </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</ ...
# <p><b>result</b> <i>4</i></p>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=14&amp;verse=5&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 14:5">Genesis 14:5</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1173109</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">sentence_atom:1236841</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:428653</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>WxQX</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:654984</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Conj</span><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:908361</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">6274</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="Show this on SHEBANQ"><span class="txtu hbo">וּ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>W</span><span class="pdp xft" ><span class="f">pdp=</span>conj</span></div></div></div></div></div></div><div class="contnr c1  rtl  hl" ><div class="lbl c1  hl" ><span class="nd">phrase:654985</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Time</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:908362</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  hl" ><div class="lbl c0 trm hl" ><span class="nd">6275</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="Show this on SHEBANQ"><span class="txtu hbo">בְ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>B</span><span class="pdp xft" ><span class="f">pdp=</span>prep</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">6276</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1ARBOn" title="Show this on SHEBANQ"><span class="txtu hbo">אַרְבַּע֩ </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>>RB&lt;/</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>c</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">6277</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1OFRHn" title="Show this on SHEBANQ"><span class="txtu hbo">עֶשְׂרֵ֨ה </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>&lt;FRH/</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>a</span></div></div><div class="contnr c0 trm rtl  hl" ><div class="lbl c0 trm hl" ><span class="nd">6278</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CNHn" title="Show this on SHEBANQ"><span class="txtu hbo">שָׁנָ֜ה </span></a></div>< ...
# <p><b>result</b> <i>5</i></p>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=17&amp;verse=21&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 17:21">Genesis 17:21</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1173319</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">sentence_atom:1237052</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:428931</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>WxY0</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:655835</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Conj</span><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:909272</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">7683</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="Show this on SHEBANQ"><span class="txtu hbo">וְ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>W</span><span class="pdp xft" ><span class="f">pdp=</span>conj</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:655836</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Objc</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:909273</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">7684</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1AT" title="Show this on SHEBANQ"><span class="txtu hbo">אֶת־</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>>T</span><span class="pdp xft" ><span class="f">pdp=</span>prep</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">7685</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1BRJTn" title="Show this on SHEBANQ"><span class="txtu hbo">בְּרִיתִ֖י </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>BRJT/</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>a</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:655837</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Pred</span><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:909274</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">7686</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1QWMv" title="Show this on SHEBANQ"><span class="tx ...
# <p><b>result</b> <i>6</i></p>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=26&amp;verse=12&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 26:12">Genesis 26:12</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1174249</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">sentence_atom:1237992</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:430124</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>Way0</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:659371</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Conj</span><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:912947</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">13221</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="Show this on SHEBANQ"><span class="txtu hbo">וַ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>W</span><span class="pdp xft" ><span class="f">pdp=</span>conj</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:659372</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Pred</span><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:912948</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">13222</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1MYAv" title="Show this on SHEBANQ"><span class="txtu hbo">יִּמְצָ֛א </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>MY>[</span><span class="pdp xft" ><span class="f">pdp=</span>verb</span></div></div></div></div></div></div><div class="contnr c1  rtl  hl" ><div class="lbl c1  hl" ><span class="nd">phrase:659373</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Time</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:912949</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  hl" ><div class="lbl c0 trm hl" ><span class="nd">13223</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="Show this on SHEBANQ"><span class="txtu hbo">בַּ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>B</span><span class="pdp xft" ><span class="f">pdp=</span>prep</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">13224</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="Show this on SHEBANQ"></a></div><div class='features'><span class="lex xft" ><span class=" ...
# <p><b>result</b> <i>7</i></p>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=41&amp;verse=34&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 41:34">Genesis 41:34</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1175940</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">sentence_atom:1239692</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:432258</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>WQt0</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:665749</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Conj</span><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:919617</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">22966</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="Show this on SHEBANQ"><span class="txtu hbo">וְ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>W</span><span class="pdp xft" ><span class="f">pdp=</span>conj</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:665750</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Pred</span><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:919618</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">22967</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1XMCv" title="Show this on SHEBANQ"><span class="txtu hbo">חִמֵּשׁ֙ </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>XMC[</span><span class="pdp xft" ><span class="f">pdp=</span>verb</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:665751</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Objc</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:919619</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">22968</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1AT" title="Show this on SHEBANQ"><span class="txtu hbo">אֶת־</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>>T</span><span class="pdp xft" ><span class="f">pdp=</span>prep</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">22969</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1ARYn" title="Show this on SHEBANQ"><span class="txtu hbo">אֶ֣רֶץ </span></a></div><div class='features'><s ...
# <p><b>result</b> <i>8</i></p>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=41&amp;verse=47&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 41:47">Genesis 41:47</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1175975</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">sentence_atom:1239727</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:432298</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>WayX</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:665891</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Conj</span><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:919763</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">23214</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="Show this on SHEBANQ"><span class="txtu hbo">וַ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>W</span><span class="pdp xft" ><span class="f">pdp=</span>conj</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:665892</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Pred</span><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:919764</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">23215</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1OFHv" title="Show this on SHEBANQ"><span class="txtu hbo">תַּ֣עַשׂ </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>&lt;FH[</span><span class="pdp xft" ><span class="f">pdp=</span>verb</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:665893</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Subj</span><span class="typ xft" ><span class="f">typ=</span>NP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:919765</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>NP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">23216</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="Show this on SHEBANQ"><span class="txtu hbo">הָ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>H</span><span class="pdp xft" ><span class="f">pdp=</span>art</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">23217</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1ARYn" title="Show this on SHEBANQ"><span class="txtu hbo">אָ֔רֶץ </span></a></div><div class='features'><spa ...
# <p><b>result</b> <i>9</i></p>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=47&amp;verse=17&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 47:17">Genesis 47:17</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1176612</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">sentence_atom:1240364</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:433140</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>Way0</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:668352</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Conj</span><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:922305</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">26929</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="Show this on SHEBANQ"><span class="txtu hbo">וַ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>W</span><span class="pdp xft" ><span class="f">pdp=</span>conj</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:668353</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>PreO</span><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:922306</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">26930</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1NHLv" title="Show this on SHEBANQ"><span class="txtu hbo">יְנַהֲלֵ֤ם </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>NHL[</span><span class="pdp xft" ><span class="f">pdp=</span>verb</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:668354</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Cmpl</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:922307</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">26931</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="Show this on SHEBANQ"><span class="txtu hbo">בַּ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>B</span><span class="pdp xft" ><span class="f">pdp=</span>prep</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">26932</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="Show this on SHEBANQ"></a></div><div class='features'><span class="lex xft" ><span class="f">lex= ...
# <p><b>result</b> <i>10</i></p>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=47&amp;verse=18&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 47:18">Genesis 47:18</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1176614</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">sentence_atom:1240366</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:433142</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>Way0</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:668360</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Conj</span><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:922313</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">26948</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="Show this on SHEBANQ"><span class="txtu hbo">וַ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>W</span><span class="pdp xft" ><span class="f">pdp=</span>conj</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:668361</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Pred</span><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:922314</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">26949</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1BWAv" title="Show this on SHEBANQ"><span class="txtu hbo">יָּבֹ֨אוּ </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>BW>[</span><span class="pdp xft" ><span class="f">pdp=</span>verb</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:668362</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Cmpl</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:922315</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">26950</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1AL" title="Show this on SHEBANQ"><span class="txtu hbo">אֵלָ֜יו </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>>L</span><span class="pdp xft" ><span class="f">pdp=</span>prep</span></div></div></div></div></div></div><div class="contnr c1  rtl  hl" ><div class="lbl c1  hl" ><span class="nd">phrase:668363</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Time</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="ch ...
# <p><b>result</b> <i>11</i></p>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=23&amp;verse=14&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Exodus 23:14">Exodus 23:14</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1178875</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">sentence_atom:1242640</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:436053</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>xYq0</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:677177</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Modi</span><span class="typ xft" ><span class="f">typ=</span>NP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:931370</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>NP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">41245</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CLCn" title="Show this on SHEBANQ"><span class="txtu hbo">שָׁלֹ֣שׁ </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>CLC/</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>a</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">41246</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1RGLn" title="Show this on SHEBANQ"><span class="txtu hbo">רְגָלִ֔ים </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>RGL/</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>a</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:677178</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Pred</span><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:931371</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">41247</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1XGGv" title="Show this on SHEBANQ"><span class="txtu hbo">תָּחֹ֥ג </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>XGG[</span><span class="pdp xft" ><span class="f">pdp=</span>verb</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:677179</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Cmpl</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:931372</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">41248</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebre ...
# <p><b>result</b> <i>12</i></p>
# ...
# <p><b>result</b> <i>98</i></p>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_II&amp;chapter=15&amp;verse=27&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="2_Kings 15:27">2_Kings 15:27</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1201006</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">sentence_atom:1264971</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:466909</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>xQtX</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  hl" ><div class="lbl c1  hl" ><span class="nd">phrase:770292</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Time</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:1030627</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  hl" ><div class="lbl c0 trm hl" ><span class="nd">204796</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="Show this on SHEBANQ"><span class="txtu hbo">בִּ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>B</span><span class="pdp xft" ><span class="f">pdp=</span>prep</span></div></div><div class="contnr c0 trm rtl  hl" ><div class="lbl c0 trm hl" ><span class="nd">204797</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CNHn" title="Show this on SHEBANQ"><span class="txtu hbo">שְׁנַ֨ת </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>CNH/</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>c</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">204798</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1XMCn" title="Show this on SHEBANQ"><span class="txtu hbo">חֲמִשִּׁ֤ים </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>XMC/</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>a</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">204799</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="Show this on SHEBANQ"><span class="txtu hbo">וּ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>W</span><span class="pdp xft" ><span class="f">pdp=</span>conj</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">204800</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CNJMn" title="Show this on SHEBANQ"><span class="txtu hbo">שְׁתַּ֨יִם֙ </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>CNJM/</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>a</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">204801</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CNHn" title="Show this on SHEBANQ"><span class="txtu hbo">שָׁנָ֔ה </span></a></div><div class='features'><span class=" ...
# <p><b>result</b> <i>99</i></p>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_II&amp;chapter=15&amp;verse=27&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="2_Kings 15:27">2_Kings 15:27</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1201006</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">sentence_atom:1264971</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:466909</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>xQtX</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  hl" ><div class="lbl c1  hl" ><span class="nd">phrase:770292</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Time</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:1030627</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  hl" ><div class="lbl c0 trm hl" ><span class="nd">204796</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="Show this on SHEBANQ"><span class="txtu hbo">בִּ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>B</span><span class="pdp xft" ><span class="f">pdp=</span>prep</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">204797</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CNHn" title="Show this on SHEBANQ"><span class="txtu hbo">שְׁנַ֨ת </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>CNH/</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>c</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">204798</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1XMCn" title="Show this on SHEBANQ"><span class="txtu hbo">חֲמִשִּׁ֤ים </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>XMC/</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>a</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">204799</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="Show this on SHEBANQ"><span class="txtu hbo">וּ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>W</span><span class="pdp xft" ><span class="f">pdp=</span>conj</span></div></div><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">204800</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CNJMn" title="Show this on SHEBANQ"><span class="txtu hbo">שְׁתַּ֨יִם֙ </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>CNJM/</span><span class="pdp xft" ><span class="f">pdp=</span>subs</span><span class="st xft" ><span class="f">st=</span>a</span></div></div><div class="contnr c0 trm rtl  hl" ><div class="lbl c0 trm hl" ><span class="nd">204801</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CNHn" title="Show this on SHEBANQ"><span class="txtu hbo">שָׁנָ֔ה </span></a></div><div class='features'><span class=" ...
# <p><b>result</b> <i>100</i></p>
# <div class="tfsechead rtl"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_II&amp;chapter=15&amp;verse=30&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="2_Kings 15:30">2_Kings 15:30</a></div><div class="rtl children"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">sentence:1201015</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">sentence_atom:1264980</span></div><div class="children hor wrap rtl"><div class="contnr c2  rtl  " ><div class="lbl c2  " ><span class="nd">clause:466920</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>Way0</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:770327</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Conj</span><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:1030671</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>CP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">204887</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="Show this on SHEBANQ"><span class="txtu hbo">וַ</span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>W</span><span class="pdp xft" ><span class="f">pdp=</span>conj</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:770328</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Pred</span><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:1030672</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">204888</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1MLKv" title="Show this on SHEBANQ"><span class="txtu hbo">יִּמְלֹ֖ךְ </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>MLK[</span><span class="pdp xft" ><span class="f">pdp=</span>verb</span></div></div></div></div></div></div><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase:770329</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Adju</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c1  rtl  " ><div class="lbl c1  " ><span class="nd">phrase_atom:1030673</span></div><div class='features'><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap rtl"><div class="contnr c0 trm rtl  " ><div class="lbl c0 trm " ><span class="nd">204889</span> <a class=" txtu hbo" target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1TXTn" title="Show this on SHEBANQ"><span class="txtu hbo">תַּחְתָּ֑יו </span></a></div><div class='features'><span class="lex xft" ><span class="f">lex=</span>TXT/</span><span class="pdp xft" ><span class="f">pdp=</span>prep</span><span class="st xft" ><span class="f">st=</span>a</span></div></div></div></div></div></div><div class="contnr c1  rtl  hl" ><div class="lbl c1  hl" ><span class="nd">phrase:770330</span></div><div class='features'><span class="function xft" ><span class="f">function=</span>Time</span><span c ...
# <b>100 more results skipped</b> because we show a maximum of 100 results at a time

# %%
def format_edge(src, tgt, rela, note=''):
    """Format JSON-like entry for edge relations used by project."""
    return (
        f'"{src}": {{\n'
        f'    "edge": [[{tgt}], "{rela}"],\n'
        f'    "note": "{note}"\n'
        '}'
    )

def form_edges(results, src_i, tgt_i, rela, note=''):
    """Format copy-pastable JSON entries for edge relas."""
    edges = []
    for r in results:
        src, tgt = r[src_i], r[tgt_i]
        edges.append(format_edge(src, tgt, rela, note=note))
    return ',\n'.join(edges)

# %%
print(form_edges(query, 4, 1, 'SPEC', note='Normalize to other cases; draw Spec to other ב-headed phrase atom instead of word'))
# Out:
# "950423": {
#     "edge": [[950422], "SPEC"],
#     "note": "Normalize to other cases; draw Spec to other ב-headed phrase atom instead of word"
# },
# "950441": {
#     "edge": [[950440], "SPEC"],
#     "note": "Normalize to other cases; draw Spec to other ב-headed phrase atom instead of word"
# },
# "966230": {
#     "edge": [[966229], "SPEC"],
#     "note": "Normalize to other cases; draw Spec to other ב-headed phrase atom instead of word"
# },
# "1018760": {
#     "edge": [[1018759], "SPEC"],
#     "note": "Normalize to other cases; draw Spec to other ב-headed phrase atom instead of word"
# },
# "1018761": {
#     "edge": [[1018760], "SPEC"],
#     "note": "Normalize to other cases; draw Spec to other ב-headed phrase atom instead of word"
# },
# "1034479": {
#     "edge": [[1034478], "SPEC"],
#     "note": "Normalize to other cases; draw Spec to other ב-headed phrase atom instead of word"
# },
# "1034568": {
#     "edge": [[1034567], "SPEC"],
#     "note": "Normalize to other cases; draw Spec to other ב-headed phrase atom instead of word"
# },
# "1034832": {
#     "edge": [[1034831], "SPEC"],
#     "note": "Normalize to other cases; draw Spec to other ב-headed phrase atom instead of word"
# },
# "1112864": {
#     "edge": [[1112863], "SPEC"],
#     "note": "Normalize to other cases; draw Spec to other ב-headed phrase atom instead of word"
# },
# "1138929": {
#     "edge": [[1138928], "SPEC"],
#     "note": "Normalize to other cases; draw Spec to other ב-headed phrase atom instead of word"
# }

# %%
T.sectionFromNode(1024006)
# Out:
# ('1_Kings', 22, 52)

# %% [markdown]
# ## Investigate Accent Separators

# %%
import json

# %%
with open('../../results/disambigs/accentseps.json', 'r') as infile:
    accentseps = json.load(infile)

# %%
len(accentseps)
# Out:
# 682

# %%
# for w in accentseps[:100]:
#     ph = L.u(w, 'phrase_atom')
#     A.prettyTuple(ph, seq=0, condenseType='phrase', highlights={w})
