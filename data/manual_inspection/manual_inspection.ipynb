# %% [markdown]
# # Manual Review of Heads and Features
#
# The manual annotations are intended to serve 2 roles: 1. to evaluate the accuracy of the head assignments on time phrases in the BHSA data, 2. to evaluate the time phrase structure in the BHSA dataset, and 3. to gain hands-on exposure to the kinds of time phrases in the dataset. This process consisted of comparing the selected heads against the surface text of the time phrase, and of reading the time phrases in the context of a verse when questions or anomalies arose. The annotation process consisted of marking a given time phrase as "g" for "good," "b" for "bad," and "?" for questionable cases. These classifications refer to both head assignments and internal structuring of the time phrases in the BHSA. The markings are often accompanied with notes: for bad or questionable entries the note explains what is wrong, for good entries the note might describe an interesting phenomenon, in some cases it might give a "light caution" about a given phrase.
#
# The outcome of this annotation process suggests that a custom database is necessary to consistently represent time phrases: there are many cases in BHSA time phrases where the phrase is cleft into 2 adjacent parts whereas in the majority of the data they are kept together. This is an inconsistency that should be solved. In other cases, the notion of "phrase" is not broad enough to encompass the full range of expressions that can mark time. For instance, several time phrases are split off from the infinitives they direct, in which the infinitive is an event. This is because the ETCBC method defines the infinitive event as a clause, operating at a different hierarchical level than the phrase; phrases are defined as strictly non-predicative. In the framework of Construction Grammar (Goldberg, *Constructions*, 1995, Croft, *Radical Construction Grammar*, 2001) preferred by this study, the link between the two forms is likewise considered a constructional object. Indeed, many phrases in this dataset refer to event-like nouns, which are from a syntactical perspective non-predicative; במות "in the death of" is a very frequent example, but other cases include ביום ישׁועה "in the day of salvation," which assumes a salvation event. If the difference between time phrases and time "clauses" is seen as merely an incremental difference rather than categorical, then one can apply a unified strategy in analyzing these cases.

# %% [markdown]
# ### Load TF / BHSA Data

# %%
import collections, random, csv
import pandas as pd
from tf.fabric import Fabric
from tf.app import use
pd.set_option('display.max_colwidth', 0)  # configure DataFrame to show full notes with no truncation

locs = {'bhsa':'~/text-fabric-data/etcbc/bhsa/tf/c',
        'heads':'~/github/etcbc/heads/tf/c',
        'custom':'~/github/csl/time_collocations/data/tf'}

# load BHSA
TF = Fabric(locations=locs.values())
api = TF.load('''

vs vt pdp gloss lex typ number  prs
g_cons_utf8 nu mother st language ls rela
obj_prep sem_set head nhead
note function

''')

A = use('bhsa', api=api, hoist=globals(), silent=True)
# Out:
# This is Text-Fabric 7.7.3
# Api reference : https://annotation.github.io/text-fabric/Api/Fabric/
#
# 121 features found and 4 ignored
#   0.00s loading features ...
#    |     0.01s Not enough info for structure in otext, structure functionality will not work
#    |     0.13s B g_cons_utf8          from /Users/cody/text-fabric-data/etcbc/bhsa/tf/c
#    |     0.09s B lex                  from /Users/cody/text-fabric-data/etcbc/bhsa/tf/c
#    |      |     0.74s C __levels__           from otype, oslots, otext
#    |      |       14s C __order__            from otype, oslots, __levels__
#    |      |     0.79s C __rank__             from otype, __order__
#    |      |       13s C __levUp__            from otype, oslots, __levels__, __rank__
#    |      |     9.78s C __levDown__          from otype, __levUp__, __rank__
#    |      |     2.56s C __boundary__         from otype, oslots, __rank__
#    |      |     0.09s C __sections__         from otype, oslots, otext, __levUp__, __levels__, book, chapter, verse
#    |     0.08s B vs                   from /Users/cody/text-fabric-data/etcbc/bhsa/tf/c
#    |     0.08s B vt                   from /Users/cody/text-fabric-data/etcbc/bhsa/tf/c
#    |     0.08s B pdp                  from /Users/cody/text-fabric-data/etcbc/bhsa/tf/c
#    |     0.10s B gloss                from /Users/cody/text-fabric-data/etcbc/bhsa/tf/c
#    |     0.15s B typ                  from /Users/cody/text-fabric-data/etcbc/bhsa/tf/c
#    |     0.16s B number               from /Users/cody/text-fabric-data/etcbc/bhsa/tf/c
#    |     0.09s B prs                  from /Users/cody/text-fabric-data/etcbc/bhsa/tf/c
#    |     0.10s B nu                   from /Users/cody/text-fabric-data/etcbc/bhsa/tf/c
#    |     0.22s B mother               from /Users/cody/text-fabric-data/etcbc/bhsa/tf/c
#    |     0.10s B st                   from /Users/cody/text-fabric-data/etcbc/bhsa/tf/c
#    |     0.13s B language             from /Users/cody/text-fabric-data/etcbc/bhsa/tf/c
#    |     0.10s B ls                   from /Users/cody/text-fabric-data/etcbc/bhsa/tf/c
#    |     0.18s B rela                 from /Users/cody/text-fabric-data/etcbc/bhsa/tf/c
#    |     0.12s B obj_prep             from /Users/cody/github/etcbc/heads/tf/c
#    |     0.03s B sem_set              from /Users/cody/github/etcbc/heads/tf/c
#    |     0.35s B head                 from /Users/cody/github/etcbc/heads/tf/c
#    |     0.53s B nhead                from /Users/cody/github/etcbc/heads/tf/c
#    |     0.00s T note                 from /Users/cody/github/csl/time_collocations/data/tf
#    |     0.58s T function             from /Users/cody/github/csl/time_collocations/data/tf
#     55s All features loaded/computed - for details use loadLog()
# 	connecting to online GitHub repo annotation/app-bhsa ... connected
# Using TF-app in /Users/cody/text-fabric-data/annotation/app-bhsa/code:
# 	rv1.0=#d3cf8f0c2ab5d690a0fda14ea31c33da5c5c8483 (latest release)
# <style>
# @font-face {
#   font-family: "Ezra SIL";
#   src:
#     local("SILEOT.ttf"),
#     url("https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true");
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0a6611;
#     display: flex;
#     flex-flow: column nowrap;
#     padding: 0.1em;
#     margin: 0.1em;
#     direction: ltr;
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1em 0em;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-style: italic;
#   font-size: small;
#   font-weight: normal;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .verse {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .vl {
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-end;
#     align-items: flex-end;
#     direction: ltr;
#     width: 100%;
# }
# .outeritem {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .sentence,.clause,.phrase {
#     margin-top: -1.2em;
#     margin-left: 1em;
#     background: #ffffff none repeat scroll 0 0;
#     padding: 0 0.3em;
#     border-style: solid;
#     border-radius: 0.2em;
#     font-size: small;
#     display: block;
#     width: fit-content;
#     max-width: fit-content;
#     direction: ltr;
# }
# .atoms {
#     display: flex;
#     flex-flow: row wrap;
#     margin: 0.3em;
#     padding: 0.3em;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .satom,.catom,.patom {
#     margin: 0.3em;
#     padding: 0.3em;
#     border-radius: 0.3em;
#     border-style: solid;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .sentence {
#     border-color: #aa3333;
#     border-width: 1px;
# }
# .clause {
#     border-color: #aaaa33;
#     border-width: 1px;
# }
# .phrase {
#     border-color: #33aaaa;
#     border-width: 1px;
# }
# .satom {
#     border-color: #aa3333;
#     border-width: 4px;
# }
# .catom {
#     border-color: #aaaa33;
#     border-width: 3px;
# }
# .patom {
#     border-color: #33aaaa;
#     border-width: 3px;
# }
# .word {
#     padding: 0.1em;
#     margin: 0.1em;
#     border-radius: 0.1em;
#     border: 1px solid #cccccc;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .lextp {
#     padding: 0.1em;
#     margin: 0.1em;
#     border-radius: 0.1em;
#     border: 2px solid #888888;
#     width: fit-content;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .occs {
#     font-size: x-small;
# }
# .satom.l,.catom.l,.patom.l {
#     border-left-style: dotted
# }
# .satom.r,.catom.r,.patom.r {
#     border-right-style: dotted
# }
# .satom.lno,.catom.lno,.patom.lno {
#     border-left-style: none
# }
# .satom.rno,.catom.rno,.patom.rno {
#     border-right-style: none
# }
# .tr,.tr a:visited,.tr a:link {
#     font-family: sans-serif;
#     font-size: large;
#     color: #000044;
#     direction: ltr;
#     text-decoration: none;
# }
# .trb,.trb a:visited,.trb a:link {
#     font-family: sans-serif;
#     font-size: normal;
#     direction: ltr;
#     text-decoration: none;
# }
# .prb,.prb a:visited,.prb a:link {
#     font-family: sans-serif;
#     font-size: large;
#     direction: ltr;
#     text-decoration: none;
# }
# .h,.h a:visited,.h a:link {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     color: #000044;
#     direction: rtl;
#     text-decoration: none;
# }
# .hb,.hb a:visited,.hb a:link {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     line-height: 2;
#     direction: rtl;
#     text-decoration: none;
# }
# .vn {
#   font-size: small !important;
#   padding-right: 1em;
# }
# .rela,.function,.typ {
#     font-family: monospace;
#     font-size: small;
#     color: #0000bb;
# }
# .pdp,.pdp a:visited,.pdp a:link {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
#     text-decoration: none;
# }
# .voc_lex {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
# }
# .vs {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .vt {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .gloss {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #444444;
# }
# .vrs {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: #444444;
# }
# .nd {
#     font-family: monospace;
#     font-size: x-small;
#     color: #999999;
# }
# .hl {
#     background-color: #ffee66;
# }
#
# tr.tf, td.tf, th.tf {
#   text-align: left;
# }
#
# span.hldot {
# 	background-color: var(--hl-strong);
# 	border: 0.2rem solid var(--hl-rim);
# 	border-radius: 0.4rem;
# 	/*
# 	display: inline-block;
# 	width: 0.8rem;
# 	height: 0.8rem;
# 	*/
# }
# span.hl {
# 	background-color: var(--hl-strong);
# 	border-width: 0;
# 	border-radius: 0.1rem;
# 	border-style: solid;
# }
#
# span.hlup {
# 	border-color: var(--hl-dark);
# 	border-width: 0.1rem;
# 	border-style: solid;
# 	border-radius: 0.2rem;
#   padding: 0.2rem;
# }
#
# :root {
# 	--hl-strong:        hsla( 60, 100%,  70%, 0.9  );
# 	--hl-rim:           hsla( 55, 100%,  60%, 0.9  );
# 	--hl-dark:          hsla( 55, 100%,  40%, 0.9  );
# }
# </style>

# %%
def tokenPhrase(phrasenode):
    '''Tokenizes a phrase with
    dot-separated words.
    input: phrase node number
    output: token string'''
    words = [(F.g_cons_utf8.v(w) if F.lex.v(w) != 'H' else 'ה') for w in L.d(phrasenode, 'word')]
    return '.'.join(words)

def tokenHeads(headslist):
    '''same as tokenPhrase but with list of head word nodes'''
    return '.'.join((F.g_cons_utf8.v(w) if F.lex.v(w) != 'H' else 'ה') for w in headslist)

# %% [markdown]
# ## Phrase Tokens and Phrase Heads
# This search counts all of the discrete time phrase tokens in Hebrew and gathers data about their heads. This data is exported to a spreadsheet for manual inspection. Per every token, a key of its heads is saved into a dictionary, linked to a list of phrase nodes. Tokens that have more than 1 head are suspicious, since the surface form is the same. All other tokens will be exported with their standard heads for inspection.

# %%
tp_heads = collections.defaultdict(lambda: collections.defaultdict(list))
tp_nheads = collections.defaultdict(lambda: collections.defaultdict(list))
tp_count = collections.Counter()

tps = A.search('''

phrase function=Time
/with/
    word language=Hebrew
/-/

''', shallow=True)

for tp in tps:
    token = tokenPhrase(tp) # tokenize surface of phrase
    heads_token = tokenHeads(E.head.t(tp)) # get heads
    nheads_token = tokenHeads(E.nhead.t(tp)) # get semantic heads
    tp_heads[token][heads_token].append(tp) # look at its heads
        
    # only populate nheads with PP phrases, since nhead feature for NP is exactly the same
    if F.typ.v(tp) == 'PP':
        tp_nheads[token][nheads_token].append(tp)
        
    tp_count[token] += 1
    
suspect_heads = [tp for tp in tp_heads if len(tp_heads[tp]) > 1]
suspect_nheads = [tp for tp in tp_nheads if len(tp_nheads[tp]) > 1]

print(f'total phrase tokens 2 head mappings: {len(tp_heads)}')
print(f'total phrase tokens 2 nhead mappings: {len(tp_nheads)}')
print(f'total suspect heads: {len(suspect_heads)}')
print(f'total suspect nheads {len(suspect_nheads)}')
# Out:
#   0.77s 3953 results
# total phrase tokens 2 head mappings: 1164
# total phrase tokens 2 nhead mappings: 888
# total suspect heads: 0
# total suspect nheads 0

# %% [markdown]
# ### Compile Manual Inspection Spreadsheet
#
# Two spreadsheets are exported: a `tp_heads.csv` and a `tp_nheads.csv`. Two versions are needed since `nhead` ("nominal" head, which is probably better-named as "semantic head") is different in cases of prepositional phrases. The `nhead` and `head` features on phrases thus have a lot of overlap, but are not identical. The `tp_nheads.csv` contains only prepositional phrases, since their `nhead` (an object of the prep.) is always different from the `head`.
#
# After export, the files are opened in Numbers and manually annotated with a series of tags. It is then re-saved as the same .csv file. The data is exported below, and the results of the manual annotations are described in the subsequent section.

# %%
tp_heads_data = []
tp_nheads_data = []
data_header = ['token', '(n)heads_token', 'freq', 'mark', 'note', 'ex_ref', 'ex', 'ex_node', 'ex_verse']

for htp, nhtp in zip(tp_heads.keys(), tp_nheads.keys()):
    head = next(tp for tp in tp_heads[htp])
    nhead = next(tp for tp in tp_nheads[nhtp])
    head_ex = random.choice(tp_heads[htp][head])
    nhead_ex = random.choice(tp_nheads[nhtp][nhead])
    
    head_ref, nhead_ref = ['{} {}:{}'.format(*T.sectionFromNode(ex)) for ex in (head_ex, nhead_ex)]
    head_txt, nhead_txt = [T.text(ex) for ex in (head_ex, nhead_ex)]
    head_verse, nhead_verse = [T.text(L.u(ex, 'verse')[0]) for ex in (head_ex, nhead_ex)]
    
    heads_data = [htp, head, tp_count[htp], '', '', head_ref, head_txt, head_ex, head_verse]
    nheads_data = [nhtp, nhead, tp_count[nhtp], '', '', nhead_ref, nhead_txt, nhead_ex, nhead_verse]
    tp_heads_data.append(heads_data)
    tp_nheads_data.append(nheads_data)
    
tp_heads_data, tp_nheads_data = sorted(tp_heads_data), sorted(tp_nheads_data)

# %%
# !! Commented out to prevent writing over the manually added data !!

# with open('manual_curation/tp_heads.csv', 'w') as outfile:
#     writer = csv.writer(outfile)
#     writer.writerow(data_header)
#     writer.writerows(tp_heads_data)
    
# with open('manual_curation/tp_nheads.csv', 'w') as outfile:
#     writer = csv.writer(outfile)
#     writer.writerow(data_header)
#     writer.writerows(tp_nheads_data)

# %% [markdown]
# ## Results of the Manual Inspection

# %%
head_anno = pd.read_csv('tp_heads.csv')
nhead_anno = pd.read_csv('tp_nheads.csv')

# %% [markdown]
# ### Looking at Bad Cases

# %%
# head_anno[head_anno['mark'] == 'b'].to_csv('head_fixes.csv')

# %%
# nhead_anno[nhead_anno['mark']=='b'].to_csv('nhead_fixes.csv')

# %% [markdown]
# **All situations have been remedied. The chosen solution is stored under the new column, "fix", in `head_fixes.csv` and `nhead_fixes.csv`.**

# %% [markdown]
# ### Looking at Questionable Cases

# %%
head_anno[head_anno['mark'] == '?']
# Out:
#                                        token (n)heads_token  freq mark  \
# 13    אחרי                                    אחרי           4     ?
# 159   ב.ה.יום.ה.שׁמיני.ו.הלאה                 ב              1     ?
# 245   ב.ה.שׁנים.עד.שׁנת.ה.יבל                 ב              1     ?
# 252   ב.זמניהם                                ב              1     ?
# 651   ימים.רבים.שׁמונים.ו.מאת.יום             ימים           1     ?
# 802   ל.עת.יום.ב.יום                          ל.ב            1     ?
# 830   ל.רוח.ה.יום                             ל              1     ?
# 864   מ.יום.אל.יום                            מ              2     ?
# 876   מ.ימי.מלכי.אשׁור.עד.ה.יום.ה.זה          מ              1     ?
# 896   מ.נערי.עד.ה.יום.ה.זה                    מ              1     ?
# 903   מ.עולם.עד.עולם                          מ              1     ?
# 905   מ.ערב.עד.בקר                            מ              2     ?
# 955   מן.ה.בטן.עד.יום.מותו                    מן             1     ?
# 964   מן.ה.יום.ה.ראשׁון.עד.ה.יום.ה.אחרון      מן             1     ?
# 973   מני.בטן                                 מני            1     ?
# 974   מני.רחם                                 מני            1     ?
# 1009  עד.יום.אחד.ל.ה.חדשׁ.ה.ראשׁון            עד             1     ?
# 1069  ראשׁ.ה.אשׁמרת.ה.תיכונה                  ראשׁ           1     ?
# 1095  שׁבעת.ימים.ו.שׁבעת.ימים.ארבעה.עשׂר.יום  ימים.ימים      1     ?
# 1105  שׁלשׁ.שׁנים.שׁנה.אחרי.שׁנה              שׁנים          1     ?
# 1164  תמיד.מ.רשׁית.ה.שׁנה.ו.עד.אחרית.שׁנה     תמיד           1     ?
#
#                                                                                                                                                                                                                       note  \
# 13    One case in Job with 1cs suffix אחרי that looks debatable
# 159   shouldn’t הלאה be considered a co-head here?
# 245   how to handle the second prep עד, here? Similar to הלאה. They could be treated as specifications as they probably are in the current dataset. This is not necessarily a bad encoding.
# 252   this does not appear adverbial but seems to be modifying ימי…; tell-tale sign is that it immediately follows a PP/NP, other questionable cases could be found in this way
# 651   this TP has quantified ימים with waw separating second part; this is typically represented as two heads, but not here. Why? Is it a problem?
# 802   There is more inconsistency here with the second prep specification. Is it or is it not a “head” element? This is done differently here than it is elsewhere…
# 830   I wonder whether this really is temporal in nature? this needs more investigation. This case was marked as a statistically rare head term for TPs in the statistical TP head tests.
# 864   Is this different from coordinated phrases with two preps?
# 876   Only one prep counted due to no waw coordination. Have a look at two examples above, from Jer 36:2, where a near-verbatim phrase is deployed without the waw
# 896   missing עד; I marked this case, but there are some other cases that I indeed didn’t mark…
# 903   missing second prep. Cf. with 1 Chronicles 29:10, where עד has been selected as a head
# 905   missing second prep. cf. with Ps 90:2, 1_Chron 29:10, in this dataset.
# 955   missing second prep. as with several other unmarked cases. Perhaps the nature of the second preposition in relation to the first gives some kind of semantic clue that the second is in coordination with the first?
# 964   missing second prep
# 973   It is questionable whether בטן here qualifies this as a temporal phrase…
# 974   as with בטן in this verse, it is suspect whether this is truly a temporal phrase. Indeed it seems to refer to a time “before”…that may be in its favor. Investigate it.
# 1009  I’m not sure anymore whether the L in the B…L construction should be considered as “goverened” and not coordinated somehow.
# 1069  This appears to be a ראשׁ “prepositional” use, and אשׁמרת should be the head instead. Or at the very least, in the nheads feature it should be that, and it is not currently (I checked)
# 1095  Have a look at this complex example. Should יום have been selected? There is a clear problem with these quantifier expressions that repeat the nominal element.
# 1105  The apositional? phrase afterwards, should it be its own TP??
# 1164  should ועד be considered part of the head structure here?
#
#                   ex_ref  \
# 13    Nehemiah 3:31
# 159   Ezekiel 43:27
# 245   Leviticus 25:52
# 252   Esther 9:31
# 651   Esther 1:4
# 802   1_Chronicles 12:23
# 830   Genesis 3:8
# 864   1_Chronicles 16:23
# 876   Nehemiah 9:32
# 896   1_Samuel 12:2
# 903   Psalms 90:2
# 905   Leviticus 24:3
# 955   Judges 13:7
# 964   Nehemiah 8:18
# 973   Isaiah 46:3
# 410  ב.עשׂרים.ו.ארבעה.ל.ה.חדשׁ
# 432  ב.ראשׁי.חדשׁיכם
# 450  ב.שׁלשׁה.עשׂר.בו.ו.ב.ארבעה.עשׂר.בו
# 558  כ.אתמול.שׁלשׁום
# 561  כ.ה.יום
# 562  כ.ה.יום.ה.זה
# 570  כ.יום.תמים
# 573  כ.מה.שׁנים
# 576  כ.מעט.רגע
# 585  ל.ארך.ימים
# 589  ל.דר.ו.דר.עד.עולם
# 609  ל.ה.מצער
# 623  ל.ימים
# 677  ל.פניהם
# 688  ל.רוח.ה.יום
# 704  מ.בטן
# 705  מ.בקר
# 707  מ.די.חדשׁ.ב.חדשׁו.ו.מ.די.שׁבת.ב.שׁבתו
# 708  מ.די.שׁנה.ב.שׁנה
# 745  מ.מעי.אמי
# 826  עד.אן
# 827  עד.אנה
# 877  עד.ערב.בקר.אלפים.ו.שׁלשׁ.מאות
#
#          (n)heads_token  freq mark  \
# 75   דמי                 1     ?
# 84   חגים.חדשׁים.שׁבתות  1     ?
# 111  חיים                1     ?
# 146  ליל                 1     ?
# 220  שׁנים               1     ?
# 273  יום.יום             1     ?
# 320  ימי                 4     ?
# 358  ימי                 1     ?
# 371  יצקתו               1     ?
# 398  עד                  1     ?
# 399  יום                 1     ?
# 400  כברת                1     ?
# 402  חדשׁים              1     ?
# 403  ימים                3     ?
# 404  שׁנתים              2     ?
# 405  שׁנה                1     ?
# 410  עשׂרים.ארבעה        1     ?
# 432  חדשׁיכם             1     ?
# 450  שׁלשׁה.ארבעה        1     ?
# 558  אתמול               2     ?
# 561  יום                 8     ?
# 562  יום                 8     ?
# 570  יום                 1     ?
# 573  מה                  1     ?
# 576  רגע                 2     ?
# 585  ארך                 2     ?
# 589  דר.דר               1     ?
# 609  מצער                1     ?
# 623  ימים                1     ?
# 677  פניהם               1     ?
# 688  רוח                 1     ?
# 704  בטן                 3     ?
# 705  בקר                 1     ?
# 707  די.די               1     ?
# 708  די                  2     ?
# 745  מעי                 1     ?
# 826  אן                  1     ?
# 827  אנה                 13    ?
# 877  ערב.בקר             1     ?
#
#                                                                                                                                                                                                                                                                      note  \
# 75   accents has a different division, excluding דמי; ESV translates as a TP. What is the basis?
# 84   should מועדי be selected as a head too? Is it just an apposition?
# 111  this is difficult syntax; ESV also reads as a TP. But what exactly is happening in this TP?
# 146  Why is this form recorded this way? without ה at end? The T.text rendition shows it properly…
# 220  How to handle the עד cases? should be considrered here. As I noted in heads manual annotations.
# 273  what to do with coordinated version of this TP, when they’re not recorded in the same way without the waw coordination?
# 320  cleft TP with missing infiinitive section
# 358  why is there an empty slot here? Also: note that this takes the CX of “in days of [person]”
# 371  I may have marked this as “good” in heads manual search, but this needs to be scrutinzed more. Is this a temporal use?
# 398  Cf with 2 Sam 3:35, בעוד היום, where יום is selected instead of עוד, because עוד is considered a prepositional-ized lex here (or at least adjectival in nature). Perhaps both cases need to be reviewed.
# 399  see note on ב.עד.יומם
# 400  see note on ב.עד.יומם
# 402  Should I perhaps reconsider the head here as עוד, functioning substnativaly, or is it truly adjectival?
# 403  Should I perhaps reconsider the head here as עוד, functioning substnativaly, or is it truly adjectival?
# 404  Should I perhaps reconsider the head here as עוד, functioning substnativaly, or is it truly adjectival?
# 405  Should I perhaps reconsider the head here as עוד, functioning substnativaly, or is it truly adjectival?
# 410  NB: other similar cases due not include the second part of the quantifier. what is really needed here is a proper solution for quantifier constructions; there are other cases of this that I did not mark, in Haggai 2:10 and Neh 6:15, immediately below this note
# 432  should I consider “beginnings” here as a simple modifying element and not a “head”?
# 450  NB: בו construction is unique here, perhaps to Esther, as an implied reference to חדשׁ?
# 558  temporal with כ?
# 561  temporal with כ?
# 562  temporal with כ?
# 570  interesting use of כ from the book of Jashar. But is it temporal?
# 573  the temporal noun here is שׁנה, but this apears to be an interrogative with מה. How is this functioning adverbially??
# 576  the ESV translates this as if a sign of duration. Is it? Is it temporal or adjunctive? What is the usual use of רגע? The כ IS used in durative constructions. See Ruth 1:4 in this dataset, 1 below this note.
# 585  the noun יום is more prominent—does >RK function here prepositionally?
# 589  what about עד
# 609  NB: this may need more investigation
# 623  questionable whether this is temporal, note, however, that it does occur in a NC, which may have different tendencies.
# 677  is it temporal? ESV doesn’t do a temporal reading
# 688  Is this temporal?
# 704  temporal? perhaps a temporal state
# 705  temporal?
# 707  Another heads issue. Should די be a head or modifier?
# 708  is די a head or a modifier?
# 745  temporal? stative possibly, like with בֶטֶן
# 826  interrogatives as temporal?
# 827  interrogatives as temporal?
# 877  what is going on here with ערב and בקר?
#
#                 ex_ref  \
# 75   Isaiah 38:10
# 84   Ezekiel 45:17
# 111  Ecclesiastes 6:12
# 146  Proverbs 31:18
# 220  Leviticus 25:52
# 273  Jeremiah 11:7
# 320  2_Chronicles 26:5
# 358  2_Samuel 21:9
# 371  1_Kings 7:24
# 398  Jeremiah 15:9
# 399  2_Samuel 3:35
# 400  Genesis 48:7
# 402  Amos 4:7
# 403  Genesis 40:13
# 404  Jeremiah 28:11
# 405  Isaiah 7:8
# 410  Haggai 2:20
# 432  Numbers 28:11
# 450  Esther 9:18
# 558  1_Samuel 14:21
# 561  Nehemiah 5:11
# 562  1_Samuel 22:13
# 570  Joshua 10:13
# 573  Zechariah 7:3
# 576  Ezra 9:8
# 585  Psalms 23:6
# 589  Psalms 106:31
# 609  Isaiah 63:18
# 623  Job 30:1
# 677  Ecclesiastes 9:1
# 688  Genesis 3:8
# 704  Isaiah 49:1
# 705  Job 4:20
# 707  Isaiah 66:23
# 708  1_Samuel 7:16
# 745  Isaiah 49:1
# 826  Job 8:2
# 827  Job 18:2
# 877  Daniel 8:14
#
#                                                                                     ex  \
# 75   בִּדְמִ֥י יָמַ֛י
# 84   בַּחַגִּ֤ים וּבֶחֳדָשִׁים֙ וּבַשַּׁבָּתֹ֔ות בְּכָֽל־מֹועֲדֵ֖י בֵּ֣ית יִשְׂרָאֵ֑ל
# 111  בַּֽחַיִּ֗ים מִסְפַּ֛ר יְמֵי־חַיֵּ֥י הֶבְלֹ֖ו
# 146  בַלַּ֣יְלָה
# 220  בַּשָּׁנִ֛ים עַד־שְׁנַ֥ת הַיֹּבֵ֖ל
