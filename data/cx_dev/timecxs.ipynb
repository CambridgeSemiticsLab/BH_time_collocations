# %% [markdown]
# # Composing Time Constructions
#
# The current method for isolating phrase heads ([here](https://nbviewer.jupyter.org/github/ETCBC/heads/blob/master/phrase_heads.ipynb)) requires strenuous and ineloquent processing of BHSA subphrase relations. The subphrases are not always consistently encoded and suffer from numerous exceptional cases. The result is that the method is rather convoluted and ineloquent.
#
# This notebook will explore the possibility of disconnecting semantic head analysis from the ETCBC subphrase encoding.
#
# A "semantic" head is the primary content word of a phrase, following Croft's "Primary Information Bearing Unit":
#
# > **The noun and the verb are the PRIMARY INFORMATION_BEARING UNITS (PIBUs) of the phrase and clause respectively. In common parlance, they are the content words. PIBUs have major informational content that functional elements such as articles and [auxiliaries] do not have. (Croft, *Radical Construction Grammar*, 2001, 258; see also Shead, *Radical Frame Semantics and Biblical Hebrew*, 104)**
#
# > **A (semantic) head is the profile equivalent that is the primary information-bearing unit, that is, the most contentful item that most closely profiles the same kind of thing that the whole constituent profiles. (ibid., 259)**
#
# Croft also provides an additional criterion to "profile equivalence":
#
# > **If the criterion of profile equivalence produces two candidates for headhood, the less schematic meaning is the PIBU; that is, the PIBU is the one with the narrower extension, in the formal semantic sense of that term (ibid., 259)**
#
# ## Inquiry
#
# Can we isolate semantic phrase heads in BHSA using only the phrase_atom and phrase limits? This question indeed means that we  take the phrase_atom/phrase boundaries for granted. Empirically, the validity of BHSA phrase boundaries needs to be tested. But for now, the exercise of isolating semantic phrase heads could be seen as the first step towards reproducible phrase boundaries.
#
# ## Basic Concepts
#
# A semantic head will most often stand in a syntactically independent position. For Hebrew nominal phrases, that essentially means a word which is not precided by a construct, and which is semantically central (excluding attributive slots (e.g. H + noun + H + ATTRIBUTIVE) or an adjectival slots (e.g. noun + noun as in אישׁ טוב).
#
# Quantifier expressions present unique cases, which may be syntactically independent but semantically secondary. These are expressed through specialized lexical items such as cardinal numbers and qualitative quantifiers (e.g.  "כל" and "חצי").
#
# Another complication is the use of nouns as prepositional items. Such uses can be seen with words like פני "face" such as לפני "in front," and even words like ראשׁ as in ראשׁ החדשׁ "beginning of the month."
#
# Other expressions of quantity, quality, and function provide similar complexities. These cases have to be specified in advance.
#
# ### Ambiguity
#
# Considerable ambiguity is present in several of cases:
#
# **`A B and C`**<br>
# Given A, B, C == nominal words. Is their relationship `A // B // C` or `A+B // C`. In other words: **what is the relationship of two adjacent nominal words given a list?** Is B a descriptor of A or is it an independent element?
#
# **`A of B and C`**<br>
# Is it, `(A of B) // (C)` or `(A of (B // C)`
#
# Or even:
#
# **`A of B C and D`**<br>
# This pattern combines elements from both ambiguous cases.
#
# To address these ambiguities we will apply a battery of disambiguation attempts. Some of those attempts will draw from corpus data, i.e. do we ever see `B and C` with the conjunction explicitly elsewhere in the corpus? Or do we ever see a `A of C` excplicitly in the corpus? Accents may also play a role: do we see a conjunctive or disjunctive accent between `B C`?
#
# ## Prerequisites
#
# A number of pre-defined word sets are needed for processing quantification and ambiguous adjacency. These sets are made available in the form of `wsets`, a dictionary containing word sets that are calculated in to the `wordsets` directory of this repository. The following wordsets have been defined:
#
# * nominals – a set of word nodes with parts of speech and participles that have the potential to function as nominalized elements. The selected parts of speech are quite permissive: `{'subs', 'nmpr', 'adjv', 'advb', 'prde', 'prps', 'prin', 'inrg'}`. Since parts of speech are not taken as universal linguistic categories but only summaries of language-specific word tendencies (cf. Croft, *Radical Construction Grammar*, 2001), we consider that almost any part of speech can be used in a nominal pattern (or construction). There are some upper limits to this assumption, though. For instance, we exclude cojunctions, articles, prepositions, and negators.
# * prepositions – a word set consisting of words with a part of speech category of `prep`, a lexical set (`ls`) feature of `ppre` ("potential preposition"), as well as a select group of nouns like פני "face" which have been processed for prepositionality.
# * quantifiers - consists of word nodes that are cardinal numbers or qualitative quantifiers such as כל.
# * mword – mapping from a word to its phonological word group ("masoretic word"); joins words on maqqeph and ø space
# * accent_type – a mapping from a word to its accent type: conjunctive or disjunctive
# * conj_pairs – a dict of observed conjunction pairings of lexemes in the corpus: `A & B`
# * cons_pairs – a dict of observed construct pairings of lexemes in the corpus: `A of B`
# * mom – mapping from word node to its mother word node for a specified relationship: `mom[A]['coord'] = B`
# * kid – opposite of mom; mapping from word to its children nodes for a relationship: `kid[A]['cons'] = B`
#
# **Let's get started**. We load the necessary functions and BHSA data (straight from source).

# %%
import sys
import collections
import pickle
import random
import re
import itertools
import copy
from IPython.display import display, HTML
from datetime import datetime
from pprint import pprint
from tf.app import use
from tf.fabric import Fabric
from tools.locations import data_locations

# load custom wordsets
wsets = pickle.load(open('wordsets/wsets.pickle', 'rb'))

# load custom BHSA data + heads
TF = Fabric(locations=data_locations.values())
load_features = ['g_cons_utf8', 'trailer_utf8', 'label', 'lex',
                 'role', 'rela', 'typ', 'function', 'language',
                 'pdp', 'gloss', 'vs', 'vt', 'nhead', 'head', 
                 'mother', 'nu', 'prs', 'sem_set', 'ls', 'st',
                 'kind', 'top_assoc', 'number', 'obj_prep',
                 'embed', 'freq_lex', 'sp']
api = TF.load(' '.join(load_features))
F, E, T, L = api.F, api.E, api.T, api.L # shortform TF methods

A = use('bhsa', api=api, silent=True)
A.displaySetup(condenseType='phrase', withNodes=True, extraFeatures='st')
# Out:
# This is Text-Fabric 7.8.12
# Api reference : https://annotation.github.io/text-fabric/Api/Fabric/
#
# 123 features found and 6 ignored
#   0.00s loading features ...
#    |     0.00s No structure info in otext, the structure part of the T-API cannot be used
#   8.02s All features loaded/computed - for details use loadLog()
# <style>
# @font-face {
#   font-family: "Ezra SIL";
#   src:
#     local("SILEOT.ttf"),
#     url("https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true");
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0a6611;
#     display: flex;
#     flex-flow: column nowrap;
#     padding: 0.1em;
#     margin: 0.1em;
#     direction: ltr;
# }
# .features div,.features span {
#     padding: 0;
#     margin: -0.1rem 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: x-small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 0.1em 0em;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-style: italic;
#   font-size: small;
#   font-weight: normal;
# }
# .ltr {
#     direction: ltr ! important;
# }
# .verse {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .vl {
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-end;
#     align-items: flex-end;
#     direction: ltr;
#     width: 100%;
# }
# .outeritem {
#     display: flex;
#     flex-flow: row wrap;
#     direction: rtl;
# }
# .sentence,.clause,.phrase {
#     margin-top: -1.2em;
#     margin-left: 1em;
#     background: #ffffff none repeat scroll 0 0;
#     padding: 0 0.3em;
#     border-style: solid;
#     border-radius: 0.2em;
#     font-size: small;
#     display: block;
#     width: fit-content;
#     max-width: fit-content;
#     direction: ltr;
# }
# .atoms {
#     display: flex;
#     flex-flow: row wrap;
#     margin: 0.3em;
#     padding: 0.3em;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .satom,.catom,.patom {
#     margin: 0.3em;
#     padding: 0.3em;
#     border-radius: 0.3em;
#     border-style: solid;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .sentence {
#     border-color: #aa3333;
#     border-width: 1px;
# }
# .clause {
#     border-color: #aaaa33;
#     border-width: 1px;
# }
# .phrase {
#     border-color: #33aaaa;
#     border-width: 1px;
# }
# .satom {
#     border-color: #aa3333;
#     border-width: 4px;
# }
# .catom {
#     border-color: #aaaa33;
#     border-width: 3px;
# }
# .patom {
#     border-color: #33aaaa;
#     border-width: 3px;
# }
# .word {
#     padding: 0.1em;
#     margin: 0.1em;
#     border-radius: 0.1em;
#     border: 1px solid #cccccc;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .lextp {
#     padding: 0.1em;
#     margin: 0.1em;
#     border-radius: 0.1em;
#     border: 2px solid #888888;
#     width: fit-content;
#     display: flex;
#     flex-flow: column nowrap;
#     direction: rtl;
#     background-color: #ffffff;
# }
# .occs {
#     font-size: x-small;
# }
# .satom.l,.catom.l,.patom.l {
#     border-left-style: dotted
# }
# .satom.r,.catom.r,.patom.r {
#     border-right-style: dotted
# }
# .satom.lno,.catom.lno,.patom.lno {
#     border-left-style: none
# }
# .satom.rno,.catom.rno,.patom.rno {
#     border-right-style: none
# }
# .tr,.tr a:visited,.tr a:link {
#     font-family: sans-serif;
#     font-size: large;
#     color: #000044;
#     direction: ltr;
#     text-decoration: none;
# }
# .trb,.trb a:visited,.trb a:link {
#     font-family: sans-serif;
#     font-size: normal;
#     direction: ltr;
#     text-decoration: none;
# }
# .prb,.prb a:visited,.prb a:link {
#     font-family: sans-serif;
#     font-size: large;
#     direction: ltr;
#     text-decoration: none;
# }
# .h,.h a:visited,.h a:link {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     color: #000044;
#     direction: rtl;
#     text-decoration: none;
# }
# .hb,.hb a:visited,.hb a:link {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     line-height: 2;
#     direction: rtl;
#     text-decoration: none;
# }
# .vn {
#   font-size: small !important;
#   padding-right: 1em;
# }
# .rela,.function,.typ {
#     font-family: monospace;
#     font-size: small;
#     color: #0000bb;
# }
# .pdp,.pdp a:visited,.pdp a:link {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
#     text-decoration: none;
# }
# .voc_lex {
#     font-family: monospace;
#     font-size: medium;
#     color: #0000bb;
# }
# .vs {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .vt {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: #0000bb;
# }
# .gloss {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #444444;
# }
# .vrs {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: #444444;
# }
# .nd {
#     font-family: monospace;
#     font-size: x-small;
#     color: #999999;
# }
# .hl {
#     background-color: #ffee66;
# }
#
# tr.tf, td.tf, th.tf {
#   text-align: left;
# }
#
# span.hldot {
# 	background-color: var(--hl-strong);
# 	border: 0.2rem solid var(--hl-rim);
# 	border-radius: 0.4rem;
# 	/*
# 	display: inline-block;
# 	width: 0.8rem;
# 	height: 0.8rem;
# 	*/
# }
# span.hl {
# 	background-color: var(--hl-strong);
# 	border-width: 0;
# 	border-radius: 0.1rem;
# 	border-style: solid;
# }
#
# span.hlup {
# 	border-color: var(--hl-dark);
# 	border-width: 0.1rem;
# 	border-style: solid;
# 	border-radius: 0.2rem;
#   padding: 0.2rem;
# }
#
# :root {
# 	--hl-strong:        hsla( 60, 100%,  70%, 0.9  );
# 	--hl-rim:           hsla( 55, 100%,  60%, 0.9  );
# 	--hl-dark:          hsla( 55, 100%,  40%, 0.9  );
# }
# </style>

# %% [markdown]
# ### Wordsets

# %%
wsets.keys()
# Out:
# dict_keys(['noms', 'preps', 'quants', 'accent_type', 'mwords', 'conj_pairs', 'cons_pairs'])

# %%
list(wsets['cons_pairs'].keys())[:10]
# Out:
# ['>JC/', 'KL/', 'BN/', 'TPF[', 'MZBX/', 'B>R/', '<T/', 'XRB/', 'RWX/', 'MLK/']

# %%
#wsets['conj_pairs']['>JC/']

# %% [markdown]
# # Machinery
#
# We could use some machinery to do the hard work of looking in and around a node. In the older approach we used TF search templates. But these are not very efficient at scale, and they are always bound by the limits of the query language. I take another approach here: a set of classes that specify locations and directions within a specified context.

# %%
from tools.langtools import Positions, Walker, Dummy

# %% [markdown]
# ## `Positions`

# %% [markdown]
# The `Positions` class enables concise access to adjacent nodes within a given context. This allows us to write algorithms with query-like efficiency with all of the power of Python.

# %% [markdown]
# This class is instantiated on a word node and can provide contextual look-up data for a given word. For example, given a phrase containing the following word nodes:
#
# > (189681, 189682, **189683**, 189684, 189685, 189686) <br>
#
# representing the following phrase (space separated for clarity):
#
# > ב שׁנת **שׁלשׁים** ו שׁמנה שׁנה
#
# Given that the bolded node, `189683` is our `source` word, we instantiate the class, feeding in the node, the "phrase_atom" string (which is the context we want to search within), and an instance of Text-Fabric (`tf`):

# %%
      #    source node    context  TF instance  
      #         |            |       |
P = Positions(189683, 'phrase_atom', A).get

# %% [markdown]
# If we want to obtain the word adjacent one space forward, we simply ask `P` for `1`, which gives us the next word in the phrase.

# %%
P(1)
# Out:
# 189684

# %% [markdown]
# If we try to ask for 4 words forward, we go beyond the bounds of the phrase. But `P` handles this by returning nothing:

# %%
P(4)

# %% [markdown]
# To look back one word, we simply give a negative value:

# %%
P(-1)
# Out:
# 189682

# %% [markdown]
# Finally, `P` can be used to quickly call features on these words. For instance, in order to get the lexeme of the word two words in front of `189683`:

# %%
P(2,'lex')
# Out:
# 'CMNH/'

# %% [markdown]
# And if we want to get a number of features, we can just add other features to the arguments. The result is a feature set:

# %%
P(2, 'lex', 'nu')
# Out:
# {'CMNH/', 'sg'}

# %% [markdown]
# `P` can also handle features on the source node itself by giving a positionality of `0`:

# %%
P(0, 'lex')
# Out:
# 'CLC/'

# %% [markdown]
# ## `Walker`
#
# `Walker` performs a similar function to `Positions`, except it is ambiguous to exact positions, walking either `ahead` or `back` from the source to a target node in the context. A function must be supplied that returns `True` on the target node.
#
# We instantiate the `Walker` using the same source and context as above.

# %%
      #  source node    context  TF instance  
      #       |            |       |
Wk = Walker(189683, 'phrase_atom', A)

# %% [markdown]
# `Walker` is demonstrated below with the same word. A simple `lambda` function is used to test for the lexeme. In the example below, we find the first word ahead of `189683` that is a cardinal number:

# %%
Wk.ahead(lambda w: F.ls.v(w) == 'card')
# Out:
# 189685

# %% [markdown]
# An alternative demonstrates the `None` returned on the lack of a valid match.

# %%
Wk.ahead(lambda w: F.ls.v(w) == 'BOOGABOOGA')

# %% [markdown]
# Another example wherein we walk backwards to the preposition:

# %%
Wk.back(lambda w: F.sp.v(w) == 'prep')
# Out:
# 189681

# %% [markdown]
# We can also specify that the walk should be interrupted under certain conditions with a `stop` function. In this case we walk forward to the next cardinal number, but the walk is interrupted when the `stop` function detects a conjunction.

# %%
Wk.ahead(lambda w: F.ls.v(w) == 'card',
         stop=lambda w: F.sp.v(w) == 'conj')

# %% [markdown]
# We can also specify the opposite with a `go` function argument, which defines the nodes that allowed to intervene between `source` and `target`. Below we specify that *only* a conjunction should intervene.

# %%
Wk.ahead(lambda w: F.ls.v(w) == 'card',
         go=lambda w: F.sp.v(w) == 'conj')
# Out:
# 189685

# %% [markdown]
# The `go` and `stop` functions can be as permissive or strict as desired.
#
# Finally, we can tell `Walker` that the output of the validation function should be returned instead of the node itself with the optional argument `output=True`:

# %%
val_funct = lambda w: F.ls.v(w) if F.ls.v(w)=='card' else None

Wk.ahead(val_funct, output=True)
# Out:
# 'card'

# %% [markdown]
# This ability is useful for certain tests.

# %% [markdown]
# ## `Dummy`
#
# When writing conditions and logic, we want an object that passively receives `NoneType`s or zero `int`s without throwing errors. Such an object should also return `None` to reflect its `False` value. `Dummy`, provides such functionality. `Dummy` can receive all of the arguments, kwargs, and function calls as a `Positions` or `Walker` object. But it returns absolutely nothing. Ouch.

# %%
D = Dummy(None, 'phrase_atom', A)

# %% [markdown]
# The function call below returns `None`:

# %%
D.get(1)

# %% [markdown]
# As does this:

# %%
D.get(1, 'lex')

# %% [markdown]
# And even this:

# %%
D.ahead(1)

# %% [markdown]
# `D` is essentially a souless void that consumes whatever you throw at it and gives nothing in return.

# %% [markdown]
# For safe-calls on a `Position` or `Walker` object, assign nodes to it via a function with a `Dummy` given on null nodes:

# %%
def getPos(node, context, tf):
    """A function to get Positions safely."""
    if node:
        return Positions(node, context, tf)
    else:
        return Dummy() # <- give dummy on empty node

# %% [markdown]
# So:

# %%
P = getPos(None, 'phrase_atom', A)
P.get(1)

# %% [markdown]
# Or:

# %%
P = getPos(1, 'phrase_atom', A)
P.get(1)
# Out:
# 2

# %% [markdown]
# # Need for Semantic Data
#
# The accurate processing of word connections depends on fuller semantic data than BHSA provides. Future semantic data could be stored in a similar way to word sets (`wsets`).
#
# For example, in the two phrases
#
# > (Exod 25:39) ככר זהב טהור <br>
# > (2 Sam 24:24) בכסף שקלים חמשׁים
#
# we see that זהב and כסף, despite being in two different positions with two different words indicates a kind of "composed of" semantic concept: "round gold" (i.e. round composed of gold) and "silver shekels" (shekels composed of silver). To process these kinds of links, we need a list of nouns that often function as "material." But this is only the beginning. Many other words will have specific semantic values that motivate their syntactic behavior. Such a scope lies outside the bounds of this author's current project on Hebrew time phrases.
#
# ## A Compromise: Time Phrases
#
# Since constructing these semantic classes is vastly time consuming, I want to start with a smaller set of cases. I will instead focus on parsing connections within time phrases for now. This is because I am analyzing time phrases in my current ongoing PhD project.

# %%
def disjoint(ph):
    """Isolate phrases with gaps."""
    ph = L.d(ph,'word')
    for w in ph:
        if ph[-1] == w:
            break
        elif (ph[ph.index(w)+1] - w) > 1:
            return True

# %%
alltimes = [
    ph for ph in F.otype.s('timephrase') 
        if len(L.d(ph, 'word')) > 2
]
    
timephrases = [ph for ph in alltimes if not disjoint(ph)]

print(f'{len(timephrases)} phrases ready')
# Out:
# 2102 phrases ready

# %% [markdown]
# ## Search & Display Functions
#
# The functions below allow for fast searching and displaying of queries using the `Positions` class. The searches rely on the `Grammar` class, described further below.

# %%
def pretty(obj, condense='phrase', **kwargs):
    """Show a linguistic object that is not native to TF app."""
    show = L.d(obj, condense)
    A.prettyTuple(show, seq=kwargs.get('seq', obj), **kwargs)

def prettyconds(cases):
    '''
    Iterate through an explain dict for a rela
    and print out all of checked conditions.
    '''
    for case in cases:
        print('cnds:')
        for cond, value in case['conds'].items():
            print('{:<30} {:>30}'.format(cond, str(value)))
        
        print()
        
def showmatch(cx):
    '''
    Displays a match from a Grammar test.
    '''
    showcontext = tuple(set(L.u(s, 'phrase')[0] for s in cx.slots))
    timephrase = L.u(list(cx.slots)[0], 'timephrase')[0]
        
    if not cx:
        print('NO MATCHES')
        print('-'*20)
        A.prettyTuple(showcontext, extraFeatures='sp st', withNodes=True, seq=f'{timephrase} -> {cx}')
        #prettyconds(cx.conds)
        return None

    colors = itertools.cycle(['pink', 'lightblue', 
                              'yellow', 'lightgreen'])
    highlights = {}
    role2color = {}
    
    for role, slots in cx.role2slots.items():
        color = next(colors)
        role2color[role] = color
        for slot in slots:
            highlights[slot] = color
    
    A.prettyTuple(
        showcontext, 
        extraFeatures='sp st', 
        withNodes=True, 
        seq=f'{timephrase} -> {cx}', 
        highlights=highlights
    )
    # reveal color meanings
    for role,color in role2color.items():
        colmean = '<div style="background: {}; text-align: center">{}</div>'.format(color, role)
        display(HTML(colmean))
    
    pprint(cx.unfoldroles(), indent=4)
    print()
    
    prettyconds(cx.cases)
    display(HTML('<hr>'))
        
def test_search(cxtest, show=10, end=None, pattern=''):
    '''
    Searches phrases with the specified relation 
    and prints out their descriptive explanation.
    '''
    
    start = datetime.now()
    print('beginning search')
    
    # build a convenient test set of words
    phrases = list(F.otype.s('timephrase'))
    words = [w for ph in phrases for w in L.d(ph, 'word')]
    
    # random shuffle to get good diversity of examples
    random.shuffle(words)
    
    # set up grammar
    G = NounConstructions(wsets, A)
    
    matches = []
    append = matches.append
    
    # iterate and find matches on words
    for i,w in enumerate(words):

        # update every 5000 iterations
        if i%5000 == 0:
            print(f'\t{len(matches)} found ({i}/{len(words)})')
        
        # run test for construction
        test = cxtest(w)
        
        # save results
        if test:
            if pattern:
                if test.pattern == pattern:
                    append(test)
            else:
                append(test)
            
        # stop at end
        if len(matches) == end:
            break
        
    # display
    print('done at', datetime.now() - start)
    print(len(matches), 'matches found...')
    print('showing', end)
    
    for match in matches[:show]:
        showmatch(match)

# %% [markdown]
# ## Constructions classes
#
# While `Positions` provides concise access to context, A `Constructions` class contains a series of functions which test a bunch of conditions. The conditions are formed by testing word `Positions`. An example of a `Constructions` class is provided below.

# %%
class Bunch(object):
    """Stores variables for shorthand and safe access."""
    def __init__(self, vardict):
        """Initialize variables object with dict."""
        self.dict = vardict
        for k,v in vardict.items():
            setattr(self, k, v)
    def __getattr__(self, name):
        return None
    def __deepcopy__(self, memo=None):
        """Handle deep copy errors by instancing a diff Bunch object."""
        return Bunch({k:v for k,v in self.dict.items()})
    
class Construction(object):
    """A linguistic construction and its attributes."""
    
    def __init__(self, **specs):
        """Initialize construction item.
        
        **specs:
            name: A name for the construction.
            roles: A dict which maps roles
                to either another Construction item
                or to a Text-Fabric word node.
            cases: A tuple containing condition dicts
                that were evaluated when processing this
                Construction. Key is string containing condition,
                value is Boolean.
            conds: A condition dict containing all of the
                conditions that evaluated to True to validate
                this Construction.
        """
        self.match = specs.get('match', {})
        self.name = specs.get('name', '')
        self.pattern = specs.get('pattern', specs.get('name', ''))
        self.roles = Bunch(specs.get('roles', {}))
        self.conds = specs.get('conds', {})
        self.cases = specs.get('cases', tuple())
        self.role2slots = collections.defaultdict(set)
        self.slots = set()
        self.mapslots(self.roles.dict)
        self.slots = set(sorted(self.slots)) # sort slots
        self.slots2role = {
            tuple(sorted(slots)):role 
                for role, slots in self.role2slots.items()
        }
        
    def __bool__(self):
        if self.match:
            return True
        else:
            return False
        
    def __str__(self):
        if self:
            return f'CX {self.name} {self.slots}'
        else:
            return ''
        
    def __repr__(self):
        if self:
            return f'CX {self.name} {self.slots}'
        else:
            return ''
            
    def mapslots(self, rolesdict, rolename=None):
        """Recursively map all slots to top embedding role name.

        Match items contain a roles key which can contain
        any number of other match items. This function maps
        all constituent words (Text-Fabric "slots") to their
        top-level linguistic unit (linguistic role).
        """
        for role, item in rolesdict.items():
            if type(item) == Construction:
                self.mapslots(
                    item.roles.dict,
                    rolename=rolename or role
                )
            elif type(item) == int:
                self.role2slots[rolename or role].add(item)
                self.slots.add(item)

    def updaterole(self, role, item):
        """Updates the role."""
        setattr(self.roles, role, item)
        self.roles.dict[role] = item
        
        # update slots 
        
        # delete previous slots2role for this role
        oldslots = tuple(sorted(self.role2slots[role]))
        del self.slots2role[oldslots]
        
        if type(item) == Construction:
            self.slots |= item.slots    
            self.role2slots[role] = item.slots
            self.slots2role[tuple(sorted(item.slots))] = role
        elif type(item) == int:
            self.slots.add(item)
            self.role2slots[role] = item
            self.slots2role[(item,)] = role
            
    def getslotrole(self, slot):
        """Returns the role to which a slot belongs to."""
        for role, slots in self.role2slots.items():
            if slot in slots:
                return role
    
    def unfoldroles(self, cx=None):
        """Return all contained construction roles as a dict.

        Recursively calls down into construction objects to convert
        to role.dict with TF slots.
        """
        cx = cx or self
        roledict={}
        roledict['__cx__'] = cx.name
        for role, item in cx.roles.dict.items():
            if type(item) == Construction :
                roledict[role] = self.unfoldroles(item)
            elif type(item) == int:
                roledict[role] = item
        return roledict

    
class CXbuilder(object):
    """Identifies and builds constructions using Text-Fabric nodes."""
    
    def __init__(self, semsets, tf, **kwargs):
        """Initialize Constructions object.
        
        Arguments:
            semsets: A dictionary containing semantic
                sets. Key should be the name of the set.
                Value is a set of TF nodes.
            tf: An instance of Text-Fabric.
            
        **kwargs:
            context: the context that contains the node in 
            which to run the attribute tests.
        """
        self.tf = tf
        self.F, self.T, self.L = tf.api.F, tf.api.T, tf.api.L
        self.context = kwargs.get('context', 'phrase_atom')
        self.semsets = Bunch(semsets)
        self.cxs = tuple()
    
    def getP(self, node):
        """Get Positions object for a TF node.
        
        Return Dummy object if not node.
        """
        if not node:
            return Dummy()
        return Positions(node, self.context, self.tf).get
    
    def getWk(self, node):
        """Get Walker object for a TF word node.
        
        Return Dummy object if not node.
        """
        if not node:
            return Dummy()
        return Walker(node, self.context, self.tf)
    
    def test(self, *cases):
        """Populate Construction obj based on a cases's all Truth value.
        
        The last-matching case will be used to populate
        a Construction object. This allows more complex
        cases to take precedence over simpler ones.
        
        Args:
            cases: an arbitrary number of dictionaries,
                each of which contains a string key that
                describes the test and a test that evals 
                to a Boolean.
        
        Returns:
            a populated or blank Construction object
        """
        
        # find cases where all cnds == True
        test = [
            case for case in cases
                if all(case['conds'].values())
                    and all(case['roles'].keys())
        ]
        
        # return last test
        if test:
            return Construction(
                match=test[-1],
                cases=cases,
                **test[-1]
            )
        else:
            return Construction(cases=cases, **cases[0])
        
    def findall(self, n):
        """Runs analysis for all constructions with a node.
        
        Returns as dict with test:result as key:value.
        """
        results = []
        for funct in self.cxs:
            cx = funct(n)
            if cx:
                results.append(cx)
        return results

# %%
class NounConstructions(CXbuilder):
    """Class for defining noun constructions."""
    
    def __init__(self, wsets, tf):
        
        """Initialize with Constructions attribs/methods."""
        CXbuilder.__init__(self, wsets, tf, context='timephrase')
        
        # map cx searches for full analyses
        self.cxs = (
            self.defi,
            self.card_chain,
            self.demon,
            self.adjv,
            self.advb,
            self.attrib,
            self.geni,
            self.numb,
            self.prep,
        )

    def defi(self, w):
        """Matches a definite construction."""
        
        P = self.getP(w)
        
        return self.test( 
            {
                'name': 'defi',
                'roles': {'defi': w, 'head': P(1)},
                'conds': {

                    'F.sp.v(w) == art':
                        self.F.sp.v(w) == 'art',

                    'bool(P(1))':
                        bool(P(1))
                }
            }
        )
    
    def prep(self, w):
        """Matches a preposition with a modified element."""
                
        P = self.getP(w)
        
        return self.test(
            {
                'name': 'prep',
                'roles': {'prep':w, 'head': P(1)},
                'conds': {

                    'w in preps':
                        w in self.semsets.preps,

                    'F.prs.v(w) == absent':
                        self.F.prs.v(w) == 'absent',
                    
                    'bool(P(1))':
                        bool(P(1)),
                }
            }
        )
        
    def geni(self, w):
        """Queries for "genitive" relations on a word."""
        
        P = self.getP(w)
        sm = self.semsets
        
        return self.test(
            {
                'name': 'geni',
                'roles': {'geni': P(0), 'head': P(-1)},
                'conds': {

                    'P(-1, st) == c': 
                        P(-1,'st') == 'c',

                    'P(-1) not in quants|preps': 
                        P(-1) not in sm.quants|sm.preps,
                }
            }
        )

    def advb(self, w):
        """Match and adverb and its mod."""
        
        P = self.getP(w)
        
        return self.test(
           {
                'name': 'advb',
                'roles': {'advb': w, 'head': P(1)},
                'conds': {
                    'F.sp.v(w) == advb':
                        self.F.sp.v(w) == 'advb',
                    'P(1) in noms':
                        P(1) in self.semsets.noms,
                }
            }
        )
    
    def adjv(self, w):
        """Matches a word serving as an adjective."""
        
        P = self.getP(w)
        F = self.F
        sm = self.semsets
        
        # check for recursive adjective matches 
        a2match = self.adjv(P(-1)) if P(-1) else Construction()
        a2match_head = a2match.roles.head
        
        common = {
            'P(-1) in noms':
                P(-1) in sm.noms,
            
            'P(-1, st) & {NA, a}': 
                P(-1,'st') in {'NA', 'a'},   
            
            'P(-1) not in {quants|preps}':
                P(-1) not in sm.quants|sm.preps,
        }
                
        tests = (
            
            {
                'name': 'adjv',
                'pattern': 'adjv (1x)',
                'roles': {'adjv':w, 'head': P(-1)},
                'conds': dict(common, **{
                    'F.sp.v(w) in {adjv, verb}':
                        F.sp.v(w) in {'adjv', 'verb'},
                })
            },
            {
                'name': 'adjv',
                'pattern': 'adjv (2x)',
                'roles': {'adjv': P(0), 'head': a2match_head},
                'conds': dict(common, **{
                    
                    'P(0,sp) in {adjv, verb}':
                        P(0,'sp') in {'adjv', 'verb'},
                    
                     'self.adjv(P(-1)) and target != P(0)':
                        bool(a2match) and a2match_head != P(0)
                })
            }
        )

        return self.test(*tests)
     
    def attrib(self, w):
        """Identify elements in a attrib construction.
        
        In Hebrew this construction typically consists of four slots:
            > ה + A + ה + B
        Attrib identifies each of these elements and labels them.
        A is assumed to be the head, or modified, element and B
        is assumed to be an adjectival element.
        """
        
        sm = self.semsets
        
        # CX consists of two constituent cxs
        # start walk from head of first match
        defi1 = self.defi(w)
        d1head = defi1.roles.head
        Wk = self.getWk(d1head)

        # walk to next valid defi match
        # and allow adjectives to intervene:
        defi2 = Wk.ahead(
            lambda n: self.defi(n),
            go=lambda n: self.F.sp.v(n)=='adjv',
            output=True
        ) if Wk else Construction()
        defi2 = defi2 or Construction()
                
        return self.test(
            {
                'name': 'attrib',
                'roles': {'head': defi1, 'attrib': defi2},
                'conds': {
                    'bool(defi1)':
                        bool(defi1),
                    'bool(defi2)':
                        bool(defi2), 
                }
            }
        )
        
    def numb(self, w):
        """Defines numerical relations with an non-quant word
        
        Often but not always indicates quantification as other
        semantic relations are possible.
        """

        P = self.getP(w)
        Wk = self.getWk(w)
        sm = self.semsets
        is_nom = (lambda n: n in sm.noms and n not in sm.quants)
        behind_nom = Wk.back(is_nom, go=lambda n: F.sp.v(n)=='art') 

        return self.test(
        
            {
                'name': 'numb',
                'pattern': 'numbered forward',
                'roles': {'numb': w, 'head': P(1)},
                'conds': {
                    
                    'w in quants':
                        w in sm.quants,

                    'bool(P(1))':
                        bool(P(1)),
                    
                    'P(1,sp) != conj':
                        P(1,'sp') != 'conj',
                    
                    'P(1) not in quants|preps':
                        P(1) not in sm.quants|sm.preps,
                },
            },  
            {
                'name': 'numb',
                'pattern': 'numbered backward',
                'roles': {'numb': w, 'head': behind_nom},
                'conds': {
                    
                    'w in quants':
                        w in sm.quants,
                    
                    'not Wk.ahead(is_nominal)':
                        not Wk.ahead(is_nom),
                    
                    'bool(Wk.back(is_nominal))':
                        bool(behind_nom)
                }
            }
        )
        
    def card_chain(self, w):
        """Defines cardinal number chain constructions"""
        
        P = self.getP(w)
        F = self.F
        
        return self.test(
            {
                'name': 'card_chain',
                'pattern': 'adjacent',
                'roles': {'card':w, 'head':P(-1)},
                'conds': {
                    
                    'F.ls.v(w) == card':
                        F.ls.v(w) == 'card',
                    'P(-1,ls) == card':
                        P(-1,'ls') == 'card',                    
                }
            },
            {
                'name': 'card_chain',
                'pattern': 'conjunctive',
                'roles': {'card': w, 'head': P(-2), 'conj': P(-1)},
                'conds': {
                    'F.ls.v(w) == card':
                        F.ls.v(w) == 'card',
                    'P(-1,lex) == W':
                        P(-1,'lex') == 'W',
                    'P(-2,ls) == card':
                        P(-2,'ls') == 'card',   
                }
            }
        )
    
    def demon(self, w):
        """Defines a direct demonstrative construction."""
        
        P = self.getP(w)
        sm = self.semsets
        
        return self.test(
            {
                'name': 'demon',
                'pattern': 'adjacent forward',
                'roles': {'demon': w, 'head': P(1)},
                'conds': {
                    'F.sp.v(w) == prde':
                        self.F.sp.v(w) == 'prde',
                    'P(-1,sp) != art': # ensure not part of attrib pattern
                        P(-1,'sp') != 'art',
                    'P(-1) not in preps': # ensure not a part of particle
                        P(-1) not in sm.preps,
                    'bool(P(1))':
                        bool(P(1)),
                    'P(1) in noms':
                        P(1) in sm.noms,
                }
            }
        )

# %%
G = NounConstructions(wsets, A)
test = G.attrib(180817)

# %%
showmatch(test)
# Out:
# <p><b>result</b> <i>1448635 -> CX attrib {180817, 180818, 180819, 180820}</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=6&amp;verse=38&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="1_Kings 6:38">1_Kings 6:38</a>
# <div class="atoms  " >
# <a href="#" class="nd">756022</a>
#
#
#
# <div class="patom  l " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=6&amp;verse=38&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 6:38" sec="1_Kings 6:38">phrase</a> <a href="#" class="nd">756022</a>  <span class="function">Time</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <a href="#" class="nd">180816</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="show this lexeme in SHEBANQ">בַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=6&amp;verse=38&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 6:38" sec="1_Kings 6:38">prep</a></span> <span class="gloss">in</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: pink;" >
# <a href="#" class="nd">180817</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="show this lexeme in SHEBANQ"></a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=6&amp;verse=38&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 6:38" sec="1_Kings 6:38">art</a></span> <span class="gloss">the</span> <span class="sp xft"><span class="f">sp=</span>art</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: pink;" >
# <a href="#" class="nd">180818</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CNHn" title="show this lexeme in SHEBANQ">שָּׁנָה֩ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=6&amp;verse=38&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 6:38" sec="1_Kings 6:38">subs</a></span> <span class="gloss">year</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">180819</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="show this lexeme in SHEBANQ">הָ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=6&amp;verse=38&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 6:38" sec="1_Kings 6:38">art</a></span> <span class="gloss">the</span> <span class="sp xft"><span class="f">sp=</span>art</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">180820</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1AXDn" title="show this lexeme in SHEBANQ">אַחַ֨ת </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=6&amp;verse=38&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 6:38" sec="1_Kings 6:38">subs</a></span> <span class="gloss">one</span> <span class="ls xft"><span class="f">ls=</span>card</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>c</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">180821</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1OFRHn" title="show this lexeme in SHEBANQ">עֶשְׂרֵ֜ה </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=6&amp;verse=38&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 6:38" sec="1_Kings 6:38">subs</a></span> <span class="gloss">-teen</span> <span class="ls xft"><span class="f">ls=</span>card</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=6&amp;verse=38&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 6:38" sec="1_Kings 6:38">phrase</a> <a href="#" class="nd">756022</a>  <span class="function">Time</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <a href="#" class="nd">180822</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="show this lexeme in SHEBANQ">בְּ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=6&amp;verse=38&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 6:38" sec="1_Kings 6:38">prep</a></span> <span class="gloss">in</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">180823</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1JRXn" title="show this lexeme in SHEBANQ">יֶ֣רַח </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=6&amp;verse=38&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 6:38" sec="1_Kings 6:38">subs</a></span> <span class="gloss">month</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>c</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">180824</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1BWLin" title="show this lexeme in SHEBANQ">בּ֗וּל </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=6&amp;verse=38&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 6:38" sec="1_Kings 6:38">nmpr</a></span> <span class="gloss">Bul</span> <span class="sp xft"><span class="f">sp=</span>nmpr</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <div style="background: pink; text-align: center">head</div>
# <div style="background: lightblue; text-align: center">attrib</div>
# {   '__cx__': 'attrib',
#     'attrib': {'__cx__': 'defi', 'defi': 180819, 'head': 180820},
#     'head': {'__cx__': 'defi', 'defi': 180817, 'head': 180818}}
#
# cnds:
# bool(defi1)                                              True
# bool(defi2)                                              True
# <hr>

# %%
prettyconds(test.cases)
# Out:
# cnds:
# bool(defi1)                                              True
# bool(defi2)                                              True

# %%
#test_search(G.attrib, show=100, end=50)

# %% [markdown]
# ## Combine Constructions
#
# For now we have delimited a set of standard noun constructions. But there are many overlapping or incomplete constructions. For instance, a prepositional construction consisting of the following phrase (space-separated for accuracy):
#
# > ב ה יום
#
# The prepositional construction, as it stands, will only recognize the first word in front of the preposition, yielding the following construction:
#
# > ב ה
#
# The reason is because ה must **first** be united with its remaining elements. We need an **order of operations** to complete this procedure. That is, a list of global priorities that tells the chunker algorithm what parts to merge first. The beginning or ends of overlapping constructions can subsequently be used to link the parts together. For instance, not only do we have a preposition construction, we also have a definite construction which recognizes:
#
# > ה יום
#
# If the definite construction has priority over the preposition construction, the algorithm can gather all of the requisite pieces before placing it in relation to the preposition.
#
# ### Set Logic
#
# We can use set logic to determine when constructions overlap in their containing slots. Constructions that are wholly contained in another construction might also need to be abolished. That is the case with the attributive adjective construction for instance:
#
# > ה יום ה שׁבעי
#
# This construction already calls the definite construction as a condition for existence and contains it in its `slots` attribute. In this case, the algorithm should not create two separate instances of the definite constructions.
#
# ### Build Constructions
#
# Before we can make the chunks, we need to run the `NounConstructions` builder on the corpus. We do that below and store the resulting `Construction` objects in a phrase2construction mapping. This takes approximately 2 mins on a 2017 Macbook pro.

# %%
phrase2cx = collections.defaultdict(list)
nocxs = []

G = NounConstructions(wsets, A)

# time it
start = datetime.now()

print(f'{datetime.now()-start} beginning analysis...')

for i, phrase in enumerate(timephrases):
     
    # analyze all known relas
    for w in L.d(phrase, 'word'):
        constructions = G.findall(w)
        if constructions:
            phrase2cx[phrase].extend(constructions)
        
    # save those phrases that have no matching constructions
    if phrase not in phrase2cx:
        nocxs.append(phrase)
        
    # report status
    if i % 500 == 0 and i:
        print(f'\t{datetime.now()-start}\tdone with iter {i}/{len(timephrases)}')
        
print(f'{datetime.now()-start}\tCOMPLETE')
# Out:
# 0:00:00.000039 beginning analysis...
# 	0:00:33.321868	done with iter 500/2102
# 	0:01:01.729406	done with iter 1000/2102
# 	0:01:40.465782	done with iter 1500/2102
# 	0:02:11.904552	done with iter 2000/2102
# 0:02:19.581734	COMPLETE

# %%
print(f'{len(phrase2cx)} phrases matched with Constructions...')
print(f'{len(nocxs)} phrases not yet matched with Constructions...')
# Out:
# 2073 phrases matched with Constructions...
# 29 phrases not yet matched with Constructions...

# %% [markdown]
# <hr>
#
# #### OLD CODE

# %%
#     # replace role in cx1 with cx2
#     elif (
#         link_cx1role != 'head'
#         and link_cx2role == 'head'
#         and not (cx1.slots - cx2.slots) # expand not shrink
#     ):
#         print(f'****I AM HERE****: {cx1} <- {cx2}')
#         cx1.updaterole(link_cx1role, cx2)
#         return weaveCX(cxlist, cx1)
        
    # replace the role in cx2 with cx1
#     if (
#         link_cx1role != 'head'
#         and link_cx2role != 'head' or (cx1.slots - cx2.slots)
#     ):
        
    
    # connect broken links
#     if not link:
#         debugmess(f'\t no explicit link between {cx1} and {cx2}', debug)
#         debugmess(f'\t\t attempting cxlist {cxlist} with {cx2}', debug)   
#         cx2 = weaveCX(cxlist, cx2, debug=debug) # compile the rest of the cx
#         debugmess(f'\t\t connecting {cx1} and {cx2}', debug)
#         return weaveCX([cx2], cx1, debug=debug) # attempt to connect cx1 and 2 again

    

    
        
#         debugmess(f'\t\t result is {cx1} with roles: {cx1.roles.dict}', debug)
#         return weaveCX(cxlist, cx1, debug=debug)

# %% [markdown]
# <hr>

# %%
def sort_cxs(cxlist):
    """Sort constructions based on order of priority."""
    order = ['attrib', 'defi', 'adjv', 'advb', 'demon', 'card_chain', 'numb', 'geni', 'prep']
    sort = sorted(
        (order.index(cx.name),) + tuple(sorted(-(s) for s in cx.slots)) + (cx,) for cx in cxlist
    )
    return [item[-1] for item in sort]

def buildclusters(cxlist):
    """Find all overlapping constructions"""
    
    clusters = []
    cxlist = [i for i in cxlist] # protect overwrite
    
    # iterate until no more intersections found
    thiscluster = [cxlist.pop(0)]
    theseslots = set(s for s in thiscluster[0].slots)
    
    # loop continues as it snowballs and picks up slots
    # loop stops when a complete loop produces no other matches
    while cxlist:
        
        matched = False # whether loop was successful
        
        for cx in cxlist:
            if theseslots & cx.slots:
                thiscluster.append(cx)
                theseslots |= cx.slots
                matched = True
        
        cxlist = [cx for cx in cxlist if cx not in thiscluster]
        
        # assemble loop
        if not matched:
            clusters.append(thiscluster)
            thiscluster = [cxlist.pop(0)]
            theseslots = set(s for s in thiscluster[0].slots)
            
    clusters.append(thiscluster)
            
    return clusters

def arrange_cxs(cxlist):
    """Clusters and orders constructions."""
    return [sort_cxs(clist) for clist in buildclusters(cxlist)]
            
def getcxs(phrase, debug=False):
    """Gather constructions mapped to nodes."""
    cxlists = arrange_cxs(phrase2cx[phrase])
    for cxlist in cxlists:
        yield weaveCX(cxlist, debug=debug)
    
def debugmess(msg, toggle):
    """Prints debugging messages if toggled."""
    if toggle:
        sys.stderr.write(msg+'\n')
            
def weaveCX(cxlist, cx=None, debug=False):
    """Weave together constructions on their intersections."""
                
    debugmess(f'\nReceived {cx} with cxlist {cxlist}', debug)
        
    # the search is complete, stop here
    if not cxlist:
        debugmess(f'\tSearch complete with {cx} with roles: {cx.roles.dict}', debug)
        return cx
    # or no search necessary, stop here
    elif cx is None and len(cxlist) == 1:
        return cxlist[0]
    
    # Copy constructions and operate on copies
    cx1 = cx or copy.deepcopy(cxlist.pop(0))
    cx2 = copy.deepcopy(cxlist.pop(0))
    
    debugmess(f'\t comparing {cx1} & {cx2}', debug)
        
    # get first slot of intersection between cx1 and 2
    # get that slot's role in both cxs
    link = next(iter(cx1.slots & cx2.slots), None)
    link1role = cx1.getslotrole(link)
    link2role = cx2.getslotrole(link)
    
    debugmess(f'\t link is {link}', debug)
    debugmess(f'\t\t link role in cx1 is {link1role}', debug)
    debugmess(f'\t\t link role in cx2 is {link2role}', debug)
        
    # discard cx2 if fully covered by cx1
    if cx1.slots.issuperset(cx2.slots):
        debugmess(f'\t discarding {cx2} since it is covered', debug)
        return weaveCX(cxlist, cx1, debug=debug)
    
    # replace role in cx2 with all of cx1
    else:
        debugmess(f'\t replacing role [{link2role}] in cx2 with cx1 [{cx1}]', debug)
        cx2.updaterole(link2role, cx1)
        debugmess(f'\t\t result is {cx2} with roles: {cx2.roles.dict}', debug)
        return weaveCX(cxlist, cx2, debug=debug)

# %%
test = 1450222
#test = 1447886
#test = 1446854

pretty(test)
# Out:
# <p><b>result</b> <i>1450222</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=9&amp;verse=26&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Daniel 9:26">Daniel 9:26</a>
# <div class="atoms  " >
# <a href="#" class="nd">880181</a>
#
#
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=9&amp;verse=26&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Daniel 9:26" sec="Daniel 9:26">phrase</a> <a href="#" class="nd">880181</a>  <span class="function">Time</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <a href="#" class="nd">376375</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1AXRn" title="show this lexeme in SHEBANQ">אַחֲרֵ֤י </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=9&amp;verse=26&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Daniel 9:26" sec="Daniel 9:26">prep</a></span> <span class="gloss">after</span> <span class="ls xft"><span class="f">ls=</span>ppre</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>c</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">376376</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=9&amp;verse=26&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Daniel 9:26" sec="Daniel 9:26">art</a></span> <span class="gloss">the</span> <span class="sp xft"><span class="f">sp=</span>art</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">376377</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CBWOn" title="show this lexeme in SHEBANQ">שָּׁבֻעִים֙ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=9&amp;verse=26&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Daniel 9:26" sec="Daniel 9:26">subs</a></span> <span class="gloss">week</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">376378</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CCn" title="show this lexeme in SHEBANQ">שִׁשִּׁ֣ים </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=9&amp;verse=26&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Daniel 9:26" sec="Daniel 9:26">subs</a></span> <span class="gloss">six</span> <span class="ls xft"><span class="f">ls=</span>card</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">376379</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="show this lexeme in SHEBANQ">וּ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=9&amp;verse=26&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Daniel 9:26" sec="Daniel 9:26">conj</a></span> <span class="gloss">and</span> <span class="sp xft"><span class="f">sp=</span>conj</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">376380</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CNJMn" title="show this lexeme in SHEBANQ">שְׁנַ֔יִם </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=9&amp;verse=26&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Daniel 9:26" sec="Daniel 9:26">subs</a></span> <span class="gloss">two</span> <span class="ls xft"><span class="f">ls=</span>card</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>

# %%
arranged = arrange_cxs(phrase2cx[test])[0]

arranged
# Out:
# [CX defi {376376, 376377},
#  CX card_chain {376378, 376379, 376380},
#  CX numb {376377, 376378},
#  CX prep {376376, 376375}]

# %%
# arranged = test_sort([arranged[4], arranged[3], arranged[0]])

# arranged

# %% [markdown]
# ### TODO:
#
# Decide how to assign precedence without breaking links.

# %%
match = weaveCX(arranged, debug=True)
# Out:
# Received None with cxlist [CX numb {376377, 376378}, CX prep {376376, 376375}]
# 	 comparing CX numb {376377, 376378} & CX prep {376376, 376375}
# 	 link is None
# 		 link role in cx1 is None
# 		 link role in cx2 is None
# 	 replacing role [None] in cx2 with cx1 [CX numb {376377, 376378}]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-516-8aad2963fe0c> in <module>()
# ----> 1 match = weaveCX(arranged, debug=True)
#
# <ipython-input-510-dea99811010e> in weaveCX(cxlist, cx, debug)
#      93     else:
#      94         debugmess(f'\t replacing role [{link2role}] in cx2 with cx1 [{cx1}]', debug)
# ---> 95         cx2.updaterole(link2role, cx1)
#      96         debugmess(f'\t\t result is {cx2} with roles: {cx2.roles.dict}', debug)
#      97         return weaveCX(cxlist, cx2, debug=debug)
#
# <ipython-input-79-1df1688eca9a> in updaterole(self, role, item)
#      84     def updaterole(self, role, item):
#      85         """Updates the role."""
# ---> 86         setattr(self.roles, role, item)
#      87         self.roles.dict[role] = item
#      88
#
# TypeError: attribute name must be string, not 'NoneType'

# %%
showmatch(match)
# Out:
# <p><b>result</b> <i>1450222 -> CX prep {376375, 376376, 376377, 376378, 376379, 376380}</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=9&amp;verse=26&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Daniel 9:26">Daniel 9:26</a>
# <div class="atoms  " >
# <a href="#" class="nd">880181</a>
#
#
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=9&amp;verse=26&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Daniel 9:26" sec="Daniel 9:26">phrase</a> <a href="#" class="nd">880181</a>  <span class="function">Time</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  hl"  style="background-color: pink;" >
# <a href="#" class="nd">376375</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1AXRn" title="show this lexeme in SHEBANQ">אַחֲרֵ֤י </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=9&amp;verse=26&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Daniel 9:26" sec="Daniel 9:26">prep</a></span> <span class="gloss">after</span> <span class="ls xft"><span class="f">ls=</span>ppre</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>c</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">376376</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=9&amp;verse=26&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Daniel 9:26" sec="Daniel 9:26">art</a></span> <span class="gloss">the</span> <span class="sp xft"><span class="f">sp=</span>art</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">376377</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CBWOn" title="show this lexeme in SHEBANQ">שָּׁבֻעִים֙ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=9&amp;verse=26&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Daniel 9:26" sec="Daniel 9:26">subs</a></span> <span class="gloss">week</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">376378</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CCn" title="show this lexeme in SHEBANQ">שִׁשִּׁ֣ים </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=9&amp;verse=26&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Daniel 9:26" sec="Daniel 9:26">subs</a></span> <span class="gloss">six</span> <span class="ls xft"><span class="f">ls=</span>card</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">376379</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="show this lexeme in SHEBANQ">וּ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=9&amp;verse=26&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Daniel 9:26" sec="Daniel 9:26">conj</a></span> <span class="gloss">and</span> <span class="sp xft"><span class="f">sp=</span>conj</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">376380</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CNJMn" title="show this lexeme in SHEBANQ">שְׁנַ֔יִם </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Daniel&amp;chapter=9&amp;verse=26&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Daniel 9:26" sec="Daniel 9:26">subs</a></span> <span class="gloss">two</span> <span class="ls xft"><span class="f">ls=</span>card</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <div style="background: pink; text-align: center">prep</div>
# <div style="background: lightblue; text-align: center">head</div>
# {   '__cx__': 'prep',
#     'head': {   '__cx__': 'defi',
#                 'defi': 376376,
#                 'head': {   '__cx__': 'numb',
#                             'head': 376377,
#                             'numb': {   '__cx__': 'card_chain',
#                                         'card': 376380,
#                                         'conj': 376379,
#                                         'head': 376378}}},
#     'prep': 376375}
#
# cnds:
# w in preps                                               True
# F.prs.v(w) == absent                                     True
# bool(P(1))                                               True
# <hr>

# %%
def makepath(cxlist):
    """Construct a bottom-up path for construction merging.
    
    Overlapping constructions should be combined at their
    point of intersection, with one construction taking on
    the role of the other. Linguistically speaking this can
    be thought of as "slot filling," where another construction
    comes to fill the slot or role of a another. 
    
    In this procedure, simpler constructions should be combined first
    (bottom-up). The order should be followed without compromising links. 
    
    For instance, 
    [CX attrib {115232, 115233, 115230, 115231},
     CX prep {115228, 115229},
     CX prep {115229, 115230}]
    """
    
    order = {
        'attrib': 1, 
        'adjv': 2, 
        'defi': 3,
        'advb': 4, 
        'demon': 4, 
        'card_chain': 5, 
        'numb': 6, 
        'geni': 7, 
        'prep': 8,
    }
    
    
    
    sort = sorted(
        (order.index(cx.name),) + tuple(cx.slots) + (cx,) for cx in cxlist
    )
    return [item[-1] for item in sort]

# %%
# matches = []
# for m in getcxs(test, debug=True):
#     showmatch(m)
#     matches.append(m)

# %% [markdown]
# ## Test Cases

# %%
A.pretty(1020587)
# Out:
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=16&amp;verse=29&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="1_Kings 16:29">1_Kings 16:29</a>
# <div class="patom  l " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=16&amp;verse=29&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 16:29" sec="1_Kings 16:29">phrase</a> <a href="#" class="nd">760754</a>  <span class="function">Time</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <a href="#" class="nd">189681</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="show this lexeme in SHEBANQ">בִּ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=16&amp;verse=29&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 16:29" sec="1_Kings 16:29">prep</a></span> <span class="gloss">in</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">189682</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CNHn" title="show this lexeme in SHEBANQ">שְׁנַ֨ת </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=16&amp;verse=29&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 16:29" sec="1_Kings 16:29">subs</a></span> <span class="gloss">year</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>c</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">189683</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CLCn" title="show this lexeme in SHEBANQ">שְׁלֹשִׁ֤ים </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=16&amp;verse=29&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 16:29" sec="1_Kings 16:29">subs</a></span> <span class="gloss">three</span> <span class="ls xft"><span class="f">ls=</span>card</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">189684</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="show this lexeme in SHEBANQ">וּ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=16&amp;verse=29&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 16:29" sec="1_Kings 16:29">conj</a></span> <span class="gloss">and</span> <span class="sp xft"><span class="f">sp=</span>conj</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">189685</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CMNHn" title="show this lexeme in SHEBANQ">שְׁמֹנֶה֙ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=16&amp;verse=29&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 16:29" sec="1_Kings 16:29">subs</a></span> <span class="gloss">eight</span> <span class="ls xft"><span class="f">ls=</span>card</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">189686</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CNHn" title="show this lexeme in SHEBANQ">שָׁנָ֔ה </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_I&amp;chapter=16&amp;verse=29&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="1_Kings 16:29" sec="1_Kings 16:29">subs</a></span> <span class="gloss">year</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>

# %%
arrange_cxs(phrase2cx[L.u(1020587,'timephrase')[0]])
# Out:
# [[CX card_chain {189683, 189684, 189685},
#   CX numb {189685, 189686},
#   CX geni {189682, 189683},
#   CX prep {189681, 189682}],
#  [CX prep {189688, 189687}],
#  [CX geni {189689, 189690}]]

# %%
A.pretty(906959)
# Out:
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=8&amp;verse=13&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Genesis 8:13">Genesis 8:13</a>
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=8&amp;verse=13&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 8:13" sec="Genesis 8:13">phrase</a> <a href="#" class="nd">653659</a>  <span class="function">Time</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <a href="#" class="nd">3799</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="show this lexeme in SHEBANQ">בְּ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=8&amp;verse=13&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 8:13" sec="Genesis 8:13">prep</a></span> <span class="gloss">in</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3800</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1AXDn" title="show this lexeme in SHEBANQ">אַחַ֨ת </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=8&amp;verse=13&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 8:13" sec="Genesis 8:13">subs</a></span> <span class="gloss">one</span> <span class="ls xft"><span class="f">ls=</span>card</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3801</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="show this lexeme in SHEBANQ">וְ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=8&amp;verse=13&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 8:13" sec="Genesis 8:13">conj</a></span> <span class="gloss">and</span> <span class="sp xft"><span class="f">sp=</span>conj</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3802</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CCn" title="show this lexeme in SHEBANQ">שֵׁשׁ־</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=8&amp;verse=13&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 8:13" sec="Genesis 8:13">subs</a></span> <span class="gloss">six</span> <span class="ls xft"><span class="f">ls=</span>card</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>c</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3803</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1MAHn" title="show this lexeme in SHEBANQ">מֵאֹ֜ות </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=8&amp;verse=13&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 8:13" sec="Genesis 8:13">subs</a></span> <span class="gloss">hundred</span> <span class="ls xft"><span class="f">ls=</span>card</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">3804</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CNHn" title="show this lexeme in SHEBANQ">שָׁנָ֗ה </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=8&amp;verse=13&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 8:13" sec="Genesis 8:13">subs</a></span> <span class="gloss">year</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>

# %%
cx_906959 = L.u(906959, 'timephrase')[0]
print(cx_906959)

arrange_cxs(phrase2cx[cx_906959])
# Out:
# 1446854
# [[CX card_chain {3800, 3801, 3802},
#   CX card_chain {3802, 3803},
#   CX numb {3803, 3804},
#   CX prep {3800, 3799}],
#  [CX defi {3806, 3807}, CX prep {3805, 3806}],
#  [CX prep {3808, 3809}],
#  [CX defi {3811, 3812}, CX prep {3810, 3811}]]

# %%
A.pretty(905154)
# Out:
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=2&amp;verse=2&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Genesis 2:2">Genesis 2:2</a>
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=2&amp;verse=2&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 2:2" sec="Genesis 2:2">phrase</a> <a href="#" class="nd">651923</a>  <span class="function">Time</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <a href="#" class="nd">687</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="show this lexeme in SHEBANQ">בַּ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=2&amp;verse=2&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 2:2" sec="Genesis 2:2">prep</a></span> <span class="gloss">in</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">688</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="show this lexeme in SHEBANQ"></a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=2&amp;verse=2&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 2:2" sec="Genesis 2:2">art</a></span> <span class="gloss">the</span> <span class="sp xft"><span class="f">sp=</span>art</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">689</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1JWMn" title="show this lexeme in SHEBANQ">יֹּ֣ום </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=2&amp;verse=2&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 2:2" sec="Genesis 2:2">subs</a></span> <span class="gloss">day</span> <span class="ls xft"><span class="f">ls=</span>padv</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">690</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=2&amp;verse=2&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 2:2" sec="Genesis 2:2">art</a></span> <span class="gloss">the</span> <span class="sp xft"><span class="f">sp=</span>art</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">691</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CBJOJn" title="show this lexeme in SHEBANQ">שְּׁבִיעִ֔י </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=2&amp;verse=2&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 2:2" sec="Genesis 2:2">adjv</a></span> <span class="gloss">seventh</span> <span class="ls xft"><span class="f">ls=</span>ordn</span> <span class="sp xft"><span class="f">sp=</span>adjv</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>

# %%
cx_905154 = L.u(905154, 'timephrase')[0]
print(cx_905154)

arrange_cxs(phrase2cx[cx_905154])
# Out:
# 1446801
# [[CX attrib {688, 689, 690, 691},
#   CX defi {688, 689},
#   CX defi {690, 691},
#   CX prep {688, 687}]]

# %%
A.pretty(974016)
# Out:
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Josua&amp;chapter=5&amp;verse=11&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Joshua 5:11">Joshua 5:11</a>
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Josua&amp;chapter=5&amp;verse=11&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Joshua 5:11" sec="Joshua 5:11">phrase</a> <a href="#" class="nd">717001</a>  <span class="function">Time</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <a href="#" class="nd">115228</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="show this lexeme in SHEBANQ">בְּ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Josua&amp;chapter=5&amp;verse=11&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Joshua 5:11" sec="Joshua 5:11">prep</a></span> <span class="gloss">in</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">115229</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1OYMn" title="show this lexeme in SHEBANQ">עֶ֖צֶם </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Josua&amp;chapter=5&amp;verse=11&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Joshua 5:11" sec="Joshua 5:11">subs</a></span> <span class="gloss">bone</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>c</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">115230</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Josua&amp;chapter=5&amp;verse=11&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Joshua 5:11" sec="Joshua 5:11">art</a></span> <span class="gloss">the</span> <span class="sp xft"><span class="f">sp=</span>art</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">115231</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1JWMn" title="show this lexeme in SHEBANQ">יֹּ֥ום </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Josua&amp;chapter=5&amp;verse=11&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Joshua 5:11" sec="Joshua 5:11">subs</a></span> <span class="gloss">day</span> <span class="ls xft"><span class="f">ls=</span>padv</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">115232</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Josua&amp;chapter=5&amp;verse=11&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Joshua 5:11" sec="Joshua 5:11">art</a></span> <span class="gloss">the</span> <span class="sp xft"><span class="f">sp=</span>art</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">115233</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1ZH" title="show this lexeme in SHEBANQ">זֶּֽה׃ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Josua&amp;chapter=5&amp;verse=11&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Joshua 5:11" sec="Joshua 5:11">prde</a></span> <span class="gloss">this</span> <span class="sp xft"><span class="f">sp=</span>prde</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>

# %%
cx_974016 = L.u(974016, 'timephrase')[0]
print(cx_974016)
arrange_cxs(phrase2cx[cx_974016])
# Out:
# 1447886
# [[CX attrib {115232, 115233, 115230, 115231},
#   CX defi {115230, 115231},
#   CX defi {115232, 115233},
#   CX prep {115228, 115229},
#   CX prep {115229, 115230}]]

# %% [markdown]
# ## Testing Construction Builds

# %% [markdown]
# ### No Matches

# %%
# for ph in nocxs:
#     pretty(ph, extraFeatures='sp')

# %% [markdown]
# ### Gaps

# %%
# analyze all phrases

cxanalyzed = {}

start = datetime.now()

print(f'{datetime.now()-start} beginning analysis...')

analyze = list(phrase2cx.keys())
random.shuffle(analyze)

for ph in analyze:

    try:
        # get analyzed phrases
        cxanalyzed[ph] = list(getcxs(ph))
    except:
        raise Exception(f'Fail on {ph}')
    
    # report status
    if i % 500 == 0 and i:
        print(f'\t{datetime.now()-start}\tdone with iter {i}/{len(timephrases)}')

print(f'{datetime.now()-start} COMPLETE.')
# Out:
# 0:00:00.000043 beginning analysis...
# No explicit link between CX attrib {66440, 66441, 66438, 66439} and CX prep {66436, 66437}
# 	attempt connect CX attrib {66440, 66441, 66438, 66439} and CX prep {66436, 66437, 66438}
# No explicit link between CX defi {4017, 4018} and CX numb {4016, 4015}
# 	attempt connect CX defi {4017, 4018} and CX geni {4016, 4017, 4015}
# No explicit link between CX numb {22262, 22263} and CX prep {22260, 22261}
# 	attempt connect CX numb {22262, 22263} and CX prep {22260, 22261, 22262}
# No explicit link between CX geni {207924, 207925} and CX prep {207922, 207923}
# 	attempt connect CX geni {207924, 207925} and CX prep {207922, 207923, 207924}
# No explicit link between CX defi {378145, 378146} and CX prep {378144, 378143}
# 	attempt connect CX defi {378145, 378146} and CX prep {378144, 378145, 378143}
# No explicit link between CX numb {78209, 78210} and CX prep {78208, 78207}
# 	attempt connect CX numb {78209, 78210} and CX prep {78208, 78209, 78207}
# No explicit link between CX numb {410611, 410612} and CX prep {410609, 410610}
# 	attempt connect CX numb {410611, 410612} and CX prep {410609, 410610, 410611}
# No explicit link between CX numb {257950, 257951} and CX prep {257948, 257949}
# 	attempt connect CX numb {257950, 257951} and CX prep {257948, 257949, 257950}
# No explicit link between CX defi {172592, 172591} and CX prep {172589, 172590}
# 	attempt connect CX defi {172592, 172591} and CX prep {172589, 172590, 172591}
# No explicit link between CX defi {377198, 377199} and CX prep {377196, 377197}
# 	attempt connect CX defi {377198, 377199} and CX prep {377196, 377197, 377198}
# No explicit link between CX numb {7082, 7083} and CX prep {7080, 7081}
# 	attempt connect CX numb {7082, 7083} and CX prep {7080, 7081, 7082}
# No explicit link between CX numb {3658, 3659} and CX prep {3656, 3657}
# 	attempt connect CX numb {3658, 3659} and CX prep {3656, 3657, 3658}
# No explicit link between CX defi {23013, 23014} and CX numb {23011, 23012}
# 	attempt connect CX defi {23013, 23014} and CX prep {23010, 23011, 23012, 23013}
# No explicit link between CX defi {390981, 390982} and CX prep {390979, 390980}
# 	attempt connect CX defi {390981, 390982} and CX prep {390979, 390980, 390981}
# No explicit link between CX attrib {265376, 265377, 265374, 265375} and CX prep {265372, 265373}
# 	attempt connect CX attrib {265376, 265377, 265374, 265375} and CX prep {265372, 265373, 265374}
# No explicit link between CX defi {162482, 162483} and CX prep {162480, 162481}
# 	attempt connect CX defi {162482, 162483} and CX prep {162480, 162481, 162482}
# No explicit link between CX numb {219611, 219612} and CX prep {219609, 219610}
# 	attempt connect CX numb {219611, 219612} and CX prep {219609, 219610, 219611}
# No explicit link between CX attrib {66480, 66481, 66482, 66483} and CX prep {66478, 66479}
# 	attempt connect CX attrib {66480, 66481, 66482, 66483} and CX prep {66480, 66478, 66479}
# No explicit link between CX numb {370397, 370398} and CX prep {370395, 370396}
# 	attempt connect CX numb {370397, 370398} and CX prep {370395, 370396, 370397}
# No explicit link between CX defi {304873, 304874} and CX prep {304872, 304871}
# 	attempt connect CX defi {304873, 304874} and CX prep {304872, 304873, 304871}
# No explicit link between CX defi {23221, 23222} and CX numb {23219, 23220}
# 	attempt connect CX defi {23221, 23222} and CX prep {23218, 23219, 23220, 23221}
# No explicit link between CX attrib {66464, 66465, 66462, 66463} and CX prep {66460, 66461}
# 	attempt connect CX attrib {66464, 66465, 66462, 66463} and CX prep {66460, 66461, 66462}
# No explicit link between CX adjv {241245, 241246} and CX prep {241243, 241244}
# 	attempt connect CX adjv {241245, 241246} and CX prep {241243, 241244, 241245}
# No explicit link between CX numb {214401, 214402, 214403, 214404} and CX prep {214400, 214399}
# 	attempt connect CX numb {214401, 214402, 214403, 214404} and CX prep {214400, 214401, 214399}
# No explicit link between CX geni {310292, 310293} and CX prep {310290, 310291}
# 	attempt connect CX geni {310292, 310293} and CX prep {310290, 310291, 310292}
# No explicit link between CX numb {110881, 110882} and CX prep {110880, 110879}
# 	attempt connect CX numb {110881, 110882} and CX prep {110880, 110881, 110879}
# No explicit link between CX defi {110886, 110887} and CX geni {110884, 110885}
# 	attempt connect CX defi {110886, 110887} and CX prep {110883, 110884, 110885, 110886}
# No explicit link between CX numb {98690, 98691} and CX prep {98688, 98689}
# 	attempt connect CX numb {98690, 98691} and CX prep {98688, 98689, 98690}
# No explicit link between CX defi {399240, 399239} and CX prep {399236, 399237}
# 	attempt connect CX defi {399240, 399239} and CX prep {399236, 399237, 399238, 399239}
# No explicit link between CX numb {21277, 21278} and CX prep {21275, 21276}
# 	attempt connect CX numb {21277, 21278} and CX prep {21275, 21276, 21277}
# No explicit link between CX numb {284640, 284641} and CX prep {284638, 284639}
# 	attempt connect CX numb {284640, 284641} and CX prep {284640, 284638, 284639}
# No explicit link between CX defi {217248, 217247} and CX geni {217245, 217246}
# 	attempt connect CX defi {217248, 217247} and CX prep {217244, 217245, 217246, 217247}
# No explicit link between CX numb {206714, 206715} and CX prep {206712, 206713}
# 	attempt connect CX numb {206714, 206715} and CX prep {206712, 206713, 206714}
# No explicit link between CX attrib {35748, 35749, 35750, 35751} and CX prep {35746, 35747}
# 	attempt connect CX attrib {35748, 35749, 35750, 35751} and CX prep {35746, 35747, 35748}
# No explicit link between CX attrib {3280, 3277, 3278, 3279} and CX prep {3275, 3276}
# 	attempt connect CX attrib {3280, 3277, 3278, 3279} and CX prep {3275, 3276, 3277}
# No explicit link between CX attrib {7777, 7778, 7779, 7780} and CX prep {7776, 7775}
# 	attempt connect CX attrib {7777, 7778, 7779, 7780} and CX prep {7776, 7777, 7775}
# No explicit link between CX defi {295412, 295413} and CX prep {295410, 295411}
# 	attempt connect CX defi {295412, 295413} and CX prep {295410, 295411, 295412}
# No explicit link between CX numb {175608, 175609} and CX prep {175606, 175607}
# 	attempt connect CX numb {175608, 175609} and CX prep {175608, 175606, 175607}
# No explicit link between CX attrib {66307, 66308, 66309, 66310} and CX prep {66305, 66306}
# 	attempt connect CX attrib {66307, 66308, 66309, 66310} and CX prep {66305, 66306, 66307}
# No explicit link between CX numb {219636, 219637} and CX prep {219634, 219635}
# 	attempt connect CX numb {219636, 219637} and CX prep {219634, 219635, 219636}
# No explicit link between CX numb {118069, 118070} and CX prep {118067, 118068}
# 	attempt connect CX numb {118069, 118070} and CX prep {118067, 118068, 118069}
# No explicit link between CX defi {77520, 77519} and CX numb {77517, 77518}
# 	attempt connect CX defi {77520, 77519} and CX geni {77517, 77518, 77519}
# No explicit link between CX defi {404888, 404887} and CX numb {404885, 404886}
# 	attempt connect CX defi {404888, 404887} and CX prep {404884, 404885, 404886, 404887}
# No explicit link between CX attrib {112120, 112121, 112122, 112123} and CX prep {112118, 112119}
# 	attempt connect CX attrib {112120, 112121, 112122, 112123} and CX prep {112120, 112118, 112119}
# No explicit link between CX numb {3607, 3608, 3609, 3610} and CX prep {3605, 3606}
# 	attempt connect CX numb {3607, 3608, 3609, 3610} and CX prep {3605, 3606, 3607}
# No explicit link between CX numb {113970, 113971} and CX prep {113968, 113969}
# 	attempt connect CX numb {113970, 113971} and CX prep {113968, 113969, 113970}
# No explicit link between CX defi {288990, 288991} and CX numb {288988, 288989}
# 	attempt connect CX defi {288990, 288991} and CX geni {288988, 288989, 288990}
# No explicit link between CX attrib {276600, 276601, 276602, 276599} and CX prep {276597, 276598}
# 	attempt connect CX attrib {276600, 276601, 276602, 276599} and CX prep {276597, 276598, 276599}
# No explicit link between CX numb {22134, 22135} and CX prep {22132, 22133}
# 	attempt connect CX numb {22134, 22135} and CX prep {22132, 22133, 22134}
# No explicit link between CX defi {178843, 178844} and CX prep {178841, 178842}
# 	attempt connect CX defi {178843, 178844} and CX prep {178841, 178842, 178843}
# No explicit link between CX attrib {35064, 35065, 35062, 35063} and CX prep {35060, 35061}
# 	attempt connect CX attrib {35064, 35065, 35062, 35063} and CX prep {35060, 35061, 35062}
# No explicit link between CX attrib {284968, 284969, 284970, 284971} and CX prep {284966, 284967}
# 	attempt connect CX attrib {284968, 284969, 284970, 284971} and CX prep {284968, 284966, 284967}
# No explicit link between CX numb {101993, 101994} and CX prep {101992, 101991}
# 	attempt connect CX numb {101993, 101994} and CX prep {101992, 101993, 101991}
# No explicit link between CX attrib {66169, 66170, 66171, 66172} and CX prep {66168, 66167}
# 	attempt connect CX attrib {66169, 66170, 66171, 66172} and CX prep {66168, 66169, 66167}
# No explicit link between CX defi {289082, 289083} and CX numb {289080, 289081}
# 	attempt connect CX defi {289082, 289083} and CX geni {289080, 289081, 289082}
# No explicit link between CX defi {401594, 401595} and CX geni {401592, 401593}
# 	attempt connect CX defi {401594, 401595} and CX prep {401591, 401592, 401593, 401594}
# No explicit link between CX numb {338184, 338183} and CX prep {338181, 338182}
# 	attempt connect CX numb {338184, 338183} and CX prep {338181, 338182, 338183}
# No explicit link between CX geni {27437, 27438} and CX prep {27435, 27436}
# 	attempt connect CX geni {27437, 27438} and CX prep {27435, 27436, 27437}
# No explicit link between CX numb {296354, 296355} and CX prep {296352, 296353}
# 	attempt connect CX numb {296354, 296355} and CX prep {296352, 296353, 296354}
# No explicit link between CX defi {376376, 376377} and CX card_chain {376378, 376379, 376380}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# ...
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# No explicit link between CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# 	attempt connect CX numb {376377, 376378, 376379, 376380} and CX prep {376376, 376375}
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-231-9f9f28ca2c5d> in <module>()
#      15         # get analyzed phrases
# ---> 16         cxanalyzed[ph] = list(getcxs(ph))
#      17     except:
#
# <ipython-input-218-61e08558807a> in getcxs(phrase)
#      86     for cxlist in cxlists:
# ---> 87         yield weaveCX(cxlist)
#
# <ipython-input-218-61e08558807a> in weaveCX(cxlist, cx)
#      69         sys.stderr.write(f'No explicit link between {cx1} and {cx2}\n')
# ---> 70         cx2 = weaveCX(cxlist, cx2) # compile the rest of the cx
#      71         sys.stderr.write(f'\tattempt connect {cx1} and {cx2}\n')
#
# <ipython-input-218-61e08558807a> in weaveCX(cxlist, cx)
#      80         cx2.updaterole(link_cx2role, cx1)
# ---> 81         return weaveCX(cxlist, cx2)
#      82
#
# <ipython-input-218-61e08558807a> in weaveCX(cxlist, cx)
#      71         sys.stderr.write(f'\tattempt connect {cx1} and {cx2}\n')
# ---> 72         return weaveCX([cx2], cx1) # attempt to connect cx1 and 2 again
#      73
#
# <ipython-input-218-61e08558807a> in weaveCX(cxlist, cx)
#      71         sys.stderr.write(f'\tattempt connect {cx1} and {cx2}\n')
# ---> 72         return weaveCX([cx2], cx1) # attempt to connect cx1 and 2 again
#      73
#
# <ipython-input-218-61e08558807a> in weaveCX(cxlist, cx)
#      71         sys.stderr.write(f'\tattempt connect {cx1} and {cx2}\n')
# ---> 72         return weaveCX([cx2], cx1) # attempt to connect cx1 and 2 again
#      73
#
# <ipython-input-218-61e08558807a> in weaveCX(cxlist, cx)
#      71         sys.stderr.write(f'\tattempt connect {cx1} and {cx2}\n')
# ---> 72         return weaveCX([cx2], cx1) # attempt to connect cx1 and 2 again
#      73
#
# <ipython-input-218-61e08558807a> in weaveCX(cxlist, cx)
#      71         sys.stderr.write(f'\tattempt connect {cx1} and {cx2}\n')
# ---> 72         return weaveCX([cx2], cx1) # attempt to connect cx1 and 2 again
#      73
#
# <ipython-input-218-61e08558807a> in weaveCX(cxlist, cx)
#      71         sys.stderr.write(f'\tattempt connect {cx1} and {cx2}\n')
# ---> 72         return weaveCX([cx2], cx1) # attempt to connect cx1 and 2 again
#      73
#
# <ipython-input-218-61e08558807a> in weaveCX(cxlist, cx)
#      71         sys.stderr.write(f'\tattempt connect {cx1} and {cx2}\n')
# ---> 72         return weaveCX([cx2], cx1) # attempt to connect cx1 and 2 again
#      73
#
# ... last 7 frames repeated, from the frame below ...
#
# <ipython-input-218-61e08558807a> in weaveCX(cxlist, cx)
#      71         sys.stderr.write(f'\tattempt connect {cx1} and {cx2}\n')
# ---> 72         return weaveCX([cx2], cx1) # attempt to connect cx1 and 2 again
#      73
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-231-9f9f28ca2c5d> in <module>()
#      16         cxanalyzed[ph] = list(getcxs(ph))
#      17     except:
# ---> 18         raise Exception(f'Fail on {ph}')
#      19
#      20     # report status
#
# Exception: Fail on 1450222

# %% [markdown]
# ### Testing on Randoms

# %%
shuff = [ph for ph in phrase2cx.keys() 
            if len(L.d(ph, 'word')) > 2
        ]

random.shuffle(shuff)

# %%
for phrase in shuff[:25]:
    print(phrase)
    for cx in getcxs(phrase):
        showmatch(cx)
    print()
# Out:
# 1447408
# <p><b>result</b> <i>1447408 -> CX prep {64208, 64209, 64205, 64206, 64207}</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&amp;chapter=19&amp;verse=25&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Leviticus 19:25">Leviticus 19:25</a>
# <div class="atoms  " >
# <a href="#" class="nd">689102</a>
#
#
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&amp;chapter=19&amp;verse=25&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Leviticus 19:25" sec="Leviticus 19:25">phrase</a> <a href="#" class="nd">689102</a>  <span class="function">Time</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  hl"  style="background-color: pink;" >
# <a href="#" class="nd">64205</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="show this lexeme in SHEBANQ">בַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&amp;chapter=19&amp;verse=25&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Leviticus 19:25" sec="Leviticus 19:25">prep</a></span> <span class="gloss">in</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">64206</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="show this lexeme in SHEBANQ"></a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&amp;chapter=19&amp;verse=25&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Leviticus 19:25" sec="Leviticus 19:25">art</a></span> <span class="gloss">the</span> <span class="sp xft"><span class="f">sp=</span>art</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">64207</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CNHn" title="show this lexeme in SHEBANQ">שָּׁנָ֣ה </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&amp;chapter=19&amp;verse=25&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Leviticus 19:25" sec="Leviticus 19:25">subs</a></span> <span class="gloss">year</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">64208</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&amp;chapter=19&amp;verse=25&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Leviticus 19:25" sec="Leviticus 19:25">art</a></span> <span class="gloss">the</span> <span class="sp xft"><span class="f">sp=</span>art</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">64209</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1XMJCJn" title="show this lexeme in SHEBANQ">חֲמִישִׁ֗ת </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&amp;chapter=19&amp;verse=25&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Leviticus 19:25" sec="Leviticus 19:25">adjv</a></span> <span class="gloss">fifth</span> <span class="ls xft"><span class="f">ls=</span>ordn</span> <span class="sp xft"><span class="f">sp=</span>adjv</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <div style="background: pink; text-align: center">prep</div>
# <div style="background: lightblue; text-align: center">head</div>
# {   '__cx__': 'prep',
#     'head': {   '__cx__': 'attrib',
#                 'attrib': {'__cx__': 'defi', 'defi': 64208, 'head': 64209},
#                 'head': {'__cx__': 'defi', 'defi': 64206, 'head': 64207}},
#     'prep': 64205}
#
# cnds:
# w in preps                                               True
# F.prs.v(w) == absent                                     True
# bool(P(1))                                               True
# <hr>
# 1450676
# <p><b>result</b> <i>1450676 -> CX numb {426222, 426223}</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_II&amp;chapter=36&amp;verse=9&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="2_Chronicles 36:9">2_Chronicles 36:9</a>
# <div class="atoms  " >
# <a href="#" class="nd">904575</a>
#
#
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_II&amp;chapter=36&amp;verse=9&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="2_Chronicles 36:9" sec="2_Chronicles 36:9">phrase</a> <a href="#" class="nd">904575</a>  <span class="function">Time</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  hl"  style="background-color: pink;" >
# <a href="#" class="nd">426222</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CLCn" title="show this lexeme in SHEBANQ">שְׁלֹשָׁ֤ה </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_II&amp;chapter=36&amp;verse=9&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="2_Chronicles 36:9" sec="2_Chronicles 36:9">subs</a></span> <span class="gloss">three</span> <span class="ls xft"><span class="f">ls=</span>card</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">426223</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1XDCin" title="show this lexeme in SHEBANQ">חֳדָשִׁים֙ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_II&amp;chapter=36&amp;verse=9&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="2_Chronicles 36:9" sec="2_Chronicles 36:9">subs</a></span> <span class="gloss">month</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">426224</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="show this lexeme in SHEBANQ">וַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_II&amp;chapter=36&amp;verse=9&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="2_Chronicles 36:9" sec="2_Chronicles 36:9">conj</a></span> <span class="gloss">and</span> <span class="sp xft"><span class="f">sp=</span>conj</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">426225</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1OFRHin" title="show this lexeme in SHEBANQ">עֲשֶׂ֣רֶת </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_II&amp;chapter=36&amp;verse=9&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="2_Chronicles 36:9" sec="2_Chronicles 36:9">subs</a></span> <span class="gloss">ten</span> <span class="ls xft"><span class="f">ls=</span>card</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>c</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">426226</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1JWMn" title="show this lexeme in SHEBANQ">יָמִ֔ים </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_II&amp;chapter=36&amp;verse=9&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="2_Chronicles 36:9" sec="2_Chronicles 36:9">subs</a></span> <span class="gloss">day</span> <span class="ls xft"><span class="f">ls=</span>padv</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <div style="background: pink; text-align: center">numb</div>
# <div style="background: lightblue; text-align: center">head</div>
# {'__cx__': 'numb', 'head': 426223, 'numb': 426222}
#
# cnds:
# w in quants                                              True
# bool(P(1))                                               True
# P(1,sp) != conj                                          True
# P(1) not in quants|preps                                 True
#
# cnds:
# w in quants                                              True
# not Wk.ahead(is_nominal)                                False
# bool(Wk.back(is_nominal))                               False
# <hr>
# <p><b>result</b> <i>1450676 -> CX numb {426225, 426226}</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_II&amp;chapter=36&amp;verse=9&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="2_Chronicles 36:9">2_Chronicles 36:9</a>
# <div class="atoms  " >
# <a href="#" class="nd">904575</a>
#
#
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_II&amp;chapter=36&amp;verse=9&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="2_Chronicles 36:9" sec="2_Chronicles 36:9">phrase</a> <a href="#" class="nd">904575</a>  <span class="function">Time</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <a href="#" class="nd">426222</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CLCn" title="show this lexeme in SHEBANQ">שְׁלֹשָׁ֤ה </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_II&amp;chapter=36&amp;verse=9&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="2_Chronicles 36:9" sec="2_Chronicles 36:9">subs</a></span> <span class="gloss">three</span> <span class="ls xft"><span class="f">ls=</span>card</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">426223</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1XDCin" title="show this lexeme in SHEBANQ">חֳדָשִׁים֙ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_II&amp;chapter=36&amp;verse=9&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="2_Chronicles 36:9" sec="2_Chronicles 36:9">subs</a></span> <span class="gloss">month</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
# <div class="word  " >
# <a href="#" class="nd">426224</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="show this lexeme in SHEBANQ">וַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_II&amp;chapter=36&amp;verse=9&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="2_Chronicles 36:9" sec="2_Chronicles 36:9">conj</a></span> <span class="gloss">and</span> <span class="sp xft"><span class="f">sp=</span>conj</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: pink;" >
# <a href="#" class="nd">426225</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1OFRHin" title="show this lexeme in SHEBANQ">עֲשֶׂ֣רֶת </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_II&amp;chapter=36&amp;verse=9&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="2_Chronicles 36:9" sec="2_Chronicles 36:9">subs</a></span> <span class="gloss">ten</span> <span class="ls xft"><span class="f">ls=</span>card</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>c</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">426226</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1JWMn" title="show this lexeme in SHEBANQ">יָמִ֔ים </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_II&amp;chapter=36&amp;verse=9&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="2_Chronicles 36:9" sec="2_Chronicles 36:9">subs</a></span> <span class="gloss">day</span> <span class="ls xft"><span class="f">ls=</span>padv</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <div style="background: pink; text-align: center">numb</div>
# <div style="background: lightblue; text-align: center">head</div>
# {'__cx__': 'numb', 'head': 426226, 'numb': 426225}
#
# cnds:
# w in quants                                              True
# bool(P(1))                                               True
# P(1,sp) != conj                                          True
# P(1) not in quants|preps                                 True
#
# cnds:
# w in quants                                              True
# not Wk.ahead(is_nominal)                                False
# bool(Wk.back(is_nominal))                               False
# <hr>
# 1447599
# <p><b>result</b> <i>1447599 -> CX prep {85074, 85075, 85076}</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=23&amp;verse=23&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Numbers 23:23">Numbers 23:23</a>
# <div class="atoms  " >
# <a href="#" class="nd">700435</a>
#
#
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=23&amp;verse=23&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 23:23" sec="Numbers 23:23">phrase</a> <a href="#" class="nd">700435</a>  <span class="function">Time</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  hl"  style="background-color: pink;" >
# <a href="#" class="nd">85074</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1K" title="show this lexeme in SHEBANQ">כָּ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=23&amp;verse=23&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 23:23" sec="Numbers 23:23">prep</a></span> <span class="gloss">as</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">85075</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="show this lexeme in SHEBANQ"></a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=23&amp;verse=23&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 23:23" sec="Numbers 23:23">art</a></span> <span class="gloss">the</span> <span class="sp xft"><span class="f">sp=</span>art</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">85076</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1OTn" title="show this lexeme in SHEBANQ">עֵ֗ת </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Numeri&amp;chapter=23&amp;verse=23&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Numbers 23:23" sec="Numbers 23:23">subs</a></span> <span class="gloss">time</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <div style="background: pink; text-align: center">prep</div>
# <div style="background: lightblue; text-align: center">head</div>
# {   '__cx__': 'prep',
#     'head': {'__cx__': 'defi', 'defi': 85075, 'head': 85076},
#     'prep': 85074}
#
# cnds:
# w in preps                                               True
# F.prs.v(w) == absent                                     True
# bool(P(1))                                               True
# <hr>
# 1448166
# <p><b>result</b> <i>1448166 -> CX prep {141504, 141505, 141506, 141507, 141508}</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Judices&amp;chapter=21&amp;verse=24&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Judges 21:24">Judges 21:24</a>
# <div class="atoms  " >
# <a href="#" class="nd">731586</a>
#
#
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Judices&amp;chapter=21&amp;verse=24&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Judges 21:24" sec="Judges 21:24">phrase</a> <a href="#" class="nd">731586</a>  <span class="function">Time</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  hl"  style="background-color: pink;" >
# <a href="#" class="nd">141504</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="show this lexeme in SHEBANQ">בָּ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Judices&amp;chapter=21&amp;verse=24&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Judges 21:24" sec="Judges 21:24">prep</a></span> <span class="gloss">in</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">141505</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="show this lexeme in SHEBANQ"></a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Judices&amp;chapter=21&amp;verse=24&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Judges 21:24" sec="Judges 21:24">art</a></span> <span class="gloss">the</span> <span class="sp xft"><span class="f">sp=</span>art</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">141506</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1OTn" title="show this lexeme in SHEBANQ">עֵ֣ת </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Judices&amp;chapter=21&amp;verse=24&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Judges 21:24" sec="Judges 21:24">subs</a></span> <span class="gloss">time</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">141507</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Judices&amp;chapter=21&amp;verse=24&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Judges 21:24" sec="Judges 21:24">art</a></span> <span class="gloss">the</span> <span class="sp xft"><span class="f">sp=</span>art</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">141508</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1HJA" title="show this lexeme in SHEBANQ">הִ֔יא </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Judices&amp;chapter=21&amp;verse=24&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Judges 21:24" sec="Judges 21:24">prde</a></span> <span class="gloss">she</span> <span class="sp xft"><span class="f">sp=</span>prps</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <div style="background: pink; text-align: center">prep</div>
# <div style="background: lightblue; text-align: center">head</div>
# {   '__cx__': 'prep',
#     'head': {   '__cx__': 'attrib',
#                 'attrib': {'__cx__': 'defi', 'defi': 141507, 'head': 141508},
#                 'head': {'__cx__': 'defi', 'defi': 141505, 'head': 141506}},
#     'prep': 141504}
#
# cnds:
# w in preps                                               True
# F.prs.v(w) == absent                                     True
# bool(P(1))                                               True
# <hr>
# 1447447
# <p><b>result</b> <i>1447447 -> CX prep {67394, 67395, 67396, 67397, 67398, 67399}</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&amp;chapter=25&amp;verse=13&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Leviticus 25:13">Leviticus 25:13</a>
# <div class="atoms  " >
# <a href="#" class="nd">690911</a>
#
#
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&amp;chapter=25&amp;verse=13&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Leviticus 25:13" sec="Leviticus 25:13">phrase</a> <a href="#" class="nd">690911</a>  <span class="function">Time</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  hl"  style="background-color: pink;" >
# <a href="#" class="nd">67394</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="show this lexeme in SHEBANQ">בִּ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&amp;chapter=25&amp;verse=13&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Leviticus 25:13" sec="Leviticus 25:13">prep</a></span> <span class="gloss">in</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">67395</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CNHn" title="show this lexeme in SHEBANQ">שְׁנַ֥ת </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&amp;chapter=25&amp;verse=13&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Leviticus 25:13" sec="Leviticus 25:13">subs</a></span> <span class="gloss">year</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>c</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">67396</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&amp;chapter=25&amp;verse=13&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Leviticus 25:13" sec="Leviticus 25:13">art</a></span> <span class="gloss">the</span> <span class="sp xft"><span class="f">sp=</span>art</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">67397</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1JWBLn" title="show this lexeme in SHEBANQ">יֹּובֵ֖ל </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&amp;chapter=25&amp;verse=13&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Leviticus 25:13" sec="Leviticus 25:13">subs</a></span> <span class="gloss">ram</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">67398</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&amp;chapter=25&amp;verse=13&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Leviticus 25:13" sec="Leviticus 25:13">art</a></span> <span class="gloss">the</span> <span class="sp xft"><span class="f">sp=</span>art</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">67399</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1ZAT" title="show this lexeme in SHEBANQ">זֹּ֑את </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&amp;chapter=25&amp;verse=13&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Leviticus 25:13" sec="Leviticus 25:13">prde</a></span> <span class="gloss">this</span> <span class="sp xft"><span class="f">sp=</span>prde</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <div style="background: pink; text-align: center">prep</div>
# <div style="background: lightblue; text-align: center">head</div>
# {   '__cx__': 'prep',
#     'head': {   '__cx__': 'geni',
#                 'geni': {   '__cx__': 'attrib',
#                             'attrib': {   '__cx__': 'defi',
#                                           'defi': 67398,
#                                           'head': 67399},
#                             'head': {   '__cx__': 'defi',
#                                         'defi': 67396,
#                                         'head': 67397}},
#                 'head': 67395},
#     'prep': 67394}
#
# cnds:
# w in preps                                               True
# F.prs.v(w) == absent                                     True
# bool(P(1))                                               True
# <hr>
# 1450608
# <p><b>result</b> <i>1450608 -> CX prep {418756, 418757, 418758, 418759}</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_II&amp;chapter=24&amp;verse=23&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="2_Chronicles 24:23">2_Chronicles 24:23</a>
# <div class="atoms  " >
# <a href="#" class="nd">900827</a>
#
#
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_II&amp;chapter=24&amp;verse=23&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="2_Chronicles 24:23" sec="2_Chronicles 24:23">phrase</a> <a href="#" class="nd">900827</a>  <span class="function">Time</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  hl"  style="background-color: pink;" >
# <a href="#" class="nd">418756</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1L" title="show this lexeme in SHEBANQ">לִ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_II&amp;chapter=24&amp;verse=23&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="2_Chronicles 24:23" sec="2_Chronicles 24:23">prep</a></span> <span class="gloss">to</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">418757</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1TQWPHn" title="show this lexeme in SHEBANQ">תְקוּפַ֣ת </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_II&amp;chapter=24&amp;verse=23&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="2_Chronicles 24:23" sec="2_Chronicles 24:23">subs</a></span> <span class="gloss">turning point</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>c</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">418758</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_II&amp;chapter=24&amp;verse=23&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="2_Chronicles 24:23" sec="2_Chronicles 24:23">art</a></span> <span class="gloss">the</span> <span class="sp xft"><span class="f">sp=</span>art</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">418759</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CNHn" title="show this lexeme in SHEBANQ">שָּׁנָ֗ה </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_II&amp;chapter=24&amp;verse=23&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="2_Chronicles 24:23" sec="2_Chronicles 24:23">subs</a></span> <span class="gloss">year</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <div style="background: pink; text-align: center">prep</div>
# <div style="background: lightblue; text-align: center">head</div>
# {   '__cx__': 'prep',
#     'head': {   '__cx__': 'geni',
#                 'geni': {'__cx__': 'defi', 'defi': 418758, 'head': 418759},
#                 'head': 418757},
#     'prep': 418756}
#
# cnds:
# w in preps                                               True
# F.prs.v(w) == absent                                     True
# bool(P(1))                                               True
# <hr>
# 1446899
# No explicit link between CX attrib {7744, 7745, 7746, 7743} and CX prep {7741, 7742}
# 	attempt connect CX attrib {7744, 7745, 7746, 7743} and CX prep {7741, 7742, 7743}
# <p><b>result</b> <i>1446899 -> CX prep {7744, 7745, 7746, 7741, 7742, 7743}</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=17&amp;verse=23&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Genesis 17:23">Genesis 17:23</a>
# <div class="atoms  " >
# <a href="#" class="nd">655859</a>
#
#
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=17&amp;verse=23&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 17:23" sec="Genesis 17:23">phrase</a> <a href="#" class="nd">655859</a>  <span class="function">Time</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  hl"  style="background-color: pink;" >
# <a href="#" class="nd">7741</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="show this lexeme in SHEBANQ">בְּ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=17&amp;verse=23&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 17:23" sec="Genesis 17:23">prep</a></span> <span class="gloss">in</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: pink;" >
# <a href="#" class="nd">7742</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1OYMn" title="show this lexeme in SHEBANQ">עֶ֨צֶם֙ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=17&amp;verse=23&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 17:23" sec="Genesis 17:23">subs</a></span> <span class="gloss">bone</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>c</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">7743</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=17&amp;verse=23&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 17:23" sec="Genesis 17:23">art</a></span> <span class="gloss">the</span> <span class="sp xft"><span class="f">sp=</span>art</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">7744</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1JWMn" title="show this lexeme in SHEBANQ">יֹּ֣ום </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=17&amp;verse=23&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 17:23" sec="Genesis 17:23">subs</a></span> <span class="gloss">day</span> <span class="ls xft"><span class="f">ls=</span>padv</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">7745</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=17&amp;verse=23&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 17:23" sec="Genesis 17:23">art</a></span> <span class="gloss">the</span> <span class="sp xft"><span class="f">sp=</span>art</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">7746</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1ZH" title="show this lexeme in SHEBANQ">זֶּ֔ה </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=17&amp;verse=23&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Genesis 17:23" sec="Genesis 17:23">prde</a></span> <span class="gloss">this</span> <span class="sp xft"><span class="f">sp=</span>prde</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <div style="background: pink; text-align: center">prep</div>
# <div style="background: lightblue; text-align: center">head</div>
# {   '__cx__': 'prep',
#     'head': {   '__cx__': 'attrib',
#                 'attrib': {'__cx__': 'defi', 'defi': 7745, 'head': 7746},
#                 'head': {'__cx__': 'defi', 'defi': 7743, 'head': 7744}},
#     'prep': {'__cx__': 'prep', 'head': 7742, 'prep': 7741}}
#
# cnds:
# w in preps                                               True
# F.prs.v(w) == absent                                     True
# bool(P(1))                                               True
# <hr>
# 1449657
# <p><b>result</b> <i>1449657 -> CX prep {307765, 307766, 307767, 307768, 307769}</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Sacharia&amp;chapter=9&amp;verse=16&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Zechariah 9:16">Zechariah 9:16</a>
# <div class="atoms  " >
# <a href="#" class="nd">833531</a>
#
#
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Sacharia&amp;chapter=9&amp;verse=16&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Zechariah 9:16" sec="Zechariah 9:16">phrase</a> <a href="#" class="nd">833531</a>  <span class="function">Time</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  hl"  style="background-color: pink;" >
# <a href="#" class="nd">307765</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="show this lexeme in SHEBANQ">בַּ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Sacharia&amp;chapter=9&amp;verse=16&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Zechariah 9:16" sec="Zechariah 9:16">prep</a></span> <span class="gloss">in</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">307766</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="show this lexeme in SHEBANQ"></a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Sacharia&amp;chapter=9&amp;verse=16&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Zechariah 9:16" sec="Zechariah 9:16">art</a></span> <span class="gloss">the</span> <span class="sp xft"><span class="f">sp=</span>art</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">307767</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1JWMn" title="show this lexeme in SHEBANQ">יֹּ֥ום </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Sacharia&amp;chapter=9&amp;verse=16&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Zechariah 9:16" sec="Zechariah 9:16">subs</a></span> <span class="gloss">day</span> <span class="ls xft"><span class="f">ls=</span>padv</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">307768</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Sacharia&amp;chapter=9&amp;verse=16&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Zechariah 9:16" sec="Zechariah 9:16">art</a></span> <span class="gloss">the</span> <span class="sp xft"><span class="f">sp=</span>art</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">307769</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1HWA" title="show this lexeme in SHEBANQ">ה֖וּא </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Sacharia&amp;chapter=9&amp;verse=16&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Zechariah 9:16" sec="Zechariah 9:16">prde</a></span> <span class="gloss">he</span> <span class="sp xft"><span class="f">sp=</span>prps</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <div style="background: pink; text-align: center">prep</div>
# <div style="background: lightblue; text-align: center">head</div>
# {   '__cx__': 'prep',
#     'head': {   '__cx__': 'attrib',
#                 'attrib': {'__cx__': 'defi', 'defi': 307768, 'head': 307769},
#                 'head': {'__cx__': 'defi', 'defi': 307766, 'head': 307767}},
#     'prep': 307765}
#
# cnds:
# w in preps                                               True
# F.prs.v(w) == absent                                     True
# bool(P(1))                                               True
# <hr>
# 1447139
# <p><b>result</b> <i>1447139 -> CX prep {34992, 34993, 34994, 34995, 34991}</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=12&amp;verse=15&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Exodus 12:15">Exodus 12:15</a>
# <div class="atoms  " >
# <a href="#" class="nd">673290</a>
#
#
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=12&amp;verse=15&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 12:15" sec="Exodus 12:15">phrase</a> <a href="#" class="nd">673290</a>  <span class="function">Time</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <a href="#" class="nd">34990</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1AK" title="show this lexeme in SHEBANQ">אַ֚ךְ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=12&amp;verse=15&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 12:15" sec="Exodus 12:15">advb</a></span> <span class="gloss">only</span> <span class="ls xft"><span class="f">ls=</span>focp</span> <span class="sp xft"><span class="f">sp=</span>advb</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: pink;" >
# <a href="#" class="nd">34991</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="show this lexeme in SHEBANQ">בַּ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=12&amp;verse=15&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 12:15" sec="Exodus 12:15">prep</a></span> <span class="gloss">in</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">34992</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="show this lexeme in SHEBANQ"></a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=12&amp;verse=15&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 12:15" sec="Exodus 12:15">art</a></span> <span class="gloss">the</span> <span class="sp xft"><span class="f">sp=</span>art</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">34993</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1JWMn" title="show this lexeme in SHEBANQ">יֹּ֣ום </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=12&amp;verse=15&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 12:15" sec="Exodus 12:15">subs</a></span> <span class="gloss">day</span> <span class="ls xft"><span class="f">ls=</span>padv</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">34994</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="show this lexeme in SHEBANQ">הָ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=12&amp;verse=15&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Exodus 12:15" sec="Exodus 12:15">art</a></span> <span class="gloss">the</span> <span class="sp xft"><span class="f">sp=</span>art</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">34995</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1RACWNn" title="show this lexeme in SHEBANQ">רִאשֹׁ֔ון </a></div>
# ...
# <div class="atoms  " >
# <a href="#" class="nd">831733</a>
#
#
#
# <div class="patom  l " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Haggai&amp;chapter=2&amp;verse=15&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Haggai 2:15" sec="Haggai 2:15">phrase</a> <a href="#" class="nd">831733</a>  <span class="function">Time</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  hl"  style="background-color: pink;" >
# <a href="#" class="nd">304794</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1MN" title="show this lexeme in SHEBANQ">מִן־</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Haggai&amp;chapter=2&amp;verse=15&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Haggai 2:15" sec="Haggai 2:15">prep</a></span> <span class="gloss">from</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">304795</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Haggai&amp;chapter=2&amp;verse=15&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Haggai 2:15" sec="Haggai 2:15">art</a></span> <span class="gloss">the</span> <span class="sp xft"><span class="f">sp=</span>art</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">304796</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1JWMn" title="show this lexeme in SHEBANQ">יֹּ֥ום </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Haggai&amp;chapter=2&amp;verse=15&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Haggai 2:15" sec="Haggai 2:15">subs</a></span> <span class="gloss">day</span> <span class="ls xft"><span class="f">ls=</span>padv</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">304797</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Haggai&amp;chapter=2&amp;verse=15&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Haggai 2:15" sec="Haggai 2:15">art</a></span> <span class="gloss">the</span> <span class="sp xft"><span class="f">sp=</span>art</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">304798</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1ZH" title="show this lexeme in SHEBANQ">זֶּ֖ה </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Haggai&amp;chapter=2&amp;verse=15&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Haggai 2:15" sec="Haggai 2:15">prde</a></span> <span class="gloss">this</span> <span class="sp xft"><span class="f">sp=</span>prde</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r l " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Haggai&amp;chapter=2&amp;verse=15&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Haggai 2:15" sec="Haggai 2:15">phrase</a> <a href="#" class="nd">831733</a>  <span class="function">Time</span> <span class="typ">PP|CP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <a href="#" class="nd">304799</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="show this lexeme in SHEBANQ">וָ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Haggai&amp;chapter=2&amp;verse=15&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Haggai 2:15" sec="Haggai 2:15">conj</a></span> <span class="gloss">and</span> <span class="sp xft"><span class="f">sp=</span>conj</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
# <div class="patom  r " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Haggai&amp;chapter=2&amp;verse=15&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Haggai 2:15" sec="Haggai 2:15">phrase</a> <a href="#" class="nd">831733</a>  <span class="function">Time</span> <span class="typ">PP|AdvP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  " >
# <a href="#" class="nd">304800</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1MOLn" title="show this lexeme in SHEBANQ">מָ֑עְלָה </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Haggai&amp;chapter=2&amp;verse=15&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Haggai 2:15" sec="Haggai 2:15">subs</a></span> <span class="gloss">top</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <div style="background: pink; text-align: center">prep</div>
# <div style="background: lightblue; text-align: center">head</div>
# {   '__cx__': 'prep',
#     'head': {   '__cx__': 'attrib',
#                 'attrib': {'__cx__': 'defi', 'defi': 304797, 'head': 304798},
#                 'head': {'__cx__': 'defi', 'defi': 304795, 'head': 304796}},
#     'prep': 304794}
#
# cnds:
# w in preps                                               True
# F.prs.v(w) == absent                                     True
# bool(P(1))                                               True
# <hr>
# 1448948
# <p><b>result</b> <i>1448948 -> CX prep {213012, 213013, 213014, 213015, 213016}</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Jesaia&amp;chapter=3&amp;verse=7&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="Isaiah 3:7">Isaiah 3:7</a>
# <div class="atoms  " >
# <a href="#" class="nd">774650</a>
#
#
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Jesaia&amp;chapter=3&amp;verse=7&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Isaiah 3:7" sec="Isaiah 3:7">phrase</a> <a href="#" class="nd">774650</a>  <span class="function">Time</span> <span class="typ">PP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  hl"  style="background-color: pink;" >
# <a href="#" class="nd">213012</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1B" title="show this lexeme in SHEBANQ">בַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Jesaia&amp;chapter=3&amp;verse=7&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Isaiah 3:7" sec="Isaiah 3:7">prep</a></span> <span class="gloss">in</span> <span class="sp xft"><span class="f">sp=</span>prep</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">213013</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="show this lexeme in SHEBANQ"></a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Jesaia&amp;chapter=3&amp;verse=7&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Isaiah 3:7" sec="Isaiah 3:7">art</a></span> <span class="gloss">the</span> <span class="sp xft"><span class="f">sp=</span>art</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">213014</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1JWMn" title="show this lexeme in SHEBANQ">יֹּ֨ום </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Jesaia&amp;chapter=3&amp;verse=7&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Isaiah 3:7" sec="Isaiah 3:7">subs</a></span> <span class="gloss">day</span> <span class="ls xft"><span class="f">ls=</span>padv</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">213015</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1H" title="show this lexeme in SHEBANQ">הַ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Jesaia&amp;chapter=3&amp;verse=7&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Isaiah 3:7" sec="Isaiah 3:7">art</a></span> <span class="gloss">the</span> <span class="sp xft"><span class="f">sp=</span>art</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">213016</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1HWA" title="show this lexeme in SHEBANQ">ה֤וּא׀ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Jesaia&amp;chapter=3&amp;verse=7&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Isaiah 3:7" sec="Isaiah 3:7">prde</a></span> <span class="gloss">he</span> <span class="sp xft"><span class="f">sp=</span>prps</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <div style="background: pink; text-align: center">prep</div>
# <div style="background: lightblue; text-align: center">head</div>
# {   '__cx__': 'prep',
#     'head': {   '__cx__': 'attrib',
#                 'attrib': {'__cx__': 'defi', 'defi': 213015, 'head': 213016},
#                 'head': {'__cx__': 'defi', 'defi': 213013, 'head': 213014}},
#     'prep': 213012}
#
# cnds:
# w in preps                                               True
# F.prs.v(w) == absent                                     True
# bool(P(1))                                               True
# <hr>
# 1450609
# <p><b>result</b> <i>1450609 -> CX numb {418897, 418898, 418899, 418900}</i></p>
# <a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_II&amp;chapter=25&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="show this passage in SHEBANQ" sec="2_Chronicles 25:1">2_Chronicles 25:1</a>
# <div class="atoms  " >
# <a href="#" class="nd">900906</a>
#
#
#
# <div class="patom  " >
#
#     <div class="phrase " >
#         <a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_II&amp;chapter=25&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="2_Chronicles 25:1" sec="2_Chronicles 25:1">phrase</a> <a href="#" class="nd">900906</a>  <span class="function">Time</span> <span class="typ">NP</span>
#     </div>
#     <div class="atoms">
#
# <div class="word  hl"  style="background-color: pink;" >
# <a href="#" class="nd">418897</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1OFRJMn" title="show this lexeme in SHEBANQ">עֶשְׂרִ֣ים </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_II&amp;chapter=25&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="2_Chronicles 25:1" sec="2_Chronicles 25:1">subs</a></span> <span class="gloss">twenty</span> <span class="ls xft"><span class="f">ls=</span>card</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: pink;" >
# <a href="#" class="nd">418898</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1W" title="show this lexeme in SHEBANQ">וָ</a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_II&amp;chapter=25&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="2_Chronicles 25:1" sec="2_Chronicles 25:1">conj</a></span> <span class="gloss">and</span> <span class="sp xft"><span class="f">sp=</span>conj</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: pink;" >
# <a href="#" class="nd">418899</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1TCOn" title="show this lexeme in SHEBANQ">תֵ֨שַׁע֙ </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_II&amp;chapter=25&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="2_Chronicles 25:1" sec="2_Chronicles 25:1">subs</a></span> <span class="gloss">nine</span> <span class="ls xft"><span class="f">ls=</span>card</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
# <div class="word  hl"  style="background-color: lightblue;" >
# <a href="#" class="nd">418900</a>
# <div class="h"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/word?version=c&amp;id=1CNHn" title="show this lexeme in SHEBANQ">שָׁנָ֔ה </a></div>
# <div class="features"> <span class="pdp"><a href="https://shebanq.ancient-data.org/hebrew/text?book=Chronica_II&amp;chapter=25&amp;verse=1&amp;version=c&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="2_Chronicles 25:1" sec="2_Chronicles 25:1">subs</a></span> <span class="gloss">year</span> <span class="sp xft"><span class="f">sp=</span>subs</span> <span class="st xft"><span class="f">st=</span>a</span></div>
#
#
# </div>
#
#
#     </div>
#
#
# </div>
#
#
# </div>
# <div style="background: pink; text-align: center">numb</div>
# <div style="background: lightblue; text-align: center">head</div>
# {   '__cx__': 'numb',
#     'head': 418900,
#     'numb': {   '__cx__': 'card_chain',
#                 'card': 418899,
#                 'conj': 418898,
#                 'head': 418897}}
#
# cnds:
# w in quants                                              True
# bool(P(1))                                               True
# P(1,sp) != conj                                          True
# P(1) not in quants|preps                                 True
#
# cnds:
# w in quants                                              True
# not Wk.ahead(is_nominal)                                False
# bool(Wk.back(is_nominal))                               False
# <hr>
