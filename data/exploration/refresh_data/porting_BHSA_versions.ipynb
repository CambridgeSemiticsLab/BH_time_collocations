# %% [markdown]
# # Porting from BHSA C to 2021

# %%
import json
import csv

from pathlib import Path
from tf.fabric import Fabric
from pprint import pprint

# %%
TF_DATA =  Path('/Users/cody/github/etcbc/bhsa/tf/')
REPO = Path('/Users/cody/github/BH_time_collocations/')
FUNCT_EDITS = '/Users/cody/Downloads/edit_function.json'
TIME_PARSINGS = REPO / 'data/data/parsing/time_parsings.json'

# %%
load_features = ' '.join([
    'function',
])

tf_c = Fabric(
    locations=[TF_DATA / 'c'],
)

api_c = tf_c.load(load_features)

tf_2021 = Fabric(
    locations=[TF_DATA / '2021'],
)

api_2021 = tf_2021.load(load_features + ' omap@c-2021')

# %%
with open(FUNCT_EDITS, 'r') as infile:
    function_edits = json.load(infile)

# %%
api_2021.EdgeString('omap@c-2021').f(881665)
# Out:
# ((881696, None),)

# %%
def get_2021_nodes(node):
    return api_2021.EdgeString('omap@c-2021').f(node)

# %% [markdown]
# ## Check for any slot diffs

# %%
slot_diffs = []

for slot in api_c.F.otype.s('word'):
    slots_2021 = get_2021_nodes(slot)
    if len(slots_2021) > 1:
        slot_diffs.append((slot, slots_2021))

# %%
len(slot_diffs)
# Out:
# 6

# %%
for slot, diff in slot_diffs:
    cl = api_c.L.u(slot, 'clause')[0]
    ph_functs = set(
        api_c.F.function.v(ph)
        for ph in api_c.L.d(cl, 'phrase')
    )
    print(api_c.T.text(slot))
    print([api_2021.T.text(s) for s, _ in diff])
    print('Time in clause:', 'Time' in ph_functs)
    print(slot, diff)
    print()
# Out:
# אֲרַ֥ם נַֽהֲרַ֖יִם
# ['אֲרַ֥ם ', 'נַֽהֲרַ֖יִם ']
# Time in clause: False
# 11325 ((11325, 1), (11326, 1))
#
# אֲרַ֥ם נַהֲרַ֖יִם
# ['אֲרַ֥ם ', 'נַהֲרַ֖יִם ']
# Time in clause: False
# 105981 ((105982, 1), (105983, 1))
#
# אֲרַ֣ם נַהֲרָ֑יִם
# ['אֲרַ֣ם ', 'נַהֲרָ֑יִם ']
# Time in clause: False
# 128871 ((128873, 1), (128874, 1))
#
# אֲרַ֣ם נַהֲרַיִם֮
# ['אֲרַ֣ם ', 'נַהֲרַיִם֮ ']
# Time in clause: False
# 320252 ((320255, 1), (320256, 1))
#
# אֲרַ֨ם נַהֲרַ֜יִם
# ['אֲרַ֨ם ', 'נַהֲרַ֜יִם ']
# Time in clause: False
# 401289 ((401293, 1), (401294, 1))
#
# אֲרַ֤ם מַעֲכָה֙
# ['אֲרַ֤ם ', 'מַעֲכָה֙ ']
# Time in clause: False
# 401292 ((401297, 1), (401298, 1))

# %% [markdown]
# ## Check for Time phrase diffs

# %%
obsoleted = []
split = []

for phrase in api_c.F.function.s('Time'):
    phrase_2021 = get_2021_nodes(phrase)
    
    # get splits
    if len(phrase_2021) > 1:
        split.append((api_c.T.text(phrase), phrase, phrase_2021))
        continue
    
    # get funct comparison
    funct_2021 = api_2021.F.function.v(phrase_2021[0][0])
    if funct_2021 != 'Time':
        obsoleted.append((
            api_c.T.sectionFromNode(phrase),
            api_c.T.text(phrase),
            phrase,
            phrase_2021[0][0],
            funct_2021,
        ))

# %%
len(split)
# Out:
# 1

# %%
len(obsoleted)
# Out:
# 7

# %%
split
# Out:
# [('מִן־הַיֹּ֥ום הַזֶּ֖ה וָמָ֑עְלָה מִיֹּום֩ עֶשְׂרִ֨ים וְאַרְבָּעָ֜ה לַתְּשִׁיעִ֗י לְמִן־הַיֹּ֛ום ',
#   831763,
#   ((831794, 12), (831795, 7)))]

# %%
obsoleted
# Out:
# [(('Exodus', 14, 27), 'בֹּ֨קֶר֙ ', 674321, 674354, 'Subj'),
#  (('Isaiah', 1, 26), 'כְּבָרִ֣אשֹׁנָ֔ה ', 774349, 774379, 'Adju'),
#  (('Isaiah', 1, 26), 'כְּבַתְּחִלָּ֑ה ', 774352, 774382, 'Adju'),
#  (('Isaiah', 9, 3), 'כְּיֹ֥ום מִדְיָֽן׃ ', 775985, 776017, 'Adju'),
#  (('Joel', 3, 5), 'בְּהַר־צִיֹּ֨ון וּבִירוּשָׁלִַ֜ם ', 825329, 825360, 'Loca'),
#  (('Jonah', 3, 4), 'מַהֲלַ֖ךְ יֹ֣ום אֶחָ֑ד ', 828081, 828112, 'Modi'),
#  (('Psalms', 113, 6), 'בַּשָּׁמַ֥יִם וּבָאָֽרֶץ׃ ', 849296, 849330, 'Cmpl')]

# %% [markdown]
# ## Port over the function edits and manually select those to keep

# %%
rows = []
header = [
    'ref', 'text', 'c_node', '2021_node', 
    'c_funct', '2021_funct', 'my_funct',
]

book_limit = 426596  # restrict with new corpus boundary

for c_node, edit in function_edits.items():
    c_node = int(c_node)
    book_node = api_c.L.u(c_node, 'book')[0]
    if book_node >= book_limit:
        continue
    my_function = edit['function']
    nodes_2021 = [
        node for (node, _)
        in api_2021.EdgeString('omap@c-2021').f(c_node)
    ]
    functs_2021 = [
        api_2021.F.function.v(node) for node
        in nodes_2021
    ]
    book, ch, vs = api_c.T.sectionFromNode(c_node)
    ref = f'{book} {ch}:{vs}'
    
    rows.append([
        ref,
        api_c.T.text(c_node),
        c_node,
        nodes_2021,
        api_c.F.function.v(c_node),
        functs_2021,
        edit['function'],
    ])

# %%
with open('curate_function_edits.csv', 'w') as outfile:
    writer = csv.writer(outfile)
    writer.writerow(header)
    writer.writerows(rows)

# %%
with open('curated_function_edits.csv', 'r') as infile:
    reader = csv.reader(infile)
    annotated_funct_changes = list(reader)[1:]

# %%
annotated_funct_changes[0]
# Out:
# ['Exodus 12:18',
#  'בָּרִאשֹׁ֡ן ',
#  '673337',
#  '[673370]',
#  'Adju',
#  "['Adju']",
#  'Time']

# %%
# Exodus 12:18, Adju->Time 
# mislabeled as Adju
 673370: "Time",

# Exodus 12:18, Adju->Time 
# mislabeled as Adju
 673373: "Time",

# Exodus 12:18, Adju->Time 
# mislabled as Adju
 673378: "Time",
    
# 1_Samuel 1:23, Time->Modi 
# no reviewed sources took this as temporal
 731946: "Modi",

# %%
for edit in annotated_funct_changes:
    ref = edit[0]
    text = edit[1]
    ph_node = eval(edit[3])[0]
    old_funct = eval(edit[-2])[0]
    new_funct = edit[-1]
    note = function_edits[edit[2]]['note']
    print(
f"""
# {old_funct}->{new_funct} 
# {note}
 {ph_node}: "{new_funct}",\
""")
# Out:
# # Adju->Time
# # mislabeled as Adju
#  673370: "Time",
#
# # Adju->Time
# # mislabeled as Adju
#  673373: "Time",
#
# # Adju->Time
# # mislabled as Adju
#  673378: "Time",
#
# # Adju->Time
# # Deut 31:10, mislabled as Adju (חג)
#  714507: "Time",
#
# # Time->Time
# # 1 Sam 25: 15, mislabled as Loca
#  741508: "Time",
#
# # Time->Modi
# # no reviewed sources took this as temporal
#  731946: "Modi",
#
# # Time->PreC
# # Gen 9:29; phrase is pred. complement
#  654059: "PreC",
#
# # Time->Adju
# # Josh 4:18; waters flowed 'as before'; not temporal
#  716817: "Adju",
#
# # Time->Adju
# # 2 Kgs 13:5; 'as before'; not temporal
#  769441: "Adju",
#
# # Time->Adju
# # 1 Sam 19:7; 'as before'; not temporal
#  738950: "Adju",
#
# # Time->Adju
# # 1 Sam 21:6; 'as before'; not temporal
#  739973: "Adju",
#
# # Time->Adju
# # Exod 30:10; This is frequentive not time location / duration
#  679412: "Adju",
#
# # Time->Adju
# # Exod 30:10; This is frequentive not time location / duration
#  679414: "Adju",
#
# # Time->Adju
# # Lev 16:34; This is frequentive not time location / duration
#  688372: "Adju",
#
# # Time->Adju
# # Lev 23:16; how far one should count, not temporal
#  690340: "Adju",
#
# # Time->Adju
# # Lev 26:18; No transs interprets as temporal
#  691647: "Adju",
#
# # Time->Adju
# # Num 2:31; 'set out last', this is sequential but not with respect to timeline
#  692794: "Adju",
#
# # Time->Cmpl
# # Josh 8:14; most take as locative; LXX omits; though Targum reads as ZMN, 'time'
#  718111: "Cmpl",
#
# # Time->Adju
# # 1 Sam 18:10; comparative not temporal
#  738537: "Adju",
#
# # Time->PreC
# # Num 28:14; the phrase belongs to prev phrase as part of genitive; 'חדש בחדו' is the complete idiom; =burnt offfering of each month
#  701713: "PreC",
#
# # Time->Freq
# # 1 Kgs 10:22; this frequentive explains some L+time cx
#  757981: "Freq",

# %%
new_rows = []

header = ['passage', 'text', 'phrase_node', 'old_function', 'new_function', 'note']

for edit in annotated_funct_changes:
    new_rows.append([
        edit[0],
        edit[1],
        eval(edit[3])[0],
        eval(edit[-2])[0],
        edit[-1],
        function_edits[edit[2]]['note'],
    ])

# %%
new_rows[0]
# Out:
# ['Exodus 12:18', 'בָּרִאשֹׁ֡ן ', 673370, 'Adju', 'Time', 'mislabeled as Adju']

# %%
with open('function_edits_2021.csv', 'w') as outfile:
    writer = csv.writer(outfile)
    writer.writerow(header)
    writer.writerows(new_rows)

# %% [markdown]
# ## Port over temporal function annotations

# %%
with open(TIME_PARSINGS, 'r') as infile:
    time_parsings_raw = json.load(infile)
    
# subset the time parsings to those within corpus
time_parsings = {}
for cl, data in time_parsings_raw.items():
    cl_node = int(cl)
    book = api_c.L.u(cl_node, 'book')[0]
    if book >= book_limit:
        continue
    else:
        time_parsings[cl_node] = data

# %%
len(time_parsings)
# Out:
# 2004

# %%
# check for diffs in clause
# we will set these aside to be solved later
diffs = []
diff_cl_set = set()

for cl_node in time_parsings:
    cl_2021 = [cl for cl, _ in get_2021_nodes(cl_node)]
    if len(cl_2021) > 1:
        diffs.append((cl_node, cl_2021))
        diff_cl_set.add(cl_node)

# %%
len(diffs)
# Out:
# 2

# %%
diffs
# Out:
# [(435108, [435113, 435114]), (455537, [455553, 455554])]

# %%
# examine multiple phrase clauses

multi_phrase = []

for cl in time_parsings:
    if cl in diff_cl_set:
        continue
    cl_node = int(cl)
    data = time_parsings[cl]
    if len(data['phrase_nodes']) > 1:
        multi_phrase.append((cl_node, data))

# %%
multi_phrase[:1]
# Out:
# [(428143,
#   {'times': [{'times': [3107],
#      'slots': [3106, 3107, 3108, 3109],
#      'quals': ['durative'],
#      'tenses': [['FUT', [3108, 3109, 'ADJV']]],
#      'preps': [['L', 3106]],
#      'functions': ['dist_fut']},
#     {'times': [{'times': [3116],
#        'slots': [3115, 3116],
#        'quants': [['NUMQ', 3115]],
#        'quals': ['durative']},
#       {'times': [3119],
#        'slots': [3118, 3119],
#        'quants': [['NUMQ', 3118]],
#        'quals': ['durative']}],
#      'slots': [3115, 3116, 3118, 3119],
#      'functions': ['atelic_ext'],
#      'quals': ['durative']}],
#    'slots': [3106, 3107, 3108, 3109, 3115, 3116, 3118, 3119],
#    'functions': ['distfut_ext'],
#    'phrase_nodes': [653347, 653351]})]

# %% [markdown]
# It appears as if the majority of these have an equal number of `'times'` to `'phrase_nodes'`, which means we can match temporal function along that axis. Let's see if that's true.

# %%
# check to see how many have matching times

no_match = []
multi_functs = []

for cl, parsing in multi_phrase:
    n_times = len(parsing['times'])
    n_phrases = len(parsing['phrase_nodes'])
    if n_times != n_phrases:
        no_match.append((cl, parsing))
    for time in parsing['times']:
        if isinstance(time, dict) and len(time['functions']) > 1:
            multi_functs.append(cl)
        
no_match
# Out:
# [(434753,
#   {'times': [34789],
#    'slots': [34786, 34787, 34788, 34789, 34790, 34791, 34792, 34794],
#    'refs': [['CALNUM', [34787, 34788, 'CARDC']],
#     ['MONTH',
#      {'times': [34792],
#       'slots': [34790, 34791, 34792, 34794],
#       'refs': [['THIS', 34794], ['THE', 34791]],
#       'preps': [['L', 34790]],
#       'functions': ['reference'],
#       'ref': 'MONTH'}]],
#    'functions': ['anterior_dur'],
#    'preps': [['<D', 34786]],
#    'quals': ['durative'],
#    'phrase_nodes': [673175, 673176]}),
#  (454827,
#   {'times': [145729],
#    'slots': [145728, 145729, 145731, 145732],
#    'refs': [['LREF',
#      {'times': [145732],
#       'slots': [145731, 145732],
#       'quals': ['durative'],
#       'functions': ['reference'],
#       'preps': [['L', 145731]]}],
#     ['THE', 145728]],
#    'functions': ['simultaneous'],
#    'phrase_nodes': [734287, 734289]})]

# %%
time_parsings[428143]
# Out:
# {'times': [{'times': [3107],
#    'slots': [3106, 3107, 3108, 3109],
#    'quals': ['durative'],
#    'tenses': [['FUT', [3108, 3109, 'ADJV']]],
#    'preps': [['L', 3106]],
#    'functions': ['dist_fut']},
#   {'times': [{'times': [3116],
#      'slots': [3115, 3116],
#      'quants': [['NUMQ', 3115]],
#      'quals': ['durative']},
#     {'times': [3119],
#      'slots': [3118, 3119],
#      'quants': [['NUMQ', 3118]],
#      'quals': ['durative']}],
#    'slots': [3115, 3116, 3118, 3119],
#    'functions': ['atelic_ext'],
#    'quals': ['durative']}],
#  'slots': [3106, 3107, 3108, 3109, 3115, 3116, 3118, 3119],
#  'functions': ['distfut_ext'],
#  'phrase_nodes': [653347, 653351]}

# %% [markdown]
# These are cases where L serves to indicate an anchoring reference point. We can thus take the one time function and assign it to the first time.

# %%
# preparing the temporal function annotations

def get_ref(node):
    return '{} {}:{}'.format(*api_c.T.sectionFromNode(node))


def get_2021_ph_with_exception(node):
    ph_2021 = get_2021_nodes(node)
    if len(ph_2021) > 1:
        raise Exception(node, ph_2021)
    else:
        return ph_2021[0][0]


rows = []

for cl, parsing in time_parsings.items():
    
    cl_2021 = get_2021_nodes(cl)[0][0]
    
    # skip clauses that have diff boundaries compared to 2021
    if cl in diff_cl_set:
        continue
        
    phrases = parsing['phrase_nodes']
    times = parsing['times']
    
    if isinstance(times[0], int):
        ph = phrases[0]
        ref = get_ref(ph)
        funct = parsing['functions'][0]
        rows.append(
            (ref, cl, get_2021_ph_with_exception(ph), funct)
        )
    else:
        if len(phrases) == len(times):
            temp_functs = [time['functions'][0] for time in times]
            for phrase, funct in zip(phrases, temp_functs):
                ref = get_ref(phrase)
                rows.append(
                    (ref, cl, get_2021_ph_with_exception(phrase), funct)
                )
        else:
            ph = phrases[0]
            ref = get_ref(ph)
            funct = parsing['functions'][0]
            rows.append(
                (ref, cl, get_2021_ph_with_exception(ph), funct)
            )

# %%
len(rows)
# Out:
# 2063

# %%
api_c.T.sectionFromNode(652870)
# Out:
# ('Genesis', 5, 6)

# %%
time_parsings[427805]
# Out:
# {'times': [1326],
#  'slots': [1325, 1326, 1327, 1328],
#  'refs': [['GEN', [1327, 1328, 'DEF']]],
#  'functions': ['anterior_dur, simultaneous'],
#  'preps': [['L', 1325]],
#  'phrase_nodes': [652298]}

# %%
api_c.T.text(1326)
# Out:
# 'ר֣וּחַ '

# %%
rows
# Out:
# [('Genesis 1:1', 427553, 651573, 'simultaneous'),
#  ('Genesis 2:2', 427680, 651954, 'simultaneous'),
#  ('Genesis 2:2', 427682, 651960, 'simultaneous'),
#  ('Genesis 2:5', 427693, 651988, 'anterior'),
#  ('Genesis 2:5', 427694, 651993, 'anterior'),
#  ('Genesis 3:8', 427805, 652329, 'anterior_dur, simultaneous'),
#  ('Genesis 3:14', 427835, 652411, 'atelic_ext'),
#  ('Genesis 3:17', 427851, 652458, 'atelic_ext'),
#  ('Genesis 3:22', 427866, 652506, 'simultaneous'),
#  ('Genesis 3:22', 427870, 652517, 'anterior_dur, simultaneous'),
#  ('Genesis 4:3', 427887, 652566, 'posterior'),
#  ('Genesis 4:11', 427916, 652659, 'simultaneous'),
#  ('Genesis 4:14', 427927, 652690, 'simultaneous'),
#  ('Genesis 4:26', 427975, 652845, 'simultaneous'),
#  ('Genesis 5:3', 427984, 652872, 'atelic_ext'),
#  ('Genesis 5:6', 427993, 652901, 'atelic_ext'),
#  ('Genesis 5:7', 427995, 652910, 'atelic_ext'),
#  ('Genesis 5:9', 428000, 652923, 'atelic_ext'),
#  ('Genesis 5:10', 428002, 652932, 'atelic_ext'),
#  ('Genesis 5:12', 428007, 652945, 'atelic_ext'),
#  ('Genesis 5:13', 428009, 652954, 'atelic_ext'),
#  ('Genesis 5:15', 428014, 652967, 'atelic_ext'),
#  ('Genesis 5:16', 428016, 652976, 'atelic_ext'),
#  ('Genesis 5:18', 428021, 652989, 'atelic_ext'),
#  ('Genesis 5:19', 428023, 652998, 'atelic_ext'),
#  ('Genesis 5:21', 428028, 653011, 'atelic_ext'),
#  ('Genesis 5:22', 428030, 653021, 'atelic_ext'),
#  ('Genesis 5:25', 428037, 653042, 'atelic_ext'),
#  ('Genesis 5:26', 428039, 653051, 'atelic_ext'),
#  ('Genesis 5:28', 428044, 653064, 'atelic_ext'),
#  ('Genesis 5:30', 428050, 653085, 'atelic_ext'),
#  ('Genesis 6:3', 428066, 653135, 'anterior_dur, simultaneous'),
#  ('Genesis 6:4', 428069, 653146, 'simultaneous'),
#  ('Genesis 6:4', 428070, 653149, 'posterior'),
#  ('Genesis 6:5', 428078, 653173, 'atelic_ext'),
#  ('Genesis 7:4', 428143, 653378, 'dist_fut'),
#  ('Genesis 7:4', 428143, 653382, 'atelic_ext'),
#  ('Genesis 7:10', 428156, 653427, 'anterior_dur, simultaneous'),
#  ('Genesis 7:11', 428158, 653432, 'cal_simul'),
#  ('Genesis 7:12', 428160, 653445, 'atelic_ext'),
#  ('Genesis 7:13', 428161, 653446, 'simultaneous'),
#  ('Genesis 7:17', 428170, 653478, 'atelic_ext'),
#  ('Genesis 7:24', 428193, 653553, 'atelic_ext'),
#  ('Genesis 8:3', 428201, 653584, 'posterior'),
#  ('Genesis 8:4', 428202, 653588, 'simultaneous'),
#  ('Genesis 8:4', 428202, 653589, 'simultaneous'),
#  ('Genesis 8:5', 428203, 653595, 'anterior_dur'),
#  ('Genesis 8:5', 428204, 653596, 'simultaneous'),
#  ('Genesis 8:5', 428204, 653597, 'simultaneous'),
#  ('Genesis 8:6', 428205, 653602, 'posterior'),
#  ('Genesis 8:10', 428220, 653653, 'atelic_ext'),
#  ('Genesis 8:11', 428223, 653663, 'anterior_dur, simultaneous'),
#  ('Genesis 8:12', 428227, 653678, 'atelic_ext'),
#  ('Genesis 8:13', 428232, 653690, 'simultaneous'),
#  ('Genesis 8:13', 428232, 653691, 'simultaneous'),
#  ('Genesis 8:13', 428232, 653692, 'simultaneous'),
#  ('Genesis 8:14', 428236, 653707, 'simultaneous'),
#  ('Genesis 8:14', 428236, 653708, 'simultaneous'),
#  ('Genesis 8:22', 428260, 653784, 'atelic_ext'),
#  ('Genesis 9:12', 428297, 653901, 'anterior_dur, simultaneous'),
#  ('Genesis 9:28', 428349, 654054, 'posterior'),
#  ('Genesis 9:28', 428349, 654055, 'atelic_ext'),
#  ('Genesis 10:1', 428353, 654069, 'posterior'),
#  ('Genesis 10:18', 428380, 654150, 'posterior'),
#  ('Genesis 10:25', 428393, 654194, 'simultaneous'),
#  ('Genesis 10:32', 428404, 654233, 'posterior'),
#  ('Genesis 11:6', 428432, 654306, 'simultaneous'),
#  ('Genesis 11:10', 428448, 654356, 'posterior_dist'),
#  ('Genesis 11:11', 428449, 654362, 'atelic_ext'),
#  ('Genesis 11:12', 428452, 654369, 'atelic_ext'),
#  ('Genesis 11:13', 428454, 654378, 'atelic_ext'),
#  ('Genesis 11:14', 428457, 654385, 'atelic_ext'),
#  ('Genesis 11:15', 428459, 654394, 'atelic_ext'),
#  ('Genesis 11:16', 428462, 654401, 'atelic_ext'),
#  ('Genesis 11:17', 428464, 654410, 'atelic_ext'),
#  ('Genesis 11:18', 428467, 654417, 'atelic_ext'),
#  ('Genesis 11:19', 428469, 654426, 'atelic_ext'),
#  ('Genesis 11:20', 428472, 654433, 'atelic_ext'),
#  ('Genesis 11:21', 428474, 654442, 'atelic_ext'),
#  ('Genesis 11:22', 428477, 654449, 'atelic_ext'),
#  ('Genesis 11:23', 428479, 654458, 'atelic_ext'),
#  ('Genesis 11:24', 428482, 654465, 'atelic_ext'),
#  ('Genesis 11:25', 428484, 654474, 'atelic_ext'),
#  ('Genesis 11:26', 428487, 654481, 'atelic_ext'),
#  ('Genesis 12:6', 428527, 654611, 'simultaneous'),
#  ('Genesis 12:19', 428578, 654777, 'simultaneous'),
#  ('Genesis 13:3', 428590, 654817, 'simultaneous'),
#  ('Genesis 13:4', 428592, 654823, 'simultaneous'),
#  ('Genesis 13:7', 428602, 654859, 'simultaneous'),
#  ('Genesis 13:15', 428633, 654961, 'anterior_dur'),
#  ('Genesis 14:1', 428646, 654998, 'simultaneous'),
#  ('Genesis 14:4', 428651, 655009, 'atelic_ext'),
#  ('Genesis 14:4', 428652, 655013, 'atelic_ext'),
#  ('Genesis 14:5', 428653, 655016, 'simultaneous'),
#  ('Genesis 14:15', 428687, 655118, 'simultaneous'),
#  ('Genesis 15:13', 428781, 655382, 'atelic_ext'),
#  ('Genesis 15:14', 428784, 655390, 'posterior'),
#  ('Genesis 15:16', 428788, 655408, 'anterior_dur'),
#  ('Genesis 15:18', 428794, 655422, 'simultaneous'),
#  ('Genesis 16:3', 428809, 655472, 'posterior'),
#  ('Genesis 17:21', 428932, 655874, 'multi_simul'),
#  ('Genesis 17:23', 428937, 655890, 'simultaneous'),
#  ('Genesis 17:26', 428943, 655905, 'simultaneous'),
#  ('Genesis 18:5', 428964, 655969, 'posterior'),
#  ('Genesis 18:10', 428989, 656037, 'simultaneous'),
#  ('Genesis 18:14', 429008, 656088, 'simultaneous'),
#  ('Genesis 18:14', 429008, 656091, 'simultaneous'),
#  ('Genesis 19:1', 429102, 656361, 'simultaneous'),
#  ('Genesis 19:5', 429131, 656436, 'simultaneous'),
#  ('Genesis 19:9', 429151, 656493, 'simultaneous'),
#  ('Genesis 19:33', 429254, 656806, 'simultaneous'),
#  ('Genesis 19:34', 429260, 656821, 'posterior, posterior_dur'),
#  ('Genesis 19:34', 429262, 656828, 'simultaneous'),
#  ('Genesis 19:34', 429263, 656832, 'simultaneous'),
#  ('Genesis 19:35', 429267, 656843, 'simultaneous'),
#  ('Genesis 19:37', 429276, 656872, 'anterior_dur'),
#  ('Genesis 19:38', 429279, 656883, 'anterior_dur'),
#  ('Genesis 20:3', 429287, 656912, 'simultaneous'),
#  ('Genesis 20:7', 429308, 656973, 'simultaneous'),
#  ('Genesis 20:8', 429317, 656998, 'simultaneous'),
#  ('Genesis 21:2', 429367, 657162, 'anterior_dur, simultaneous'),
#  ('Genesis 21:14', 429403, 657283, 'simultaneous'),
#  ('Genesis 21:22', 429443, 657402, 'simultaneous'),
#  ('Genesis 21:23', 429448, 657415, 'simultaneous'),
#  ('Genesis 21:26', 429462, 657462, 'simultaneous'),
#  ('Genesis 21:34', 429481, 657531, 'atelic_ext'),
#  ('Genesis 22:1', 429482, 657534, 'posterior'),
#  ('Genesis 22:3', 429494, 657568, 'simultaneous'),
#  ('Genesis 22:12', 429543, 657714, 'simultaneous'),
#  ('Genesis 22:14', 429555, 657755, 'simultaneous'),
#  ('Genesis 22:20', 429574, 657814, 'posterior'),
#  ('Genesis 23:19', 429656, 658036, 'posterior'),
#  ('Genesis 24:12', 429703, 658199, 'simultaneous'),
#  ('Genesis 24:41', 429833, 658551, 'simultaneous'),
#  ('Genesis 24:42', 429837, 658568, 'simultaneous'),
#  ('Genesis 24:49', 429882, 658688, 'simultaneous'),
#  ('Genesis 24:54', 429908, 658762, 'simultaneous'),
#  ('Genesis 24:55', 429913, 658774, 'posterior'),
#  ('Genesis 25:11', 429990, 658998, 'posterior'),
#  ('Genesis 25:26', 430037, 659131, 'posterior'),
#  ('Genesis 25:31', 430059, 659202, 'simultaneous'),
#  ('Genesis 25:33', 430065, 659221, 'simultaneous'),
#  ('Genesis 26:12', 430124, 659404, 'simultaneous'),
#  ('Genesis 26:15', 430132, 659431, 'simultaneous'),
#  ('Genesis 26:18', 430143, 659465, 'simultaneous'),
#  ('Genesis 26:18', 430144, 659469, 'posterior'),
#  ('Genesis 26:22', 430162, 659527, 'simultaneous'),
#  ('Genesis 26:24', 430165, 659542, 'simultaneous'),
#  ('Genesis 26:31', 430196, 659641, 'simultaneous'),
#  ('Genesis 26:32', 430201, 659655, 'simultaneous'),
#  ('Genesis 26:33', 430208, 659677, 'anterior_dur'),
#  ('Genesis 27:3', 430224, 659719, 'simultaneous'),
#  ('Genesis 27:7', 430247, 659782, 'anterior'),
#  ('Genesis 27:8', 430248, 659784, 'simultaneous'),
#  ('Genesis 27:10', 430258, 659814, 'anterior'),
#  ('Genesis 27:43', 430428, 660272, 'simultaneous'),
#  ('Genesis 27:44', 430433, 660285, 'atelic_ext'),
#  ('Genesis 27:45', 430440, 660305, 'simultaneous'),
#  ('Genesis 28:18', 430516, 660547, 'simultaneous'),
#  ('Genesis 28:19', 430522, 660570, 'anterior_dur, simultaneous'),
#  ('Genesis 29:14', 430602, 660806, 'atelic_ext'),
#  ('Genesis 29:18', 430615, 660844, 'atelic_ext'),
#  ('Genesis 29:20', 430621, 660862, 'atelic_ext'),
#  ('Genesis 29:23', 430629, 660889, 'simultaneous'),
#  ('Genesis 29:25', 430635, 660909, 'simultaneous'),
#  ('Genesis 29:27', 430646, 660949, 'atelic_ext'),
#  ('Genesis 29:30', 430655, 660981, 'atelic_ext'),
#  ('Genesis 29:32', 430665, 661011, 'simultaneous'),
#  ('Genesis 29:34', 430676, 661044, 'simultaneous'),
#  ('Genesis 30:14', 430731, 661223, 'simultaneous'),
#  ('Genesis 30:15', 430741, 661256, 'simultaneous'),
#  ('Genesis 30:16', 430742, 661262, 'simultaneous'),
#  ('Genesis 30:16', 430748, 661278, 'simultaneous'),
#  ('Genesis 30:21', 430763, 661330, 'posterior'),
#  ('Genesis 30:30', 430797, 661433, 'anterior'),
#  ('Genesis 30:30', 430800, 661443, 'simultaneous'),
#  ('Genesis 30:32', 430810, 661470, 'simultaneous'),
#  ('Genesis 30:33', 430813, 661481, 'simultaneous'),
#  ('Genesis 30:35', 430821, 661502, 'simultaneous'),
#  ('Genesis 31:16', 430917, 661805, 'simultaneous'),
#  ('Genesis 31:22', 430938, 661868, 'simultaneous'),
#  ('Genesis 31:24', 430943, 661889, 'simultaneous'),
#  ('Genesis 31:29', 430965, 661954, 'simultaneous'),
#  ('Genesis 31:30', 430969, 661964, 'simultaneous'),
#  ('Genesis 31:38', 431012, 662090, 'atelic_ext'),
#  ('Genesis 31:40', 431019, 662109, 'simultaneous'),
#  ('Genesis 31:40', 431020, 662114, 'simultaneous'),
#  ('Genesis 31:41', 431024, 662124, 'atelic_ext'),
#  ('Genesis 31:41', 431025, 662127, 'atelic_ext'),
#  ('Genesis 31:42', 431028, 662138, 'simultaneous'),
#  ('Genesis 31:42', 431030, 662146, 'simultaneous'),
#  ('Genesis 31:43', 431040, 662173, 'simultaneous'),
#  ('Genesis 31:44', 431043, 662179, 'simultaneous'),
#  ('Genesis 31:48', 431057, 662225, 'simultaneous'),
#  ('Genesis 32:1', 431084, 662312, 'simultaneous'),
#  ('Genesis 32:11', 431128, 662437, 'simultaneous'),
#  ('Genesis 32:14', 431137, 662470, 'simultaneous'),
#  ('Genesis 32:21', 431169, 662550, 'posterior'),
#  ('Genesis 32:22', 431172, 662563, 'simultaneous'),
#  ('Genesis 32:23', 431173, 662567, 'simultaneous'),
#  ('Genesis 32:33', 431215, 662689, 'anterior_dur'),
#  ('Genesis 33:7', 431246, 662772, 'posterior'),
#  ('Genesis 33:13', 431279, 662863, 'simultaneous'),
#  ('Genesis 33:16', 431290, 662898, 'simultaneous'),
#  ('Genesis 34:25', 431399, 663235, 'simultaneous'),
#  ('Genesis 35:3', 431443, 663359, 'simultaneous'),
#  ('Genesis 35:20', 431513, 663577, 'anterior_dur'),
#  ('Genesis 37:20', 431719, 664180, 'simultaneous'),
#  ('Genesis 37:34', 431795, 664392, 'atelic_ext'),
#  ('Genesis 38:1', 431805, 664419, 'simultaneous'),
#  ('Genesis 38:24', 431913, 664737, 'simultaneous'),
#  ('Genesis 38:30', 431951, 664834, 'posterior'),
#  ('Genesis 39:7', 431981, 664940, 'posterior'),
#  ('Genesis 39:10', 431998, 664994, 'multi_simuls, atelic_ext'),
#  ('Genesis 39:11', 432002, 665005, 'simultaneous'),
#  ('Genesis 40:1', 432065, 665181, 'posterior'),
#  ('Genesis 40:4', 432072, 665208, 'atelic_ext'),
#  ('Genesis 40:5', 432074, 665216, 'telic_ext, dist_fut, dist_past'),
#  ('Genesis 40:6', 432078, 665228, 'simultaneous'),
#  ('Genesis 40:7', 432084, 665245, 'simultaneous'),
#  ('Genesis 40:13', 432107, 665312, 'dist_fut'),
#  ('Genesis 40:19', 432132, 665390, 'dist_fut'),
#  ('Genesis 41:1', 432145, 665441, 'posterior'),
#  ('Genesis 41:3', 432150, 665461, 'posterior'),
#  ('Genesis 41:8', 432161, 665501, 'simultaneous'),
#  ('Genesis 41:9', 432170, 665528, 'simultaneous'),
#  ('Genesis 41:11', 432173, 665539, 'telic_ext, dist_fut, dist_past'),
#  ('Genesis 41:27', 432234, 665710, 'posterior'),
#  ('Genesis 41:31', 432247, 665750, 'posterior'),
#  ('Genesis 41:33', 432253, 665769, 'simultaneous'),
#  ('Genesis 41:34', 432258, 665785, 'telic_ext, dist_fut, dist_past'),
#  ('Genesis 41:36', 432263, 665802, 'anterior_dur, simultaneous'),
#  ('Genesis 41:47', 432298, 665927, 'telic_ext, dist_fut, dist_past'),
#  ('Genesis 42:13', 432397, 666212, 'simultaneous'),
#  ('Genesis 42:17', 432418, 666265, 'atelic_ext'),
#  ('Genesis 42:18', 432419, 666270, 'simultaneous'),
#  ('Genesis 42:32', 432490, 666470, 'simultaneous'),
#  ('Genesis 43:9', 432574, 666717, 'atelic_ext'),
#  ('Genesis 43:16', 432606, 666816, 'telic_ext, dist_fut, dist_past'),
#  ('Genesis 43:25', 432646, 666938, 'telic_ext, dist_fut, dist_past'),
#  ('Genesis 44:10', 432738, 667191, 'simultaneous'),
#  ('Genesis 44:28', 432829, 667448, 'anterior_dur'),
#  ('Genesis 44:30', 432833, 667462, 'simultaneous'),
#  ('Genesis 44:32', 432846, 667500, 'atelic_ext'),
#  ('Genesis 44:33', 432847, 667502, 'simultaneous'),
#  ('Genesis 45:5', 432877, 667595, 'simultaneous'),
#  ('Genesis 45:6', 432882, 667613, 'atelic_ext'),
#  ('Genesis 45:8', 432888, 667635, 'simultaneous'),
#  ('Genesis 45:15', 432919, 667724, 'posterior'),
#  ('Genesis 46:34', 433071, 668170, 'begin_to_end'),
#  ('Genesis 47:4', 433093, 668230, 'simultaneous'),
#  ('Genesis 47:17', 433140, 668389, 'simultaneous'),
#  ('Genesis 47:18', 433142, 668396, 'simultaneous'),
#  ('Genesis 47:23', 433168, 668485, 'simultaneous'),
#  ('Genesis 47:24', 433171, 668495, 'simultaneous'),
#  ('Genesis 47:26', 433180, 668526, 'anterior_dur'),
#  ('Genesis 47:28', 433187, 668550, 'atelic_ext'),
#  ('Genesis 48:1', 433206, 668609, 'posterior'),
#  ('Genesis 48:5', 433223, 668662, 'simultaneous'),
#  ('Genesis 48:6', 433230, 668681, 'posterior'),
#  ('Genesis 48:7', 433234, 668696, 'simultaneous'),
#  ('Genesis 48:15', 433275, 668816, 'posterior_dur'),
#  ('Genesis 48:15', 433275, 668817, 'anterior_dur'),
#  ('Genesis 48:20', 433299, 668889, 'simultaneous'),
#  ('Genesis 49:1', 433315, 668940, 'simultaneous'),
#  ('Genesis 49:4', 433327, 668960, 'simultaneous'),
#  ('Genesis 49:27', 433409, 669158, 'simultaneous'),
#  ('Genesis 49:27', 433410, 669162, 'anterior_dur, simultaneous'),
#  ('Genesis 50:3', 433445, 669268, 'atelic_ext'),
#  ('Genesis 50:5', 433458, 669300, 'simultaneous'),
#  ('Genesis 50:10', 433476, 669352, 'atelic_ext'),
#  ('Genesis 50:16', 433499, 669428, 'anterior'),
#  ('Genesis 50:17', 433504, 669441, 'simultaneous'),
#  ('Genesis 50:20', 433517, 669480, 'simultaneous'),
#  ('Genesis 50:21', 433519, 669484, 'simultaneous'),
#  ('Genesis 50:22', 433525, 669503, 'atelic_ext'),
#  ('Exodus 2:2', 433617, 669787, 'atelic_ext'),
#  ('Exodus 2:11', 433659, 669913, 'simultaneous'),
#  ('Exodus 2:13', 433670, 669945, 'simultaneous'),
#  ('Exodus 2:18', 433703, 670028, 'simultaneous'),
#  ('Exodus 2:23', 433720, 670078, 'simultaneous'),
#  ('Exodus 3:9', 433769, 670220, 'simultaneous'),
#  ('Exodus 3:10', 433773, 670234, 'simultaneous'),
#  ('Exodus 3:15', 433804, 670325, 'anterior_dur, simultaneous'),
#  ('Exodus 3:18', 433820, 670370, 'simultaneous'),
#  ('Exodus 3:20', 433830, 670401, 'posterior'),
#  ('Exodus 4:10', 433888, 670578, 'posterior, posterior_dur'),
#  ('Exodus 4:10', 433888, 670579, 'posterior, posterior_dur'),
#  ('Exodus 4:10', 433888, 670580, 'posterior, posterior_dur'),
#  ('Exodus 4:12', 433895, 670602, 'simultaneous'),
#  ('Exodus 5:1', 433994, 670881, 'posterior'),
#  ('Exodus 5:5', 434015, 670944, 'simultaneous'),
#  ('Exodus 5:6', 434017, 670953, 'simultaneous'),
#  ('Exodus 5:8', 434026, 670975, 'dist_past'),
#  ('Exodus 5:14', 434054, 671058, 'multi_simuls, atelic_ext'),
#  ('Exodus 5:18', 434071, 671098, 'simultaneous'),
#  ('Exodus 6:1', 434099, 671171, 'simultaneous'),
#  ('Exodus 7:15', 434239, 671609, 'simultaneous'),
#  ('Exodus 7:16', 434251, 671640, 'anterior_dur'),
#  ('Exodus 8:5', 434327, 671875, 'anterior_dur, simultaneous'),
#  ('Exodus 8:6', 434331, 671885, 'anterior_dur, simultaneous'),
#  ('Exodus 8:16', 434370, 672012, 'simultaneous'),
#  ('Exodus 8:18', 434382, 672049, 'simultaneous'),
#  ('Exodus 8:19', 434388, 672067, 'anterior_dur, simultaneous'),
#  ('Exodus 8:25', 434416, 672150, 'simultaneous'),
#  ('Exodus 8:28', 434426, 672182, 'simultaneous'),
#  ('Exodus 9:5', 434445, 672233, 'simultaneous'),
#  ('Exodus 9:6', 434446, 672242, 'posterior, posterior_dur'),
#  ('Exodus 9:14', 434478, 672351, 'simultaneous'),
#  ('Exodus 9:15', 434482, 672365, 'simultaneous'),
#  ('Exodus 9:18', 434491, 672391, 'simultaneous'),
#  ('Exodus 9:19', 434494, 672401, 'simultaneous'),
#  ('Exodus 10:3', 434577, 672660, 'anterior_dur'),
#  ('Exodus 10:4', 434581, 672676, 'simultaneous'),
#  ('Exodus 10:7', 434597, 672721, 'anterior_dur'),
#  ('Exodus 10:7', 434600, 672732, 'anterior'),
#  ('Exodus 10:13', 434629, 672818, 'atelic_ext'),
#  ('Exodus 10:14', 434635, 672833, 'anterior'),
#  ('Exodus 10:14', 434636, 672840, 'posterior'),
#  ('Exodus 10:17', 434646, 672872, 'simultaneous'),
#  ('Exodus 10:22', 434663, 672935, 'atelic_ext'),
#  ('Exodus 10:23', 434664, 672945, 'atelic_ext'),
#  ('Exodus 11:1', 434701, 673039, 'posterior'),
#  ('Exodus 11:4', 434712, 673075, 'simultaneous'),
#  ('Exodus 11:8', 434728, 673126, 'posterior'),
#  ('Exodus 12:6', 434753, 673208, 'anterior_dur'),
#  ('Exodus 12:6', 434754, 673214, 'simultaneous'),
#  ('Exodus 12:8', 434758, 673228, 'simultaneous'),
#  ('Exodus 12:10', 434763, 673246, 'anterior_dur'),
#  ('Exodus 12:10', 434765, 673251, 'anterior_dur'),
#  ('Exodus 12:12', 434772, 673275, 'simultaneous'),
#  ('Exodus 12:14', 434783, 673317, 'anterior_dur, simultaneous'),
#  ('Exodus 12:15', 434785, 673320, 'atelic_ext'),
#  ('Exodus 12:15', 434786, 673323, 'simultaneous'),
#  ('Exodus 12:16', 434790, 673338, 'simultaneous'),
#  ('Exodus 12:16', 434791, 673341, 'simultaneous'),
#  ('Exodus 12:17', 434796, 673361, 'simultaneous'),
#  ('Exodus 12:17', 434797, 673368, 'anterior_dur, simultaneous'),
#  ('Exodus 12:19', 434799, 673379, 'atelic_ext'),
#  ('Exodus 12:22', 434815, 673435, 'anterior_dur'),
#  ('Exodus 12:24', 434824, 673461, 'anterior_dur'),
#  ('Exodus 12:29', 434844, 673517, 'simultaneous'),
#  ('Exodus 12:30', 434848, 673530, 'simultaneous'),
#  ('Exodus 12:31', 434852, 673545, 'simultaneous'),
#  ('Exodus 12:41', 434891, 673650, 'simultaneous'),
#  ('Exodus 12:42', 434895, 673664, 'anterior_dur, simultaneous'),
#  ('Exodus 12:44', 434901, 673681, 'simultaneous'),
#  ('Exodus 12:48', 434910, 673716, 'simultaneous'),
#  ('Exodus 12:51', 434919, 673744, 'simultaneous'),
#  ('Exodus 13:4', 434931, 673780, 'simultaneous'),
#  ('Exodus 13:4', 434931, 673783, 'simultaneous'),
#  ('Exodus 13:5', 434936, 673798, 'simultaneous'),
#  ('Exodus 13:6', 434937, 673799, 'atelic_ext'),
#  ('Exodus 13:6', 434938, 673803, 'simultaneous'),
#  ('Exodus 13:7', 434939, 673808, 'atelic_ext'),
#  ('Exodus 13:8', 434942, 673823, 'simultaneous'),
#  ('Exodus 13:10', 434949, 673848, 'begin_to_end'),
#  ('Exodus 13:14', 434963, 673891, 'simultaneous'),
#  ('Exodus 13:21', 434994, 673991, 'atelic_ext'),
#  ('Exodus 13:21', 434996, 673996, 'simultaneous'),
#  ('Exodus 13:21', 434998, 674001, 'atelic_ext'),
#  ('Exodus 13:22', 434999, 674005, 'atelic_ext'),
#  ('Exodus 13:22', 435000, 674008, 'simultaneous'),
#  ('Exodus 14:13', 435057, 674177, 'simultaneous'),
#  ('Exodus 14:13', 435058, 674187, 'anterior_dur'),
#  ('Exodus 14:13', 435059, 674182, 'simultaneous'),
#  ('Exodus 14:20', 435086, 674270, 'atelic_ext'),
#  ('Exodus 14:21', 435088, 674281, 'atelic_ext'),
#  ('Exodus 14:24', 435095, 674309, 'simultaneous'),
#  ('Exodus 14:30', 435118, 674392, 'simultaneous'),
#  ('Exodus 15:1', 435125, 674416, 'simultaneous'),
#  ('Exodus 15:18', 435196, 674571, 'anterior_dur, simultaneous'),
#  ('Exodus 15:22', 435208, 674619, 'atelic_ext'),
#  ('Exodus 16:1', 435237, 674714, 'simultaneous'),
#  ('Exodus 16:5', 435255, 674767, 'simultaneous'),
#  ('Exodus 16:5', 435259, 674777, 'multi_simuls, atelic_ext'),
#  ('Exodus 16:8', 435271, 674810, 'simultaneous'),
#  ('Exodus 16:8', 435273, 674815, 'simultaneous'),
#  ('Exodus 16:12', 435295, 674866, 'simultaneous'),
#  ('Exodus 16:12', 435296, 674870, 'simultaneous'),
#  ('Exodus 16:13', 435299, 674880, 'simultaneous'),
#  ('Exodus 16:13', 435302, 674888, 'simultaneous'),
#  ('Exodus 16:19', 435336, 674976, 'anterior_dur'),
#  ('Exodus 16:20', 435338, 674985, 'anterior_dur'),
#  ('Exodus 16:21', 435342, 674998, 'habitual, multi_simul'),
#  ('Exodus 16:22', 435347, 675008, 'simultaneous'),
#  ('Exodus 16:23', 435353, 675026, 'simultaneous'),
#  ('Exodus 16:23', 435358, 675039, 'anterior_dur'),
#  ('Exodus 16:24', 435359, 675043, 'anterior_dur'),
#  ('Exodus 16:25', 435364, 675059, 'simultaneous'),
#  ('Exodus 16:25', 435365, 675062, 'simultaneous'),
#  ('Exodus 16:25', 435366, 675064, 'simultaneous'),
#  ('Exodus 16:26', 435367, 675068, 'atelic_ext'),
#  ('Exodus 16:26', 435368, 675071, 'simultaneous'),
#  ('Exodus 16:27', 435371, 675078, 'simultaneous'),
#  ('Exodus 16:28', 435375, 675089, 'anterior_dur'),
#  ('Exodus 16:29', 435379, 675103, 'simultaneous'),
#  ('Exodus 16:29', 435382, 675112, 'simultaneous'),
#  ('Exodus 16:30', 435383, 675116, 'simultaneous'),
#  ('Exodus 16:35', 435400, 675179, 'atelic_ext'),
#  ('Exodus 17:9', 435450, 675327, 'simultaneous'),
#  ('Exodus 17:16', 435481, 675428, 'posterior, posterior_dur'),
#  ('Exodus 18:2', 435485, 675446, 'posterior'),
#  ('Exodus 18:13', 435526, 675569, 'posterior, posterior_dur'),
#  ('Exodus 18:13', 435529, 675579, 'begin_to_end'),
#  ('Exodus 18:14', 435536, 675604, 'begin_to_end'),
#  ('Exodus 18:22', 435564, 675691, 'simultaneous'),
#  ('Exodus 18:26', 435580, 675742, 'simultaneous'),
#  ('Exodus 19:1', 435585, 675758, 'simultaneous'),
#  ('Exodus 19:5', 435600, 675809, 'simultaneous'),
#  ('Exodus 19:9', 435621, 675881, 'anterior_dur, simultaneous'),
#  ('Exodus 19:10', 435625, 675895, 'multi_simuls'),
#  ('Exodus 19:11', 435627, 675902, 'anterior_dur, simultaneous'),
#  ('Exodus 19:11', 435628, 675904, 'simultaneous'),
#  ('Exodus 19:15', 435648, 675964, 'anterior_dur, simultaneous'),
#  ('Exodus 19:16', 435650, 675970, 'simultaneous'),
#  ('Exodus 20:9', 435717, 676162, 'atelic_ext'),
#  ('Exodus 20:11', 435722, 676178, 'atelic_ext'),
#  ('Exodus 20:11', 435724, 676186, 'simultaneous'),
#  ('Exodus 21:2', 435776, 676349, 'atelic_ext'),
#  ('Exodus 21:2', 435777, 676352, 'simultaneous'),
#  ('Exodus 21:6', 435792, 676408, 'anterior_dur, simultaneous'),
#  ('Exodus 21:21', 435841, 676552, 'atelic_ext'),
#  ('Exodus 21:29', 435870, 676642, 'posterior, posterior_dur'),
#  ('Exodus 21:36', 435898, 676734, 'posterior, posterior_dur'),
#  ('Exodus 22:29', 436006, 677062, 'atelic_ext'),
#  ('Exodus 22:29', 436007, 677065, 'simultaneous'),
#  ('Exodus 23:10', 436038, 677163, 'atelic_ext'),
#  ('Exodus 23:11', 436040, 677170, 'simultaneous'),
#  ('Exodus 23:12', 436045, 677185, 'atelic_ext'),
#  ('Exodus 23:12', 436046, 677189, 'simultaneous'),
#  ('Exodus 23:14', 436053, 677213, 'simultaneous'),
#  ('Exodus 23:15', 436055, 677216, 'atelic_ext'),
#  ('Exodus 23:29', 436102, 677374, 'telic_ext, dist_fut, dist_past'),
#  ('Exodus 24:4', 436129, 677467, 'simultaneous'),
#  ('Exodus 24:16', 436175, 677608, 'atelic_ext'),
#  ('Exodus 24:16', 436176, 677612, 'simultaneous'),
#  ('Exodus 24:18', 436180, 677630, 'atelic_ext'),
#  ('Exodus 25:30', 436257, 677881, 'atelic_ext'),
#  ('Exodus 27:21', 436445, 678469, 'begin_to_end'),
#  ('Exodus 28:29', 436514, 678694, 'atelic_ext'),
#  ('Exodus 28:30', 436519, 678710, 'atelic_ext'),
#  ('Exodus 28:38', 436544, 678789, 'atelic_ext'),
#  ('Exodus 29:30', 436654, 679153, 'atelic_ext'),
#  ('Exodus 29:34', 436667, 679196, 'anterior_dur'),
#  ('Exodus 29:35', 436674, 679214, 'atelic_ext'),
#  ('Exodus 29:36', 436675, 679220, 'anterior_dur, simultaneous'),
#  ('Exodus 29:37', 436680, 679231, 'atelic_ext'),
#  ('Exodus 29:38', 436687, 679252, 'anterior_dur, simultaneous'),
#  ('Exodus 29:39', 436688, 679256, 'simultaneous'),
#  ('Exodus 29:39', 436689, 679260, 'simultaneous'),
#  ('Exodus 29:41', 436692, 679269, 'simultaneous'),
#  ('Exodus 30:7', 436729, 679386, 'habitual, multi_simul'),
#  ('Exodus 30:8', 436732, 679394, 'simultaneous'),
#  ('Exodus 31:15', 436862, 679767, 'atelic_ext'),
#  ('Exodus 31:15', 436866, 679779, 'simultaneous'),
#  ('Exodus 31:17', 436869, 679793, 'anterior_dur, simultaneous'),
#  ('Exodus 31:17', 436870, 679795, 'atelic_ext'),
#  ('Exodus 32:5', 436907, 679898, 'simultaneous'),
#  ('Exodus 32:6', 436908, 679901, 'posterior, posterior_dur'),
#  ('Exodus 32:10', 436934, 679962, 'simultaneous'),
#  ('Exodus 32:13', 436957, 680028, 'anterior_dur, simultaneous'),
#  ('Exodus 32:28', 437030, 680234, 'simultaneous'),
#  ('Exodus 32:29', 437032, 680241, 'simultaneous'),
#  ('Exodus 32:29', 437034, 680249, 'simultaneous'),
#  ('Exodus 32:30', 437035, 680253, 'posterior, posterior_dur'),
#  ('Exodus 32:30', 437038, 680262, 'simultaneous'),
#  ('Exodus 32:32', 437045, 680283, 'simultaneous'),
#  ('Exodus 32:34', 437054, 680306, 'simultaneous'),
#  ('Exodus 33:5', 437084, 680389, 'atelic_ext, simultaneous'),
#  ('Exodus 33:5', 437086, 680395, 'simultaneous'),
#  ('Exodus 33:13', 437129, 680519, 'simultaneous'),
#  ('Exodus 34:2', 437183, 680676, 'anterior_dur, simultaneous'),
#  ('Exodus 34:2', 437184, 680679, 'simultaneous'),
#  ('Exodus 34:4', 437190, 680707, 'simultaneous'),
#  ('Exodus 34:11', 437225, 680811, 'simultaneous'),
#  ('Exodus 34:18', 437248, 680883, 'atelic_ext'),
#  ('Exodus 34:18', 437249, 680888, 'anterior_dur, simultaneous'),
#  ('Exodus 34:18', 437250, 680890, 'simultaneous'),
#  ('Exodus 34:21', 437259, 680916, 'atelic_ext'),
#  ('Exodus 34:21', 437260, 680919, 'simultaneous'),
#  ('Exodus 34:21', 437261, 680921, 'habitual, multi_simul'),
#  ('Exodus 34:28', 437277, 680981, 'atelic_ext'),
#  ('Exodus 34:32', 437295, 681037, 'posterior'),
#  ('Exodus 35:2', 437318, 681102, 'atelic_ext'),
#  ('Exodus 35:2', 437319, 681106, 'simultaneous'),
#  ('Exodus 35:3', 437322, 681120, 'simultaneous'),
#  ('Exodus 36:3', 437404, 681342, 'habitual, multi_simul'),
#  ('Exodus 40:2', 437770, 682450, 'simultaneous'),
#  ('Exodus 40:2', 437770, 682451, 'simultaneous'),
#  ('Exodus 40:15', 437806, 682574, 'anterior_dur, simultaneous'),
#  ('Exodus 40:17', 437812, 682587, 'simultaneous'),
#  ('Exodus 40:17', 437812, 682588, 'simultaneous'),
#  ('Exodus 40:17', 437812, 682589, 'simultaneous'),
#  ('Exodus 40:38', 437864, 682785, 'atelic_ext'),
#  ('Exodus 40:38', 437865, 682789, 'simultaneous'),
#  ('Leviticus 6:2', 438280, 684117, 'atelic_ext'),
#  ('Leviticus 6:2', 438280, 684118, 'anterior_dur'),
#  ('Leviticus 6:5', 438293, 684164, 'habitual, multi_simul'),
#  ('Leviticus 7:15', 438413, 684480, 'simultaneous'),
#  ('Leviticus 7:15', 438414, 684485, 'anterior_dur'),
#  ('Leviticus 7:17', 438422, 684505, 'simultaneous'),
#  ('Leviticus 7:18', 438423, 684513, 'simultaneous'),
#  ('Leviticus 8:33', 438594, 685063, 'atelic_ext'),
#  ('Leviticus 8:34', 438595, 685068, 'simultaneous'),
#  ('Leviticus 8:35', 438599, 685077, 'atelic_ext'),
#  ('Leviticus 8:35', 438599, 685078, 'atelic_ext'),
#  ('Leviticus 9:1', 438605, 685098, 'simultaneous'),
#  ('Leviticus 9:4', 438617, 685126, 'simultaneous'),
#  ('Leviticus 10:19', 438755, 685575, 'simultaneous'),
#  ('Leviticus 10:19', 438757, 685586, 'simultaneous'),
#  ('Leviticus 11:24', 438832, 685785, 'anterior_dur'),
#  ('Leviticus 11:25', 438836, 685795, 'anterior_dur'),
#  ('Leviticus 11:27', 438848, 685832, 'anterior_dur'),
#  ('Leviticus 11:28', 438852, 685841, 'anterior_dur'),
#  ('Leviticus 11:31', 438859, 685864, 'anterior_dur'),
#  ('Leviticus 11:32', 438865, 685882, 'anterior_dur'),
#  ('Leviticus 11:39', 438894, 685967, 'anterior_dur'),
#  ('Leviticus 11:40', 438897, 685976, 'anterior_dur'),
#  ('Leviticus 11:40', 438900, 685985, 'anterior_dur'),
#  ('Leviticus 12:2', 438941, 686092, 'atelic_ext'),
#  ('Leviticus 12:3', 438943, 686096, 'simultaneous'),
#  ('Leviticus 12:4', 438944, 686100, 'atelic_ext'),
#  ('Leviticus 12:5', 438949, 686118, 'atelic_ext'),
#  ('Leviticus 12:5', 438950, 686121, 'atelic_ext'),
#  ('Leviticus 13:4', 438979, 686222, 'atelic_ext'),
#  ('Leviticus 13:5', 438980, 686226, 'simultaneous'),
#  ('Leviticus 13:5', 438983, 686239, 'atelic_ext'),
#  ('Leviticus 13:6', 438984, 686245, 'simultaneous'),
#  ('Leviticus 13:21', 439051, 686447, 'atelic_ext'),
#  ('Leviticus 13:26', 439075, 686524, 'atelic_ext'),
#  ('Leviticus 13:27', 439076, 686528, 'simultaneous'),
#  ('Leviticus 13:31', 439099, 686604, 'atelic_ext'),
#  ('Leviticus 13:32', 439100, 686609, 'simultaneous'),
#  ('Leviticus 13:33', 439107, 686635, 'atelic_ext'),
#  ('Leviticus 13:34', 439108, 686641, 'simultaneous'),
#  ('Leviticus 13:35', 439116, 686668, 'posterior'),
#  ('Leviticus 13:50', 439171, 686818, 'atelic_ext'),
#  ('Leviticus 13:51', 439172, 686822, 'simultaneous'),
#  ('Leviticus 13:54', 439187, 686867, 'atelic_ext'),
#  ('Leviticus 14:2', 439215, 686943, 'simultaneous'),
#  ('Leviticus 14:8', 439236, 687009, 'posterior'),
#  ('Leviticus 14:8', 439237, 687015, 'atelic_ext'),
#  ('Leviticus 14:9', 439238, 687018, 'simultaneous'),
#  ('Leviticus 14:10', 439244, 687034, 'simultaneous'),
#  ('Leviticus 14:19', 439271, 687131, 'posterior'),
#  ('Leviticus 14:23', 439286, 687182, 'simultaneous'),
#  ('Leviticus 14:36', 439326, 687318, 'posterior'),
#  ('Leviticus 14:38', 439332, 687342, 'atelic_ext'),
#  ('Leviticus 14:39', 439333, 687346, 'simultaneous'),
#  ('Leviticus 14:46', 439359, 687433, 'anterior_dur'),
#  ('Leviticus 15:5', 439405, 687569, 'anterior_dur'),
#  ('Leviticus 15:6', 439410, 687585, 'anterior_dur'),
#  ('Leviticus 15:7', 439414, 687597, 'anterior_dur'),
#  ('Leviticus 15:8', 439418, 687611, 'anterior_dur'),
#  ('Leviticus 15:10', 439421, 687628, 'anterior_dur'),
#  ('Leviticus 15:10', 439427, 687640, 'anterior_dur'),
#  ('Leviticus 15:11', 439433, 687660, 'anterior_dur'),
#  ('Leviticus 15:14', 439442, 687692, 'simultaneous'),
#  ('Leviticus 15:16', 439452, 687730, 'anterior_dur'),
#  ('Leviticus 15:17', 439456, 687742, 'anterior_dur'),
#  ('Leviticus 15:18', 439460, 687755, 'anterior_dur'),
#  ('Leviticus 15:19', 439464, 687765, 'atelic_ext'),
#  ('Leviticus 15:19', 439465, 687774, 'anterior_dur'),
#  ('Leviticus 15:21', 439474, 687800, 'anterior_dur'),
#  ('Leviticus 15:22', 439479, 687816, 'anterior_dur'),
#  ('Leviticus 15:23', 439484, 687830, 'anterior_dur'),
#  ('Leviticus 15:24', 439487, 687843, 'atelic_ext'),
#  ('Leviticus 15:25', 439493, 687861, 'atelic_ext'),
#  ('Leviticus 15:26', 439496, 687870, 'atelic_ext'),
#  ('Leviticus 15:27', 439503, 687896, 'anterior_dur'),
#  ('Leviticus 15:28', 439506, 687906, 'posterior'),
#  ('Leviticus 15:29', 439507, 687909, 'simultaneous'),
#  ('Leviticus 16:1', 439523, 687969, 'posterior'),
#  ('Leviticus 16:2', 439528, 687983, 'simultaneous'),
#  ('Leviticus 16:26', 439619, 688279, 'posterior'),
#  ('Leviticus 16:28', 439627, 688306, 'posterior'),
#  ('Leviticus 16:29', 439629, 688313, 'cal_simul'),
#  ('Leviticus 16:30', 439632, 688325, 'simultaneous'),
#  ('Leviticus 17:15', 439716, 688579, 'anterior_dur'),
#  ('Leviticus 18:18', 439775, 688736, 'simultaneous'),
#  ('Leviticus 19:6', 439831, 688904, 'simultaneous'),
#  ('Leviticus 19:6', 439832, 688907, 'posterior, posterior_dur'),
#  ('Leviticus 19:6', 439834, 688911, 'anterior_dur'),
#  ('Leviticus 19:7', 439835, 688918, 'simultaneous'),
#  ('Leviticus 19:13', 439859, 688988, 'anterior_dur'),
#  ('Leviticus 19:23', 439899, 689121, 'atelic_ext'),
#  ('Leviticus 19:24', 439901, 689128, 'simultaneous'),
#  ('Leviticus 19:25', 439903, 689135, 'simultaneous'),
#  ('Leviticus 22:6', 440175, 689927, 'anterior_dur'),
#  ('Leviticus 22:7', 440180, 689942, 'posterior'),
#  ('Leviticus 22:27', 440249, 690156, 'atelic_ext'),
#  ('Leviticus 22:27', 440250, 690159, 'begin_to_end'),
#  ('Leviticus 22:28', 440252, 690168, 'simultaneous'),
#  ('Leviticus 22:30', 440255, 690176, 'simultaneous'),
#  ('Leviticus 22:30', 440256, 690181, 'anterior_dur'),
#  ('Leviticus 23:3', 440276, 690229, 'atelic_ext'),
#  ('Leviticus 23:6', 440284, 690253, 'atelic_ext'),
#  ('Leviticus 23:7', 440285, 690256, 'simultaneous'),
#  ('Leviticus 23:8', 440287, 690267, 'atelic_ext'),
#  ('Leviticus 23:11', 440299, 690302, 'posterior, posterior_dur'),
#  ('Leviticus 23:14', 440306, 690326, 'anterior_dur'),
#  ('Leviticus 23:21', 440325, 690388, 'simultaneous'),
#  ('Leviticus 23:27', 440344, 690438, 'simultaneous'),
#  ('Leviticus 23:28', 440348, 690455, 'simultaneous'),
#  ('Leviticus 23:29', 440352, 690467, 'simultaneous'),
#  ('Leviticus 23:30', 440355, 690476, 'simultaneous'),
#  ('Leviticus 23:32', 440361, 690492, '?'),
#  ('Leviticus 23:34', 440366, 690503, 'simultaneous'),
#  ('Leviticus 23:34', 440366, 690505, 'atelic_ext'),
#  ('Leviticus 23:36', 440369, 690511, 'atelic_ext'),
#  ('Leviticus 23:36', 440370, 690515, 'simultaneous'),
#  ('Leviticus 23:39', 440379, 690542, 'simultaneous'),
#  ('Leviticus 23:39', 440379, 690547, 'atelic_ext'),
#  ('Leviticus 23:40', 440383, 690556, 'simultaneous'),
#  ('Leviticus 23:40', 440384, 690561, 'atelic_ext'),
#  ('Leviticus 23:41', 440385, 690566, 'atelic_ext + simultaneous'),
#  ('Leviticus 23:41', 440387, 690569, 'simultaneous'),
#  ('Leviticus 23:42', 440388, 690574, 'atelic_ext'),
#  ('Leviticus 24:3', 440400, 690613, 'begin_to_end'),
#  ('Leviticus 24:8', 440411, 690650, 'habitual, multi_simul'),
#  ('Leviticus 25:3', 440475, 690834, 'atelic_ext'),
#  ('Leviticus 25:3', 440476, 690838, 'atelic_ext'),
#  ('Leviticus 25:4', 440478, 690845, 'simultaneous'),
#  ('Leviticus 25:9', 440491, 690894, 'cal_simul'),
#  ('Leviticus 25:9', 440492, 690895, 'simultaneous'),
#  ('Leviticus 25:13', 440508, 690942, 'simultaneous'),
#  ('Leviticus 25:20', 440531, 691016, 'simultaneous'),
#  ('Leviticus 25:21', 440534, 691028, 'simultaneous'),
#  ('Leviticus 25:22', 440537, 691040, 'anterior_dur'),
#  ('Leviticus 25:28', 440559, 691118, 'anterior_dur'),
#  ('Leviticus 25:29', 440567, 691135, 'atelic_ext'),
#  ('Leviticus 25:40', 440605, 691263, 'anterior_dur'),
#  ('Leviticus 25:46', 440627, 691328, 'anterior_dur, simultaneous'),
#  ('Leviticus 25:50', 440641, 691372, 'anterior_dur'),
#  ('Leviticus 25:52', 440647, 691391, 'simul_to_end'),
#  ('Leviticus 26:4', 440669, 691464, 'simultaneous'),
#  ('Leviticus 26:34', 440775, 691854, 'simultaneous'),
#  ('Leviticus 26:41', 440801, 691943, 'simultaneous'),
#  ('Leviticus 26:41', 440802, 691947, 'simultaneous'),
#  ('Leviticus 27:17', 440881, 692211, 'posterior, posterior_dur'),
#  ('Leviticus 27:18', 440883, 692218, 'posterior'),
#  ('Leviticus 27:18', 440885, 692229, 'anterior_dur'),
#  ('Leviticus 27:23', 440900, 692287, 'simultaneous'),
#  ('Leviticus 27:24', 440902, 692289, 'simultaneous'),
#  ('Numbers 1:1', 440943, 692414, 'simultaneous'),
#  ('Numbers 1:18', 440972, 692480, 'simultaneous'),
#  ('Numbers 4:15', 441266, 693287, 'posterior'),
#  ('Numbers 5:26', 441452, 693855, 'posterior'),
#  ('Numbers 6:4', 441487, 693963, 'atelic_ext'),
#  ('Numbers 6:5', 441489, 693971, 'atelic_ext'),
#  ('Numbers 6:8', 441499, 693999, 'atelic_ext'),
#  ('Numbers 6:9', 441502, 694016, 'simultaneous'),
#  ('Numbers 6:9', 441503, 694017, 'simultaneous'),
#  ('Numbers 6:10', 441504, 694020, 'simultaneous'),
#  ('Numbers 6:11', 441509, 694042, 'simultaneous'),
#  ('Numbers 6:20', 441542, 694145, 'posterior'),
#  ('Numbers 7:12', 441597, 694309, 'simultaneous'),
#  ('Numbers 7:18', 441609, 694335, 'simultaneous'),
#  ('Numbers 7:24', 441620, 694361, 'simultaneous'),
#  ('Numbers 7:30', 441631, 694385, 'simultaneous'),
#  ('Numbers 7:36', 441642, 694409, 'simultaneous'),
#  ('Numbers 7:42', 441653, 694433, 'simultaneous'),
#  ('Numbers 7:48', 441664, 694457, 'simultaneous'),
#  ('Numbers 7:54', 441675, 694481, 'simultaneous'),
#  ('Numbers 7:60', 441686, 694505, 'simultaneous'),
#  ('Numbers 7:66', 441697, 694529, 'simultaneous'),
#  ('Numbers 7:72', 441708, 694553, 'simultaneous'),
#  ('Numbers 7:78', 441719, 694577, 'simultaneous'),
#  ('Numbers 8:15', 441794, 694796, 'posterior'),
#  ('Numbers 8:22', 441818, 694882, 'posterior'),
#  ('Numbers 9:1', 441834, 694935, 'simultaneous'),
#  ('Numbers 9:1', 441834, 694938, 'simultaneous'),
#  ('Numbers 9:3', 441838, 694945, 'cal_simul'),
#  ('Numbers 9:3', 441838, 694946, 'simultaneous'),
#  ('Numbers 9:5', 441842, 694962, 'cal_simul'),
#  ('Numbers 9:5', 441842, 694963, 'simultaneous'),
#  ('Numbers 9:6', 441849, 694985, 'simultaneous'),
#  ('Numbers 9:6', 441850, 694989, 'simultaneous'),
#  ('Numbers 9:11', 441867, 695033, 'cal_simul'),
#  ('Numbers 9:11', 441867, 695034, 'simultaneous'),
#  ('Numbers 9:12', 441869, 695042, 'anterior_dur'),
#  ('Numbers 9:15', 441886, 695099, 'simultaneous'),
#  ('Numbers 9:15', 441886, 695103, 'anterior_dur'),
#  ('Numbers 9:16', 441887, 695106, 'atelic_ext'),
#  ('Numbers 9:16', 441889, 695111, 'simultaneous'),
#  ('Numbers 9:17', 441892, 695118, 'posterior'),
#  ('Numbers 9:19', 441900, 695146, 'atelic_ext'),
#  ('Numbers 9:20', 441904, 695159, 'atelic_ext'),
#  ('Numbers 9:21', 441908, 695171, 'begin_to_end'),
#  ('Numbers 9:21', 441909, 695175, 'simultaneous'),
#  ('Numbers 9:21', 441911, 695179, 'atelic_ext'),
#  ('Numbers 9:22', 441914, 695186, 'atelic_ext'),
#  ('Numbers 10:10', 441950, 695295, 'habitual, multi_simul'),
#  ('Numbers 10:11', 441954, 695308, 'cal_simul'),
#  ('Numbers 10:34', 442006, 695475, 'atelic_ext'),
#  ('Numbers 11:6', 442038, 695561, 'simultaneous'),
#  ('Numbers 11:9', 442052, 695601, 'simultaneous'),
#  ('Numbers 11:18', 442095, 695744, 'anterior_dur, simultaneous'),
#  ('Numbers 11:19', 442103, 695767, 'simultaneous'),
#  ('Numbers 11:19', 442104, 695771, 'atelic_ext'),
#  ('Numbers 11:19', 442105, 695774, 'atelic_ext'),
#  ('Numbers 11:19', 442106, 695777, 'atelic_ext'),
#  ('Numbers 11:19', 442107, 695780, 'atelic_ext'),
#  ('Numbers 11:20', 442108, 695781, 'anterior_dur'),
#  ('Numbers 11:21', 442121, 695817, 'atelic_ext'),
#  ('Numbers 11:32', 442168, 695964, 'atelic_ext'),
#  ('Numbers 12:14', 442232, 696166, 'atelic_ext'),
#  ('Numbers 12:14', 442233, 696168, 'atelic_ext'),
#  ('Numbers 12:14', 442234, 696171, 'posterior'),
#  ('Numbers 12:15', 442235, 696177, 'atelic_ext'),
#  ('Numbers 12:16', 442238, 696185, 'posterior'),
#  ('Numbers 13:22', 442303, 696361, 'atelic_ext'),
#  ('Numbers 13:22', 442303, 696363, 'anterior'),
#  ('Numbers 13:25', 442310, 696389, 'posterior'),
#  ('Numbers 14:1', 442354, 696519, 'simultaneous'),
#  ('Numbers 14:11', 442392, 696633, 'anterior_dur'),
#  ('Numbers 14:11', 442393, 696637, 'anterior_dur'),
#  ('Numbers 14:14', 442408, 696687, 'atelic_ext'),
#  ('Numbers 14:14', 442409, 696690, 'simultaneous'),
#  ('Numbers 14:17', 442418, 696714, 'simultaneous'),
#  ('Numbers 14:25', 442447, 696803, 'simultaneous'),
#  ('Numbers 14:27', 442451, 696815, 'anterior_dur'),
#  ('Numbers 14:33', 442473, 696882, 'atelic_ext'),
#  ('Numbers 14:34', 442476, 696895, 'atelic_ext'),
#  ('Numbers 14:40', 442497, 696956, 'simultaneous'),
#  ('Numbers 15:32', 442612, 697322, 'simultaneous'),
#  ('Numbers 16:7', 442670, 697498, 'simultaneous'),
#  ('Numbers 16:16', 442711, 697610, 'simultaneous'),
#  ('Numbers 17:6', 442804, 697893, 'posterior, posterior_dur'),
#  ('Numbers 17:10', 442816, 697928, 'simultaneous'),
#  ('Numbers 17:23', 442859, 698072, 'posterior, posterior_dur'),
#  ('Numbers 19:7', 443010, 698569, 'posterior'),
#  ('Numbers 19:7', 443011, 698575, 'anterior_dur'),
#  ('Numbers 19:8', 443015, 698589, 'anterior_dur'),
#  ('Numbers 19:10', 443022, 698612, 'anterior_dur'),
#  ('Numbers 19:11', 443026, 698625, 'atelic_ext'),
#  ('Numbers 19:12', 443027, 698629, 'simultaneous'),
#  ('Numbers 19:12', 443028, 698631, 'simultaneous'),
#  ('Numbers 19:12', 443029, 698637, 'simultaneous'),
#  ('Numbers 19:12', 443030, 698639, 'simultaneous'),
#  ('Numbers 19:14', 443043, 698680, 'atelic_ext'),
#  ('Numbers 19:16', 443049, 698696, 'atelic_ext'),
#  ('Numbers 19:19', 443058, 698727, 'habitual, multi_simul'),
#  ('Numbers 19:19', 443059, 698730, 'simultaneous'),
#  ('Numbers 19:19', 443062, 698739, 'simultaneous'),
#  ('Numbers 19:21', 443072, 698773, 'anterior_dur'),
#  ('Numbers 19:22', 443076, 698786, 'anterior_dur'),
#  ('Numbers 20:1', 443078, 698791, 'simultaneous'),
#  ('Numbers 20:15', 443131, 698970, 'atelic_ext'),
#  ('Numbers 20:29', 443185, 699143, 'atelic_ext'),
#  ('Numbers 21:17', 443254, 699354, 'simultaneous'),
#  ('Numbers 22:4', 443335, 699588, 'simultaneous'),
#  ('Numbers 22:4', 443337, 699599, 'simultaneous'),
#  ('Numbers 22:6', 443345, 699622, 'simultaneous'),
#  ('Numbers 22:8', 443362, 699666, 'simultaneous'),
#  ('Numbers 22:13', 443383, 699730, 'simultaneous'),
#  ('Numbers 22:19', 443412, 699808, 'simultaneous'),
#  ('Numbers 22:19', 443413, 699813, 'simultaneous'),
#  ('Numbers 22:20', 443417, 699825, 'simultaneous'),
#  ('Numbers 22:21', 443426, 699847, 'simultaneous'),
#  ('Numbers 22:29', 443465, 699970, 'simultaneous'),
#  ('Numbers 22:30', 443468, 699983, 'posterior_dur'),
#  ('Numbers 22:30', 443468, 699984, 'anterior_dur'),
#  ('Numbers 22:33', 443486, 700041, 'simultaneous'),
#  ('Numbers 22:34', 443493, 700061, 'simultaneous'),
#  ('Numbers 22:41', 443527, 700156, 'simultaneous'),
#  ('Numbers 23:23', 443634, 700467, 'simultaneous'),
#  ('Numbers 24:11', 443709, 700677, 'simultaneous'),
#  ('Numbers 24:14', 443724, 700719, 'simultaneous'),
#  ('Numbers 24:14', 443728, 700729, 'simultaneous'),
#  ('Numbers 24:17', 443738, 700750, 'simultaneous'),
#  ('Numbers 24:22', 443761, 700815, 'anterior_dur'),
#  ('Numbers 25:18', 443823, 701015, 'simultaneous'),
#  ('Numbers 25:19', 443824, 701019, 'posterior'),
#  ('Numbers 28:2', 444055, 701620, 'simultaneous'),
#  ('Numbers 28:3', 444059, 701630, 'anterior_dur, simultaneous'),
#  ('Numbers 28:4', 444060, 701634, 'simultaneous'),
#  ('Numbers 28:4', 444061, 701638, 'simultaneous'),
#  ('Numbers 28:8', 444068, 701659, 'simultaneous'),
#  ('Numbers 28:9', 444071, 701664, 'simultaneous'),
#  ('Numbers 28:11', 444075, 701674, 'simultaneous'),
#  ('Numbers 28:17', 444093, 701727, 'atelic_ext'),
#  ('Numbers 28:24', 444107, 701769, 'simultaneous + atelic_ext'),
#  ('Numbers 28:25', 444110, 701776, 'simultaneous'),
#  ('Numbers 28:26', 444112, 701784, 'simultaneous'),
#  ('Numbers 28:26', 444113, 701788, 'simultaneous'),
#  ('Numbers 29:1', 444127, 701823, 'cal_simul'),
#  ('Numbers 29:7', 444138, 701859, 'simultaneous'),
#  ('Numbers 29:12', 444149, 701893, 'simultaneous'),
#  ('Numbers 29:12', 444151, 701904, 'atelic_ext'),
#  ('Numbers 29:17', 444160, 701931, 'simultaneous'),
#  ('Numbers 29:20', 444163, 701942, 'simultaneous'),
#  ('Numbers 29:23', 444166, 701952, 'simultaneous'),
#  ('Numbers 29:26', 444169, 701962, 'simultaneous'),
#  ('Numbers 29:29', 444172, 701972, 'simultaneous'),
#  ('Numbers 29:32', 444175, 701982, 'simultaneous'),
#  ('Numbers 29:35', 444178, 701991, 'simultaneous'),
#  ('Numbers 30:15', 444248, 702219, 'begin_to_end'),
#  ('Numbers 31:2', 444262, 702259, 'posterior'),
#  ('Numbers 31:17', 444293, 702368, 'simultaneous'),
#  ('Numbers 31:19', 444299, 702389, 'atelic_ext'),
#  ('Numbers 31:19', 444303, 702396, 'habitual, multi_simul'),
#  ('Numbers 31:24', 444316, 702436, 'simultaneous'),
#  ('Numbers 31:24', 444318, 702440, 'posterior'),
#  ('Numbers 32:10', 444408, 702728, 'simultaneous'),
#  ('Numbers 32:13', 444418, 702757, 'atelic_ext'),
#  ('Numbers 32:22', 444446, 702851, 'posterior'),
#  ('Numbers 33:3', 444502, 703048, 'cal_simul'),
#  ('Numbers 33:39', 444587, 703312, 'simultaneous'),
#  ('Numbers 35:25', 444795, 703973, 'anterior_dur'),
#  ('Numbers 35:28', 444802, 704002, 'anterior_dur'),
#  ('Numbers 35:28', 444803, 704004, 'posterior'),
#  ('Numbers 35:32', 444816, 704046, 'anterior_dur'),
#  ('Deuteronomy 1:3', 444872, 704242, 'simultaneous'),
#  ('Deuteronomy 1:3', 444872, 704243, 'simultaneous'),
#  ('Deuteronomy 1:3', 444872, 704244, 'simultaneous'),
#  ('Deuteronomy 1:9', 444895, 704306, 'simultaneous'),
#  ('Deuteronomy 1:10', 444900, 704318, 'simultaneous'),
#  ('Deuteronomy 1:16', 444915, 704365, 'simultaneous'),
#  ('Deuteronomy 1:18', 444927, 704399, 'simultaneous'),
#  ('Deuteronomy 1:33', 444992, 704592, 'simultaneous'),
#  ('Deuteronomy 1:33', 444997, 704600, 'atelic_ext'),
#  ('Deuteronomy 1:39', 445021, 704662, 'simultaneous'),
#  ('Deuteronomy 1:46', 445059, 704771, 'atelic_ext'),
#  ('Deuteronomy 2:1', 445064, 704787, 'atelic_ext'),
#  ('Deuteronomy 2:7', 445085, 704851, 'atelic_ext'),
#  ('Deuteronomy 2:10', 445097, 704892, 'anterior_dur, simultaneous'),
#  ('Deuteronomy 2:12', 445100, 704909, 'anterior_dur, simultaneous'),
#  ('Deuteronomy 2:18', 445123, 704973, 'simultaneous'),
#  ('Deuteronomy 2:20', 445130, 705000, 'anterior_dur, simultaneous'),
#  ('Deuteronomy 2:22', 445140, 705031, 'anterior_dur'),
#  ('Deuteronomy 2:25', 445154, 705060, 'simultaneous'),
#  ('Deuteronomy 2:34', 445191, 705165, 'simultaneous'),
#  ('Deuteronomy 3:4', 445217, 705246, 'simultaneous'),
#  ('Deuteronomy 3:8', 445225, 705272, 'simultaneous'),
#  ('Deuteronomy 3:12', 445235, 705308, 'simultaneous'),
#  ('Deuteronomy 3:14', 445242, 705331, 'anterior_dur'),
#  ('Deuteronomy 3:18', 445247, 705347, 'simultaneous'),
#  ('Deuteronomy 3:21', 445263, 705392, 'simultaneous'),
#  ('Deuteronomy 3:23', 445274, 705421, 'simultaneous'),
#  ('Deuteronomy 4:1', 445301, 705499, 'simultaneous'),
#  ('Deuteronomy 4:4', 445323, 705558, 'simultaneous'),
#  ('Deuteronomy 4:8', 445343, 705613, 'simultaneous'),
#  ('Deuteronomy 4:9', 445348, 705631, 'atelic_ext'),
#  ('Deuteronomy 4:10', 445356, 705653, 'atelic_ext'),
#  ('Deuteronomy 4:14', 445370, 705699, 'simultaneous'),
#  ('Deuteronomy 4:26', 445419, 705842, 'simultaneous'),
#  ('Deuteronomy 4:30', 445437, 705905, 'simultaneous'),
#  ('Deuteronomy 4:39', 445474, 706019, 'simultaneous'),
#  ('Deuteronomy 4:40', 445480, 706036, 'simultaneous'),
#  ('Deuteronomy 4:40', 445483, 706049, 'atelic_ext'),
#  ('Deuteronomy 4:41', 445484, 706050, 'simultaneous'),
#  ('Deuteronomy 4:42', 445487, 706067, 'posterior, posterior_dur'),
#  ('Deuteronomy 5:1', 445509, 706129, 'simultaneous'),
#  ('Deuteronomy 5:3', 445516, 706150, 'simultaneous'),
#  ('Deuteronomy 5:5', 445518, 706161, 'simultaneous'),
#  ('Deuteronomy 5:13', 445541, 706229, 'atelic_ext'),
#  ('Deuteronomy 5:24', 445576, 706341, 'simultaneous'),
#  ('Deuteronomy 5:25', 445579, 706350, 'simultaneous'),
#  ('Deuteronomy 5:29', 445606, 706427, 'atelic_ext'),
#  ('Deuteronomy 5:29', 445607, 706431, 'anterior_dur, simultaneous'),
#  ('Deuteronomy 6:2', 445634, 706508, 'atelic_ext'),
#  ('Deuteronomy 6:6', 445651, 706546, 'simultaneous'),
#  ('Deuteronomy 6:20', 445695, 706672, 'simultaneous'),
#  ('Deuteronomy 6:24', 445710, 706719, 'atelic_ext'),
#  ('Deuteronomy 7:11', 445761, 706876, 'simultaneous'),
#  ('Deuteronomy 8:1', 445827, 707074, 'simultaneous'),
#  ('Deuteronomy 8:2', 445835, 707097, 'atelic_ext'),
#  ('Deuteronomy 8:4', 445851, 707143, 'atelic_ext'),
#  ('Deuteronomy 8:11', 445874, 707209, 'simultaneous'),
#  ('Deuteronomy 8:19', 445908, 707304, 'simultaneous'),
#  ('Deuteronomy 9:1', 445916, 707323, 'simultaneous'),
#  ('Deuteronomy 9:3', 445924, 707343, 'simultaneous'),
#  ('Deuteronomy 9:7', 445951, 707422, 'anterior_dur_past?'),
#  ('Deuteronomy 9:9', 445960, 707452, 'atelic_ext'),
#  ('Deuteronomy 9:10', 445966, 707475, 'simultaneous'),
#  ('Deuteronomy 9:11', 445968, 707478, 'posterior'),
#  ('Deuteronomy 9:18', 445999, 707571, 'atelic_ext'),
#  ('Deuteronomy 9:20', 446012, 707610, 'simultaneous'),
#  ('Deuteronomy 9:25', 446032, 707673, 'atelic_ext'),
#  ('Deuteronomy 10:1', 446054, 707726, 'simultaneous'),
#  ('Deuteronomy 10:4', 446067, 707777, 'simultaneous'),
#  ('Deuteronomy 10:8', 446081, 707820, 'simultaneous'),
#  ('Deuteronomy 10:8', 446085, 707832, 'anterior_dur'),
#  ('Deuteronomy 10:10', 446090, 707851, 'atelic_ext'),
#  ('Deuteronomy 10:12', 446101, 707880, 'simultaneous'),
#  ('Deuteronomy 10:13', 446110, 707903, 'simultaneous'),
#  ('Deuteronomy 10:15', 446117, 707920, 'simultaneous'),
#  ('Deuteronomy 10:22', 446138, 707983, 'simultaneous'),
#  ('Deuteronomy 11:1', 446140, 707993, 'atelic_ext'),
#  ('Deuteronomy 11:2', 446141, 707996, 'simultaneous'),
#  ('Deuteronomy 11:4', 446150, 708027, 'anterior_dur'),
#  ('Deuteronomy 11:8', 446162, 708063, 'simultaneous'),
#  ('Deuteronomy 11:13', 446187, 708136, 'simultaneous'),
#  ('Deuteronomy 11:14', 446190, 708145, 'simultaneous'),
#  ('Deuteronomy 11:26', 446236, 708291, 'simultaneous'),
#  ('Deuteronomy 11:27', 446239, 708301, 'simultaneous'),
#  ('Deuteronomy 11:28', 446243, 708315, 'simultaneous'),
#  ('Deuteronomy 11:32', 446262, 708371, 'simultaneous'),
#  ('Deuteronomy 12:1', 446264, 708383, 'atelic_ext'),
#  ('Deuteronomy 12:8', 446288, 708458, 'simultaneous'),
#  ('Deuteronomy 12:9', 446291, 708467, 'anterior_dur'),
#  ('Deuteronomy 12:19', 446330, 708593, 'atelic_ext'),
#  ('Deuteronomy 12:28', 446369, 708705, 'anterior_dur'),
#  ('Deuteronomy 13:19', 446479, 709029, 'simultaneous'),
#  ('Deuteronomy 14:22', 446539, 709187, 'multi_simuls, atelic_ext'),
#  ('Deuteronomy 14:23', 446544, 709202, 'atelic_ext'),
#  ('Deuteronomy 14:28', 446565, 709267, 'posterior'),
#  ('Deuteronomy 15:1', 446574, 709293, 'posterior'),
#  ('Deuteronomy 15:5', 446591, 709349, 'simultaneous'),
#  ('Deuteronomy 15:12', 446622, 709458, 'atelic_ext'),
#  ('Deuteronomy 15:12', 446623, 709460, 'simultaneous'),
#  ('Deuteronomy 15:15', 446632, 709494, 'simultaneous'),
#  ('Deuteronomy 15:18', 446645, 709535, 'atelic_ext'),
#  ('Deuteronomy 15:20', 446653, 709558, 'habitual'),
#  ('Deuteronomy 16:1', 446663, 709590, 'simultaneous'),
#  ('Deuteronomy 16:1', 446663, 709594, 'simultaneous'),
#  ('Deuteronomy 16:3', 446668, 709611, 'atelic_ext'),
#  ('Deuteronomy 16:3', 446670, 709624, 'atelic_ext'),
#  ('Deuteronomy 16:4', 446672, 709631, 'atelic_ext'),
#  ('Deuteronomy 16:4', 446673, 709639, 'anterior_dur, simultaneous'),
#  ('Deuteronomy 16:4', 446674, 709638, 'habitual, multi_simul'),
#  ('Deuteronomy 16:7', 446686, 709676, 'simultaneous'),
#  ('Deuteronomy 16:8', 446688, 709680, 'atelic_ext'),
#  ('Deuteronomy 16:13', 446707, 709736, 'atelic_ext'),
#  ('Deuteronomy 16:15', 446711, 709745, 'atelic_ext'),
#  ('Deuteronomy 17:19', 446821, 710098, 'atelic_ext'),
#  ('Deuteronomy 18:5', 446840, 710160, 'atelic_ext'),
#  ('Deuteronomy 18:16', 446872, 710259, 'simultaneous'),
#  ('Deuteronomy 19:4', 446923, 710412, 'posterior, posterior_dur'),
#  ('Deuteronomy 19:6', 446939, 710463, 'posterior, posterior_dur'),
#  ('Deuteronomy 19:9', 446950, 710494, 'simultaneous'),
#  ('Deuteronomy 19:9', 446952, 710500, 'atelic_ext'),
#  ('Deuteronomy 20:3', 447015, 710690, 'simultaneous'),
#  ('Deuteronomy 20:19', 447088, 710905, 'atelic_ext'),
#  ('Deuteronomy 21:13', 447155, 711109, 'atelic_ext'),
#  ('Deuteronomy 21:23', 447199, 711248, 'simultaneous'),
#  ('Deuteronomy 22:19', 447275, 711495, 'atelic_ext'),
#  ('Deuteronomy 22:29', 447327, 711656, 'atelic_ext'),
#  ('Deuteronomy 23:4', 447334, 711685, 'anterior_dur'),
#  ('Deuteronomy 23:7', 447343, 711718, 'atelic_ext'),
#  ('Deuteronomy 23:7', 447343, 711719, 'anterior_dur'),
#  ('Deuteronomy 24:5', 447441, 712030, 'atelic_ext'),
#  ('Deuteronomy 24:15', 447477, 712133, 'simultaneous'),
#  ('Deuteronomy 26:3', 447603, 712521, 'simultaneous'),
#  ('Deuteronomy 26:10', 447624, 712591, 'simultaneous'),
#  ('Deuteronomy 26:12', 447634, 712619, 'simultaneous'),
#  ('Deuteronomy 26:16', 447654, 712678, 'simultaneous'),
#  ('Deuteronomy 26:17', 447658, 712691, 'simultaneous'),
#  ('Deuteronomy 26:18', 447663, 712707, 'simultaneous'),
#  ('Deuteronomy 27:1', 447675, 712740, 'simultaneous'),
#  ('Deuteronomy 27:2', 447676, 712743, 'simultaneous'),
#  ('Deuteronomy 27:4', 447689, 712786, 'simultaneous'),
#  ('Deuteronomy 27:9', 447706, 712834, 'simultaneous'),
#  ('Deuteronomy 27:10', 447709, 712847, 'simultaneous'),
#  ('Deuteronomy 27:11', 447710, 712852, 'simultaneous'),
#  ('Deuteronomy 28:1', 447777, 712989, 'simultaneous'),
#  ('Deuteronomy 28:12', 447809, 713088, 'simultaneous'),
#  ('Deuteronomy 28:13', 447818, 713120, 'simultaneous'),
#  ('Deuteronomy 28:14', 447822, 713132, 'simultaneous'),
#  ('Deuteronomy 28:15', 447829, 713149, 'simultaneous'),
#  ('Deuteronomy 28:29', 447870, 713261, 'telic_ext, dist_fut, dist_past'),
#  ('Deuteronomy 28:29', 447873, 713274, 'atelic_ext'),
#  ('Deuteronomy 28:32', 447889, 713324, 'atelic_ext'),
#  ('Deuteronomy 28:33', 447893, 713338, 'atelic_ext'),
#  ('Deuteronomy 28:46', 447935, 713469, 'anterior_dur'),
#  ('Deuteronomy 28:66', 448010, 713720, 'atelic_ext'),
#  ('Deuteronomy 28:67', 448012, 713725, 'simultaneous'),
#  ('Deuteronomy 28:67', 448014, 713731, 'simultaneous'),
#  ('Deuteronomy 29:3', 448035, 713805, 'anterior_dur'),
#  ('Deuteronomy 29:4', 448039, 713809, 'atelic_ext'),
#  ('Deuteronomy 29:9', 448056, 713862, 'simultaneous'),
#  ('Deuteronomy 29:11', 448060, 713874, 'simultaneous'),
#  ('Deuteronomy 29:12', 448061, 713877, 'simultaneous'),
#  ('Deuteronomy 29:14', 448068, 713904, 'simultaneous'),
#  ('Deuteronomy 29:14', 448069, 713911, 'simultaneous'),
#  ('Deuteronomy 29:17', 448077, 713936, 'simultaneous'),
#  ('Deuteronomy 29:19', 448091, 713970, 'simultaneous'),
#  ('Deuteronomy 29:28', 448128, 714089, 'anterior_dur'),
#  ('Deuteronomy 30:2', 448137, 714119, 'simultaneous'),
#  ('Deuteronomy 30:8', 448159, 714188, 'simultaneous'),
#  ('Deuteronomy 30:11', 448169, 714220, 'simultaneous'),
#  ('Deuteronomy 30:15', 448188, 714272, 'simultaneous'),
#  ('Deuteronomy 30:16', 448189, 714277, 'simultaneous'),
#  ('Deuteronomy 30:18', 448203, 714314, 'simultaneous'),
#  ('Deuteronomy 30:19', 448209, 714331, 'simultaneous'),
#  ('Deuteronomy 31:2', 448224, 714373, 'simultaneous'),
#  ('Deuteronomy 31:10', 448273, 714505, 'posterior'),
#  ('Deuteronomy 31:10', 448273, 714506, 'simultaneous'),
#  ('Deuteronomy 31:10', 448273, 714507, 'simultaneous'),
#  ('Deuteronomy 31:13', 448287, 714545, 'atelic_ext'),
#  ('Deuteronomy 31:17', 448309, 714616, 'simultaneous'),
#  ('Deuteronomy 31:17', 448315, 714631, 'simultaneous'),
#  ('Deuteronomy 31:18', 448318, 714645, 'simultaneous'),
#  ('Deuteronomy 31:19', 448321, 714653, 'simultaneous'),
#  ('Deuteronomy 31:21', 448341, 714711, 'simultaneous'),
#  ('Deuteronomy 31:22', 448344, 714721, 'simultaneous'),
#  ('Deuteronomy 31:27', 448364, 714777, 'simultaneous'),
#  ('Deuteronomy 31:27', 448366, 714784, 'posterior'),
#  ...]
