# %% [markdown]
# # Examining the Effects of Several Corpus Limitations

# %%
from tf.fabric import Fabric
from tf.app import use

# %%
TF = Fabric(
    locations=['/Users/cody/github/etcbc/bhsa/tf/c',
               '/Users/cody/github/etcbc/genre_synvar/tf/c'], 
    silent='deep',
)


API = TF.load(
    'kind lex vt pdp ls '
    'lex_utf8 nu code rela '
    'prs prs_gn prs_nu prs_ps '
    'genre mother txt uvf typ '
    'g_prs_utf8 sp vs typ '
    'voc_lex_utf8 '
    'label gloss function number '
    'language '
)
# Out:
#    |     1.34s T language             from ~/github/etcbc/bhsa/tf/c

# %%
bhsa = use('etcbc/bhsa', backend=None, api=API)
F, E, T, L = (getattr(bhsa.api, method) for method in "FETL")
# Out:
# **Locating corpus resources ...**
# <b title="local commit">app:</b> <span title="#b83bcaee62ada4d03547df0b0e7aac2fd5de3f67 offline under /Users/cody/text-fabric-data/github">~/text-fabric-data/github/etcbc/bhsa/app</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.3.1</a>, <a target="_blank" href="https://github.com/etcbc/bhsa/blob/master/app" title="etcbc/bhsa app">etcbc/bhsa/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
# ...

# %%
test = bhsa.search('''

book book@en=Genesis|Exodus|Leviticus|Numbers|Deuteronomy|Joshua|Judges|1_Samuel|2_Samuel|1_Kings|2_Kings
    verse genre=prose
        clause
        /with/
            phrase function=Time
        /-/

''')
# Out:
#   0.18s 1724 results

# %%
test = bhsa.search('''

book book@en=Genesis|Exodus|Leviticus|Numbers|Deuteronomy|Joshua|Judges|1_Samuel|2_Samuel|1_Kings|2_Kings
    verse genre=prose
        clause
        /with/
            phrase function=Time
                =: word lex=B
        /-/

''')
# Out:
#   0.36s 473 results

# %%
# bhsa.show(test)

# %%
test = bhsa.search('''

book book@en=Genesis|Exodus|Leviticus|Numbers|Deuteronomy|Joshua|Judges|1_Samuel|2_Samuel|1_Kings|2_Kings
    verse genre=prose
        clause
        /with/
            phrase function=Time
                =: word lex=L
        /-/

''')
# Out:
#   0.34s 81 results

# %%
test = bhsa.search('''

book book@en=Genesis|Exodus|Leviticus|Numbers|Deuteronomy|Joshua|Judges|1_Samuel|2_Samuel|1_Kings|2_Kings
    verse genre=prose
        clause
        /with/
            phrase function=Time
                =: word lex=<D
        /-/

''')
# Out:
#   0.34s 149 results

# %%
test = bhsa.search('''

book book@en=Genesis|Exodus|Leviticus|Numbers|Deuteronomy|Joshua|Judges|1_Samuel|2_Samuel|1_Kings|2_Kings
    verse genre=prose
        clause
        /with/
            phrase function=Time typ=NP
        /-/

''')
# Out:
#   0.17s 519 results

# %%
bhsa.show(test)
# Out:
# <p><b>result</b> <i>1</i>
# <div class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=1&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis">Genesis</a></span></div><div class="rtl children"><div class="contnr c4 trm rtl  " ><div class="lbl c4 trm " ><span class="nd">book </span> <span class="txtu hbo"><span class="tfsechead rtl"><span class="ltr">Genesis</span></span></span></div><div class="features"><span class="book@en xft" ><span class="f">book@en=</span>Genesis</span></div></div></div>
# ...

# %%
test = bhsa.search('''

book book@en=Genesis|Exodus|Leviticus|Numbers|Deuteronomy|Joshua|Judges|1_Samuel|2_Samuel|1_Kings|2_Kings
    verse genre=prose
        clause
        /with/
            phrase function=Time typ=PP
        /-/

''')
# Out:
#   0.18s 885 results

# %%
test = bhsa.search('''

book book@en=Genesis|Exodus|Leviticus|Numbers|Deuteronomy|Joshua|Judges|1_Samuel|2_Samuel|1_Kings|2_Kings
    verse genre=prose
        clause
        /with/
            phrase function=Time typ=AdvP
        /-/


''')
# Out:
#   0.16s 347 results
